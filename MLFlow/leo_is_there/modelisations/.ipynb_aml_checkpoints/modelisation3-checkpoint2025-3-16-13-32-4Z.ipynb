# %%
import pandas as pd
import numpy as np
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import joblib
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV, KFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from xgboost import XGBRegressor
warnings.filterwarnings('ignore')
from sklearn.model_selection import GridSearchCV, KFold
import numpy as np
import time

# %%
def load_data(filepath, sep=';', encoding='utf-8'):
    """Charge les données avec gestion des erreurs améliorée"""
    try:
        df = pd.read_csv(filepath, sep=sep, engine='python', quoting=3, 
                         on_bad_lines='skip', encoding=encoding)
        print(f"Chargement réussi: {df.shape[0]} lignes et {df.shape[1]} colonnes")
        return df
    except Exception as e:
        print(f"Erreur lors du chargement: {e}")
        try:
            # Alternative avec CSV standard
            df = pd.read_csv(filepath, sep=sep, encoding=encoding)
            print(f"Chargement alternatif réussi: {df.shape[0]} lignes et {df.shape[1]} colonnes")
            return df
        except Exception as e2:
            print(f"Échec du chargement alternatif: {e2}")
            return None


df = load_data('fusionV3.csv')
df_clean = df.copy()
# Out:
# Chargement réussi: 7944 lignes et 46 colonnes

# %% [markdown]
# Delete colonnes inutiles

# %%
# Liste des colonnes à supprimer
colonnes_a_supprimer = [
    "titre_jpbox"
]

# Supprimer uniquement les colonnes qui existent dans le dataframe
colonnes_existantes = [col for col in colonnes_a_supprimer if col in df_clean.columns]

# Supprimer les colonnes
df_clean = df_clean.drop(columns=colonnes_existantes)

# Afficher un message indiquant quelles colonnes ont été supprimées
print(f"{len(colonnes_existantes)} colonnes ont été supprimées sur {len(colonnes_a_supprimer)} demandées.")
print(f"Colonnes supprimées: {colonnes_existantes}")
print(f"Colonnes restantes: {df_clean.columns.tolist()}")
# Out:
# 1 colonnes ont été supprimées sur 1 demandées.
# Colonnes supprimées: ['titre_jpbox']
# Colonnes restantes: ['film_id', 'genre_principale', 'genres', 'date_sortie_france', 'date_sortie_usa', 'duree_minutes', 'synopsis_x', 'realisateur', 'acteurs', 'pays_origine', 'budget', 'box_office_demarrage', 'box_office_france', 'recette_usa', 'recette_monde', 'image_url', 'note_moyenne', 'titre_clean', 'titre_allocine', 'film_url', 'film_image_url', 'release_date', 'duration', 'age_classification', 'producers', 'director', 'top_stars', 'press_rating', 'viewer_rating', 'languages', 'distributor', 'year_of_production', 'film_nationality', 'filming_secrets', 'fr_entry_week', 'us_entry_week', 'fr_entries', 'us_entries', 'awards', 'associated_genres', 'press_critics_count', 'viewer_critics_count', 'broadcast_category', 'trailer_views', 'synopsis_y']

# %% [markdown]
# Création du jeu de données de test

# %%
films_test = [
    "Zion", 
    "Dog Man", 
    "Doux Jésus", 
    "Mikado", 
    "One of Them Days", 
    "Cassandre", 
    "Le Routard",
    "Banger",
    "Minecraft, Le Film"
]

films_present = df_clean[df['titre_allocine'].isin(films_test)]

print(films_present)
# Out:
#      film_id    genre_principale genres date_sortie_france date_sortie_usa  \
# 190    24499  Comédie dramatique    NaN         09/04/2025      00/00/0000
# 2965   24495               Drame    NaN         02/04/2025      00/00/0000
# 4039   24399           Animation    NaN         09/04/2025      31/01/2025
# 4730   24033   Aventure - Action    NaN         02/04/2025      04/04/2025
# 4731   24571   Aventure - Action    NaN         09/04/2025      00/00/0000
# 7089   24536             Comédie    NaN         02/04/2025      00/00/0000
# 7091   24496             Comédie    NaN         02/04/2025      00/00/0000
# 7092   24393             Comédie    NaN         07/04/2025      17/01/2025
# 7093   24572             Comédie    NaN         09/04/2025      00/00/0000
#
#      duree_minutes                                         synopsis_x  \
# 190           34.0  Mikado et Laetitia vivent avec leurs enfants s...
# 2965          43.0  Été 1998. Campagne. Cassandre a 14 ans. Dans l...
# 4039          34.0  Lorsqu’un un policier et son fidèle compagnon ...
# 4730          41.0  Bienvenue dans l’univers de Minecraft où la cr...
# 4731          39.0  En Guadeloupe, Chris partage son temps entre d...
# 7089          30.0  Scorpex, un DJ autrefois célèbre et aujourd'hu...
# 7091          25.0  "Yann n’a qu’un seul rêve dans la vie : voyage...
# 7092          37.0  Les meilleures amies et colocataires Dreux et ...
# 7093          26.0  Sœur Lucie, religieuse dévouée, décide de fuir...
#
#      realisateur                           acteurs pays_origine  ...  \
# 190          NaN                       Ramzy Bedia          NaN  ...
# 2965         NaN                    Zabou Breitman          NaN  ...
# 4039         NaN                               NaN          NaN  ...
# 4730         NaN          Jack Black | Jason Momoa          NaN  ...
# 4731         NaN                               NaN          NaN  ...
# 7089         NaN                    Vincent Cassel          NaN  ...
# 7091         NaN  Christian Clavier | Michel Blanc          NaN  ...
# 7092         NaN                               NaN          NaN  ...
# 7093         NaN                               NaN          NaN  ...
#
#                           us_entry_week fr_entries   us_entries awards  \
# 190                                 NaN        NaN          NaN    NaN
# 2965                                NaN        NaN          NaN    NaN
# 4039  31 janvier 2025 au 3 février 2025        NaN   36 001 940    NaN
# 4730                 04 au 7 avril 2025        NaN  162 753 003    NaN
# 4731                                NaN        NaN          NaN    NaN
# 7089                                NaN        NaN          NaN    NaN
# 7091                                NaN        NaN          NaN    NaN
# 7092              17 au 20 janvier 2025        NaN   11 807 731    NaN
# 7093                                NaN        NaN          NaN    NaN
#
#                       associated_genres   press_critics_count  \
# 190                  Comédie dramatique          31 critiques
# 2965                              Drame          24 critiques
# 4039           Action,Animation,Comédie          14 critiques
# 4730           Aventure,Comédie,Famille          17 critiques
# 4731                    Action,Thriller          11 critiques
# 7089  Comédie,Comédie musicale,Thriller           6 critiques
# 7091                            Comédie           7 critiques
# 7092                            Comédie  8 notes, 4 critiques
# 7093                            Comédie           5 critiques
#
#           viewer_critics_count broadcast_category trailer_views  \
# 190    133 notes, 42 critiques           en salle  102 854,vues
# 2965   384 notes, 96 critiques           en salle  339 132,vues
# 4039    21 notes, 11 critiques           en salle           NaN
# 4730  796 notes, 585 critiques           en salle           NaN
# 4731  256 notes, 167 critiques           en salle   78 697,vues
# 7089   481 notes, 69 critiques        sur Netflix   38 748,vues
# 7091   316 notes, 95 critiques           en salle  131 718,vues
# 7092      8 notes, 4 critiques             en VOD           NaN
# 7093   106 notes, 47 critiques           en salle   33 411,vues
#
#                                              synopsis_y
# 190   Mikado et Laetitia vivent avec leurs enfants s...
# 2965  Été 1998. Campagne. Cassandre a 14 ans. Dans l...
# 4039  Lorsqu’un policier et son fidèle compagnon de ...
# 4730  Bienvenue dans l’univers de Minecraft où la cr...
# 4731  En Guadeloupe, Chris partage son temps entre d...
# 7089  Scorpex, un DJ autrefois célèbre et aujourd'hu...
# 7091  "Yann n’a qu’un seul rêve dans la vie : voyage...
# 7092  Les meilleures amies et colocataires Dreux et ...
# 7093  Sœur Lucie, religieuse dévouée, décide de fuir...
#
# [9 rows x 45 columns]

# %%
# D'abord, vérifions les colonnes disponibles
print("Colonnes disponibles:", df_clean.columns.tolist())

# Trouvons une colonne qui contient les titres des films
# Examinons les premières lignes pour voir où sont stockés les titres
print(df_clean.head(3))

# En se basant sur les données partagées, les titres peuvent être dans d'autres colonnes
# Essayons de trouver des correspondances dans les colonnes synopsis_x ou synopsis_y
# qui pourraient contenir des descriptions avec les titres

# Option 1: Utiliser la colonne 'synopsis_x' ou 'synopsis_y' pour identifier les films
mask_films_test = False
for film in films_test:
    if 'synopsis_x' in df_clean.columns:
        mask_films_test = mask_films_test | df_clean['synopsis_x'].str.contains(film, case=False, na=False)
    if 'synopsis_y' in df_clean.columns:
        mask_films_test = mask_films_test | df_clean['synopsis_y'].str.contains(film, case=False, na=False)

# Option 2: Si vous avez identifié la bonne colonne pour les titres de films
# (peut-être en examinant les colonnes disponibles), utilisez celle-ci:
# Exemple si les titres sont dans une colonne appelée 'titre' ou autre chose:
titre_column = None
potential_title_columns = ['titre', 'titre_jpbox', 'film_title', 'name', 'title']
for col in potential_title_columns:
    if col in df_clean.columns:
        titre_column = col
        print(f"Colonne de titre trouvée: {col}")
        break

# Si nous avons trouvé une colonne de titre
if titre_column:
    mask_films_test = df_clean[titre_column].isin(films_test)
    print(f"Films trouvés avec {titre_column}: {df_clean[mask_films_test].shape[0]}")

# Option 3: Utiliser simplement les films d'avril 2025
print("Utilisation des films d'avril 2025 comme jeu de test...")
mask_avril_2025 = df_clean['date_sortie_france'].str.contains('04/2025', na=False)
print(f"Films d'avril 2025 trouvés: {df_clean[mask_avril_2025].shape[0]}")

# Créer le dataframe de test avec les films d'avril 2025
df_test = df_clean[mask_avril_2025].copy()
print(f"Nombre de films extraits pour le test: {len(df_test)}")

# Sauvegarder les valeurs réelles pour l'évaluation future (si disponibles)
if 'box_office_demarrage' in df_test.columns:
    box_office_reels = df_test['box_office_demarrage'].copy()
    print("Valeurs box office sauvegardées pour évaluation.")
else:
    # Créer une série vide si la colonne n'existe pas
    box_office_reels = pd.Series([None] * len(df_test), index=df_test.index)
    print("ATTENTION: Colonne box_office_demarrage non trouvée.")

# Mettre à NULL la cible dans le dataframe de test (si elle existe)
if 'box_office_demarrage' in df_test.columns:
    df_test['box_office_demarrage'] = None

# Retirer ces films du dataframe principal
df_clean = df_clean[~mask_avril_2025]
print(f"Nombre de films restants dans le dataset principal: {len(df_clean)}")

# Afficher les titres des films de test
print("\nFilms extraits pour le test:")
for i, (_, film) in enumerate(df_test.iterrows()):
    # Utiliser les informations disponibles
    film_info = []
    if 'synopsis_x' in film and isinstance(film['synopsis_x'], str) and len(film['synopsis_x']) > 10:
        film_info.append(film['synopsis_x'][:50] + "...")
    if 'genres' in film:
        film_info.append(f"Genre: {film['genres']}")
    if 'date_sortie_france' in film:
        film_info.append(f"Sortie: {film['date_sortie_france']}")
    
    box_office = box_office_reels.iloc[i] if i < len(box_office_reels) else None
    box_office_text = f"Box office: {box_office}" if box_office is not None else "Box office: Non disponible"
    
    print(f"- Film {i+1}: {' | '.join(film_info)}")
    print(f"  {box_office_text}")
# Out:
# Colonnes disponibles: ['film_id', 'genre_principale', 'genres', 'date_sortie_france', 'date_sortie_usa', 'duree_minutes', 'synopsis_x', 'realisateur', 'acteurs', 'pays_origine', 'budget', 'box_office_demarrage', 'box_office_france', 'recette_usa', 'recette_monde', 'image_url', 'note_moyenne', 'titre_clean', 'titre_allocine', 'film_url', 'film_image_url', 'release_date', 'duration', 'age_classification', 'producers', 'director', 'top_stars', 'press_rating', 'viewer_rating', 'languages', 'distributor', 'year_of_production', 'film_nationality', 'filming_secrets', 'fr_entry_week', 'us_entry_week', 'fr_entries', 'us_entries', 'awards', 'associated_genres', 'press_critics_count', 'viewer_critics_count', 'broadcast_category', 'trailer_views', 'synopsis_y']
#                                              film_id genre_principale genres  \
# 0                                              20941          Fantasy    NaN
# 1                                              10280          Fantasy    NaN
# 2  L'enfance de Lawrence Talbot prit fin à la mor...             None   None
#
#   date_sortie_france date_sortie_usa duree_minutes  \
# 0         08/01/2020      00/00/0000          51.0
# 1         10/02/2010      12/02/2010          42.0
# 2               None            None          None
#
#                                           synopsis_x realisateur acteurs  \
# 0  Un siècle après le début de la Contamination, ...         NaN     NaN
# 1  "Lawrence Talbot est un aristocrate torturé qu...        None    None
# 2                                               None        None    None
#
#   pays_origine  ... us_entry_week fr_entries us_entries awards  \
# 0          NaN  ...           NaN        NaN        NaN    NaN
# 1         None  ...          None       None       None   None
# 2         None  ...          None       None       None   None
#
#     associated_genres      press_critics_count     viewer_critics_count  \
# 0  Action,Fantastique  241 notes, 40 critiques  241 notes, 40 critiques
# 1                None                     None                     None
# 2                None                     None                     None
#
#   broadcast_category trailer_views  \
# 0             en VOD   47 731,vues
# 1               None          None
# 2               None          None
#
#                                           synopsis_y
# 0  Un siècle après le début de la Contamination, ...
# 1                                               None
# 2                                               None
#
# [3 rows x 45 columns]
# Utilisation des films d'avril 2025 comme jeu de test...
# Films d'avril 2025 trouvés: 13
# Nombre de films extraits pour le test: 13
# Valeurs box office sauvegardées pour évaluation.
# Nombre de films restants dans le dataset principal: 7931
#
# Films extraits pour le test:
# - Film 1: Pansy est rongée par la douleur physique et mental... | Genre: nan | Sortie: 02/04/2025
#   Box office: 25 470
# - Film 2: "Frantz Fanon, un psychiatre français originaire d... | Genre: nan | Sortie: 02/04/2025
#   Box office: Non disponible
# - Film 3: Mikado et Laetitia vivent avec leurs enfants sur l... | Genre: nan | Sortie: 09/04/2025
#   Box office: -
# - Film 4: Été 1998. Campagne. Cassandre a 14 ans. Dans le pe... | Genre: nan | Sortie: 02/04/2025
#   Box office: 23 762
# - Film 5: Ozi, une jeune orang-outan, est séparée de ses par... | Genre: nan | Sortie: 02/04/2025
#   Box office: 82 387
# - Film 6: Lorsqu’un un policier et son fidèle compagnon de l... | Genre: nan | Sortie: 09/04/2025
#   Box office: -
# - Film 7: Bienvenue dans l’univers de Minecraft où la créati... | Genre: nan | Sortie: 02/04/2025
#   Box office: 795 858
# - Film 8: En Guadeloupe, Chris partage son temps entre deals... | Genre: nan | Sortie: 09/04/2025
#   Box office: -
# - Film 9: Scorpex, un DJ autrefois célèbre et aujourd'hui en... | Genre: nan | Sortie: 02/04/2025
#   Box office: nan
# - Film 10: Depuis sa plus tendre enfance, Natacha est bien dé... | Genre: nan | Sortie: 02/04/2025
#   Box office: 56 406
# - Film 11: "Yann n’a qu’un seul rêve dans la vie : voyager. A... | Genre: nan | Sortie: 02/04/2025
#   Box office: 90 569
# - Film 12: Les meilleures amies et colocataires Dreux et Alys... | Genre: nan | Sortie: 07/04/2025
#   Box office: nan
# - Film 13: Sœur Lucie, religieuse dévouée, décide de fuir son... | Genre: nan | Sortie: 09/04/2025
#   Box office: -

# %% [markdown]
# Nettoyage des valeurs monétaire

# %%
def clean_monetary_value(value):
    """Nettoie et convertit les valeurs monétaires avec gestion améliorée des erreurs"""
    # Dictionnaire des taux de conversion approximatifs
    currency_rates = {
        '€': 1.1,  # Euro vers Dollar
        '£': 1.25, # Livre vers Dollar
        '¥': 0.0068, # Yen vers Dollar
        'CA$': 0.73, # Dollar canadien vers Dollar américain
        'A$': 0.65  # Dollar australien vers Dollar américain
    }
    
    if pd.isna(value) or value in ['Non disponible', '?', '? $', '- $', '-', '', 'nan', '? €']:
        return np.nan
        
    if isinstance(value, str):
        # Vérifier si la chaîne est un titre de film ou un texte non pertinent
        if len(value) > 20 and not any(c.isdigit() for c in value):
            return np.nan
            
        # Détecter la devise et convertir en USD
        for symbol, rate in currency_rates.items():
            if symbol in value:
                cleaned_value = value.replace(symbol, '').replace(' ', '').strip()
                try:
                    return float(cleaned_value.replace(',', '.')) * rate
                except ValueError:
                    continue
                    
        # Traitement standard pour les montants en dollars
        cleaned_value = value.replace('$', '').replace(' ', '').replace(',', '.').strip()
        
        if cleaned_value == '' or cleaned_value == '-':
            return np.nan
            
        try:
            return float(cleaned_value)
        except ValueError:
            return np.nan
            
    return value



# NETTOYAGE DES COLONNES MONÉTAIRES
monetary_columns = ['budget', 'box_office_demarrage', 'trailer_views']

for col in monetary_columns:
    if col in df_test.columns:
        print(f"Nettoyage de la colonne {col}...")
        df_test[col] = df_test[col].apply(clean_monetary_value)

if 'trailer_views' in df_test.columns:
    # Nettoyage spécifique pour trailer_views
    df_test['trailer_views_clean'] = df_test['trailer_views'].apply(
        lambda x: float(str(x).replace('vues', '').replace(',', '').strip()) 
        if isinstance(x, str) and 'vues' in x else np.nan
    )
    
    # Transformation logarithmique des vues
    df_test['log_trailer_views'] = np.log1p(df_test['trailer_views_clean'])
# Out:
# Nettoyage de la colonne budget...
# Nettoyage de la colonne box_office_demarrage...
# Nettoyage de la colonne trailer_views...

# %%
# TRAITEMENT DU JEU DE DONNEES DE TEST
monetary_columns = ['budget', 'box_office_demarrage', 'trailer_views']

for col in monetary_columns:
    if col in df_test.columns:
        print(f"Nettoyage de la colonne {col}...")
        df_test[col] = df_test[col].apply(clean_monetary_value)

if 'trailer_views' in df_test.columns:
    # Nettoyage spécifique pour trailer_views
    df_test['trailer_views_clean'] = df_test['trailer_views'].apply(
        lambda x: float(str(x).replace('vues', '').replace(',', '').strip()) 
        if isinstance(x, str) and 'vues' in x else np.nan
    )
    
    # Transformation logarithmique des vues
    df_test['log_trailer_views'] = np.log1p(df_test['trailer_views_clean'])
# Out:
# Nettoyage de la colonne budget...
# Nettoyage de la colonne box_office_demarrage...
# Nettoyage de la colonne trailer_views...

# %% [markdown]
# Nettoyage de la durée

# %%
def extract_duration_minutes(duration):
    """Extrait la durée en minutes à partir de différents formats"""
    if pd.isna(duration):
        return np.nan
        
    # Si c'est déjà un nombre, le retourner
    if isinstance(duration, (int, float)):
        return float(duration)
        
    # Convertir en string pour traiter
    duration_str = str(duration)
    
    # Format '1h 32min' ou '1h32min' ou '1h32'
    match = re.search(r'(\d+)h\s*(\d*)', duration_str)
    if match:
        hours = int(match.group(1))
        minutes = 0
        if match.group(2):
            minutes = int(match.group(2))
        return hours * 60 + minutes
    
    # Format '92min' ou '92 min'
    match = re.search(r'(\d+)\s*min', duration_str)
    if match:
        return int(match.group(1))
    
    # Format simple nombre (déjà en minutes)
    try:
        return float(duration_str)
    except ValueError:
        return np.nan
    


# TRAITEMENT DE LA DUREE
if 'duration' in df_test.columns:
    df_test['duree_minutes'] = df_test['duration'].apply(extract_duration_minutes)
elif 'duree' in df_clean.columns:
    df_clean['duree_minutes'] = df_clean['duree'].apply(extract_duration_minutes)

# Création d'une colonne unique pour la durée
if 'duree_minutes' in df_clean.columns:
    df_clean['duree_film'] = df_clean['duree_minutes']

# %%
# TRAITEMENT DU JEU DE DONNEES DE TEST
if 'duration' in df_test.columns:
    df_test['duree_minutes'] = df_test['duration'].apply(extract_duration_minutes)
elif 'duree' in df_test.columns:
    df_test['duree_minutes'] = df_test['duree'].apply(extract_duration_minutes)

# Création d'une colonne unique pour la durée
if 'duree_minutes' in df_test.columns:
    df_test['duree_film'] = df_test['duree_minutes']

# %% [markdown]
# Nettoyage des notes

# %%
def clean_numeric_value(value):
    """Nettoie et convertit les valeurs numériques générales"""
    if pd.isna(value) or value in ['Non disponible', '?', '-', '', 'nan']:
        return np.nan
        
    if isinstance(value, str):
        cleaned_value = value.replace(',', '.').strip()
        
        if cleaned_value == '' or cleaned_value == '-':
            return np.nan
            
        try:
            return float(cleaned_value)
        except ValueError:
            return np.nan
            
    return value



# NETTOYAGE DES NOTES
numeric_columns = ['press_rating']

for col in numeric_columns:
    if col in df_clean.columns:
        print(f"Nettoyage de la colonne {col}...")
        df_clean[col] = df_clean[col].apply(clean_numeric_value)
# Out:
# Nettoyage de la colonne press_rating...

# %%
# TRAITEMENT DU JEU DE DONNEES DE TEST
numeric_columns = ['press_rating']

for col in numeric_columns:
    if col in df_test.columns:
        print(f"Nettoyage de la colonne {col}...")
        df_test[col] = df_test[col].apply(clean_numeric_value)
# Out:
# Nettoyage de la colonne press_rating...

# %% [markdown]
# Extraire les informations temporelles

# %%
def extract_month(date_str):
    """Extrait le mois à partir d'une date au format DD/MM/YYYY"""
    if pd.isna(date_str):
        return np.nan
        
    match = re.search(r'(\d{1,2})/(\d{1,2})/(\d{4})', str(date_str))
    if match:
        return int(match.group(2))
        
    return np.nan

def extract_year(date_str):
    """Extrait l'année à partir d'une date au format DD/MM/YYYY"""
    if pd.isna(date_str):
        return np.nan
        
    match = re.search(r'(\d{1,2})/(\d{1,2})/(\d{4})', str(date_str))
    if match:
        return int(match.group(3))
    
    # Format YYYY uniquement
    match = re.search(r'^(\d{4})$', str(date_str).strip())
    if match:
        return int(match.group(1))
        
    return np.nan

def determine_season(month):
    """Détermine la saison en fonction du mois"""
    if pd.isna(month):
        return np.nan
    month = int(month)
    if month in [12, 1, 2]:
        return 1  # Hiver
    elif month in [3, 4, 5]:
        return 2  # Printemps
    elif month in [6, 7, 8]:
        return 3  # Été
    else:
        return 4  # Automne

def is_holiday_season(month, day=15):
    """Détermine si c'est une période de vacances scolaires"""
    if pd.isna(month):
        return np.nan
    
    month = int(month)
    
    # Vacances d'été (juillet-août)
    if month in [7, 8]:
        return 1
    # Vacances de Noël (décembre)
    elif month == 12:
        return 1
    # Vacances d'hiver (février)
    elif month == 2:
        return 1
    # Vacances de printemps (avril)
    elif month == 4:
        return 1
    # Vacances de la Toussaint (octobre)
    elif month == 10:
        return 1
    else:
        return 0
    


# EXTRACTION DES INFORMATIONS TEMPORELLES
if 'date_sortie_france' in df_clean.columns:
    df_clean['annee_sortie'] = df_clean['date_sortie_france'].apply(extract_year)
    df_clean['mois_sortie'] = df_clean['date_sortie_france'].apply(extract_month)
    df_clean['saison_sortie'] = df_clean['mois_sortie'].apply(determine_season)
    df_clean['vacances_scolaires'] = df_clean['mois_sortie'].apply(is_holiday_season)

    # Créer des indicateurs pour les périodes clés de sortie
    df_clean['sortie_ete'] = (df_clean['mois_sortie'].isin([6, 7, 8])).astype(int)
    df_clean['sortie_fetes'] = (df_clean['mois_sortie'].isin([11, 12])).astype(int)
    
    # Post-COVID (après 2020)
    df_clean['post_covid'] = (df_clean['annee_sortie'] >= 2020).astype(int)
    
    # Jour de la semaine de sortie
    try:
        df_clean['day_of_week'] = pd.to_datetime(
            df_clean['date_sortie_france'], 
            format='%d/%m/%Y', 
            errors='coerce'
        ).dt.dayofweek
        
        # Est-ce une sortie mercredi (jour traditionnel en France)
        df_clean['is_wednesday_release'] = (df_clean['day_of_week'] == 2).astype(int)
        
        # Est-ce une sortie en week-end (vendredi-dimanche)
        df_clean['is_weekend_release'] = df_clean['day_of_week'].isin([4, 5, 6]).astype(int)
    except:
        print("Impossible de calculer le jour de la semaine")

# %%
# TRAITEMENT DU JEU DE DONNEES DE TEST
if 'date_sortie_france' in df_test.columns:
    df_test['annee_sortie'] = df_test['date_sortie_france'].apply(extract_year)
    df_test['mois_sortie'] = df_test['date_sortie_france'].apply(extract_month)
    df_test['saison_sortie'] = df_test['mois_sortie'].apply(determine_season)
    df_test['vacances_scolaires'] = df_test['mois_sortie'].apply(is_holiday_season)

    # Créer des indicateurs pour les périodes clés de sortie
    df_test['sortie_ete'] = (df_test['mois_sortie'].isin([6, 7, 8])).astype(int)
    df_test['sortie_fetes'] = (df_test['mois_sortie'].isin([11, 12])).astype(int)
    
    # Post-COVID (après 2020)
    df_test['post_covid'] = (df_test['annee_sortie'] >= 2020).astype(int)
    
    # Jour de la semaine de sortie
    try:
        df_test['day_of_week'] = pd.to_datetime(
            df_test['date_sortie_france'], 
            format='%d/%m/%Y', 
            errors='coerce'
        ).dt.dayofweek
        
        # Est-ce une sortie mercredi (jour traditionnel en France)
        df_test['is_wednesday_release'] = (df_test['day_of_week'] == 2).astype(int)
        
        # Est-ce une sortie en week-end (vendredi-dimanche)
        df_test['is_weekend_release'] = df_test['day_of_week'].isin([4, 5, 6]).astype(int)
    except:
        print("Impossible de calculer le jour de la semaine")

# %% [markdown]
# Catégoriser le budget

# %%
def categorize_budget(budget):
    """Catégorise le budget en 4 niveaux"""
    if pd.isna(budget):
        return np.nan
    elif budget < 10000000:  # Moins de 10 millions
        return 1  # Petit budget
    elif budget < 50000000:  # Entre 10 et 50 millions
        return 2  # Budget moyen
    elif budget < 100000000:  # Entre 50 et 100 millions
        return 3  # Gros budget
    else:  # 100 millions et plus
        return 4  # Blockbuster

df_clean['budget'] = pd.to_numeric(df_clean['budget'], errors='coerce')
# Transformation logarithmique du budget
if 'budget' in df_clean.columns:
    df_clean['log_budget'] = np.log1p(df_clean['budget'])
    
    # Catégorisation du budget
    df_clean['categorie_budget'] = df_clean['budget'].apply(categorize_budget)
    
    # Blockbusters d'été
    budget_median = df_clean['budget'].median()
    df_clean['is_summer_blockbuster'] = ((df_clean['mois_sortie'] >= 6) & 
                                        (df_clean['mois_sortie'] <= 8) & 
                                        (df_clean['budget'] > budget_median)).astype(int)
    
    # Ratio marketing/budget (estimation à partir de règles de l'industrie)
    df_clean['marketing_ratio'] = np.where(
        df_clean['budget'] > df_clean['budget'].quantile(0.75), 0.5,
        np.where(df_clean['budget'] > df_clean['budget'].quantile(0.25), 0.3, 0.2)
    )
    df_clean['estimated_marketing_budget'] = df_clean['budget'] * df_clean['marketing_ratio']
    df_clean['estimated_total_budget'] = df_clean['budget'] + df_clean['estimated_marketing_budget']
    df_clean['log_total_budget'] = np.log1p(df_clean['estimated_total_budget'])

# %%
# TRAITEMENT DU JEU DE DONNEES DE TEST
if 'budget' in df_test.columns:
    df_test['log_budget'] = np.log1p(df_test['budget'])
    
    # Catégorisation du budget
    df_test['categorie_budget'] = df_test['budget'].apply(categorize_budget)
    
    # Blockbusters d'été
    budget_median = df_test['budget'].median()
    df_test['is_summer_blockbuster'] = ((df_test['mois_sortie'] >= 6) & 
                                        (df_test['mois_sortie'] <= 8) & 
                                        (df_test['budget'] > budget_median)).astype(int)
    
    # Ratio marketing/budget (estimation à partir de règles de l'industrie)
    df_test['marketing_ratio'] = np.where(
        df_test['budget'] > df_test['budget'].quantile(0.75), 0.5,
        np.where(df_test['budget'] > df_test['budget'].quantile(0.25), 0.3, 0.2)
    )
    df_test['estimated_marketing_budget'] = df_test['budget'] * df_test['marketing_ratio']
    df_test['estimated_total_budget'] = df_test['budget'] + df_test['estimated_marketing_budget']
    df_test['log_total_budget'] = np.log1p(df_test['estimated_total_budget'])

# %% [markdown]
# Traitement des acteurs et franchises

# %%
# Caractéristique pour les films avec des stars importantes
famous_actors = [
                # Acteurs
                'Leonardo DiCaprio', 'Dwayne Johnson', 'Brad Pitt', 'Tom Cruise', 'Ryan Reynolds',
                'Robert Downey Jr', 'Chris Hemsworth', 'Chris Evans', 'Keanu Reeves', 'Will Smith',
                'Johnny Depp', 'Matt Damon', 'Christian Bale', 'Timothée Chalamet', 'Jake Gyllenhaal',
                'Benedict Cumberbatch', 'Tom Holland', 'Michael B. Jordan', 'Hugh Jackman', 'Oscar Isaac',
                'Cillian Murphy', 'Adam Driver', 'Daniel Craig', 'Joaquin Phoenix', 'Mark Wahlberg',
                'Denzel Washington', 'Tom Hanks', 'George Clooney', 'Ryan Gosling', 'Jamie Foxx',
                'Idris Elba', 'Chris Pratt', 'Samuel L. Jackson', 'Jason Statham', 'Anthony Hopkins',
                
                # Actrices
                'Margot Robbie', 'Scarlett Johansson', 'Jennifer Lawrence', 'Zendaya', 'Emma Stone',
                'Natalie Portman', 'Florence Pugh', 'Gal Gadot', 'Anya Taylor-Joy', 'Cate Blanchett',
                'Charlize Theron', 'Emily Blunt', 'Anne Hathaway', 'Jessica Chastain', 'Saoirse Ronan',
                'Viola Davis', 'Brie Larson', 'Millie Bobby Brown', 'Salma Hayek', 'Penélope Cruz',
                'Sandra Bullock', 'Angelina Jolie', 'Elizabeth Olsen', 'Rachel McAdams', 'Zoe Saldana',
                'Meryl Streep', 'Nicole Kidman', 'Julia Roberts', 'Jennifer Aniston', 'Emma Watson',
                
                # Acteurs français
                'Jean Dujardin', 'Omar Sy', 'Vincent Cassel', 'Gérard Depardieu', 'François Civil',
                'Dany Boon', 'Guillaume Canet', 'Mathieu Amalric', 'Louis Garrel', 'Melvil Poupaud',
                
                # Actrices françaises
                'Marion Cotillard', 'Léa Seydoux', 'Eva Green', 'Audrey Tautou', 'Juliette Binoche',
                'Adèle Exarchopoulos', 'Isabelle Huppert', 'Mélanie Laurent', 'Sophie Marceau', 'Catherine Deneuve'
                ]

df_clean['has_famous_actor'] = df_clean['top_stars'].apply(
                    lambda x: 1 if isinstance(x, str) and any(actor.lower() in str(x).lower() for actor in famous_actors) else 0
                )

# Feature pour les suites/franchises
if 'titre_jpbox' in df_clean.columns:
    franchise_indicators = ['2', '3', '4', '5', 'II', 'III', 'IV', 'V', 'saga', 'trilogy', 
                          'suite', 'chapitre', 'épisode', 'retour', 'episode']
    df_clean['is_franchise'] = df_clean['titre_jpbox'].apply(
        lambda x: 1 if isinstance(x, str) and any(ind in str(x).lower() for ind in franchise_indicators) else 0
    )


if 'top_stars' in df_clean.columns:
    # Nombre total d'acteurs dans le casting
    df_clean['star_count'] = df_clean['top_stars'].apply(
        lambda x: len(str(x).split(',')) if not pd.isna(x) else 0
    )
    
    # Présence d'une star majeure
    df_clean['has_famous_actor'] = df_clean['top_stars'].apply(
        lambda x: 1 if isinstance(x, str) and any(actor.lower() in str(x).lower() for actor in famous_actors) else 0
    )
    
    # Nombre d'acteurs célèbres dans le casting
    df_clean['famous_actor_count'] = df_clean['top_stars'].apply(
        lambda x: sum(1 for actor in famous_actors if isinstance(x, str) and actor.lower() in str(x).lower()) if not pd.isna(x) else 0
    )
    
    # Star power index (0-3) basé sur le nombre d'acteurs célèbres
    df_clean['star_power'] = df_clean['famous_actor_count'].apply(
        lambda x: min(3, x)  # Plafonné à 3 pour éviter les valeurs extrêmes
    )
    
    # Présence spécifique d'acteurs à forte popularité (top 10)
    top_actors = ['Leonardo DiCaprio', 'Dwayne Johnson', 'Brad Pitt', 'Tom Cruise', 
                 'Margot Robbie', 'Scarlett Johansson', 'Jennifer Lawrence', 'Robert Downey Jr',
                 'Tom Holland', 'Zendaya']
    
    df_clean['has_top_tier_actor'] = df_clean['top_stars'].apply(
        lambda x: 1 if isinstance(x, str) and any(actor.lower() in str(x).lower() for actor in top_actors) else 0
    )

# %%
# TRAITEMENT DU JEU DE DONNEES DE TEST
df_test['has_famous_actor'] = df_test['top_stars'].apply(
                    lambda x: 1 if isinstance(x, str) and any(actor.lower() in str(x).lower() for actor in famous_actors) else 0
                )

# Feature pour les suites/franchises
if 'titre_jpbox' in df_test.columns:
    franchise_indicators = ['2', '3', '4', '5', 'II', 'III', 'IV', 'V', 'saga', 'trilogy', 
                          'suite', 'chapitre', 'épisode', 'retour', 'episode']
    df_test['is_franchise'] = df_test['titre_jpbox'].apply(
        lambda x: 1 if isinstance(x, str) and any(ind in str(x).lower() for ind in franchise_indicators) else 0
    )


if 'top_stars' in df_test.columns:
    # Nombre total d'acteurs dans le casting
    df_test['star_count'] = df_test['top_stars'].apply(
        lambda x: len(str(x).split(',')) if not pd.isna(x) else 0
    )
    
    # Présence d'une star majeure
    df_test['has_famous_actor'] = df_test['top_stars'].apply(
        lambda x: 1 if isinstance(x, str) and any(actor.lower() in str(x).lower() for actor in famous_actors) else 0
    )
    
    # Nombre d'acteurs célèbres dans le casting
    df_test['famous_actor_count'] = df_test['top_stars'].apply(
        lambda x: sum(1 for actor in famous_actors if isinstance(x, str) and actor.lower() in str(x).lower()) if not pd.isna(x) else 0
    )
    
    # Star power index (0-3) basé sur le nombre d'acteurs célèbres
    df_test['star_power'] = df_test['famous_actor_count'].apply(
        lambda x: min(3, x)  # Plafonné à 3 pour éviter les valeurs extrêmes
    )
    
    # Présence spécifique d'acteurs à forte popularité (top 10)
    top_actors = ['Leonardo DiCaprio', 'Dwayne Johnson', 'Brad Pitt', 'Tom Cruise', 
                 'Margot Robbie', 'Scarlett Johansson', 'Jennifer Lawrence', 'Robert Downey Jr',
                 'Tom Holland', 'Zendaya']
    
    df_test['has_top_tier_actor'] = df_test['top_stars'].apply(
        lambda x: 1 if isinstance(x, str) and any(actor.lower() in str(x).lower() for actor in top_actors) else 0
    )

# %% [markdown]
# Traitement des distributeurs / indicateur pour les gros studios
#
# Extraction des langues pour la nationalité

# %%
# Créer une caractéristique pour les gros distributeurs
major_distributors = ['Disney', 'Warner', 'Universal', 'Sony', 'Paramount', 'Fox', 
                         'Gaumont', 'Pathé', 'Netflix', 'Amazon', 'StudioCanal']
    
for distributor in major_distributors:
        df_clean[f'distributor_{distributor.lower()}'] = df_clean['distributor'].apply(
            lambda x: 1 if isinstance(x, str) and distributor.lower() in str(x).lower() else 0
        )
    
    # Indicateur pour les grands studios (majors)
major_studios = ['Disney', 'Warner', 'Universal', 'Sony', 'Paramount', 'Fox']
df_clean['is_major_studio'] = df_clean['distributor'].apply(
        lambda x: 1 if isinstance(x, str) and any(studio.lower() in str(x).lower() for studio in major_studios) else 0
    )

# Création et nationalités via "language"
df_clean['is_english'] = df_clean['languages'].apply(
        lambda x: 1 if isinstance(x, str) and 'anglais' in str(x).lower() else 0
    )
df_clean['is_french'] = df_clean['languages'].apply(
        lambda x: 1 if isinstance(x, str) and 'français' in str(x).lower() else 0
    )

# Création et nationalités via "film_nationality"
df_clean['is_usa'] = df_clean['film_nationality'].apply(
        lambda x: 1 if isinstance(x, str) and any(term in str(x).lower() for term in ['u.s.a', 'usa', 'états-unis']) else 0
    )
df_clean['is_france'] = df_clean['film_nationality'].apply(
        lambda x: 1 if isinstance(x, str) and 'france' in str(x).lower() else 0
    )
df_clean['is_europe'] = df_clean['film_nationality'].apply(
        lambda x: 1 if isinstance(x, str) and any(term in str(x).lower() for term in ['royaume-uni', 'allemagne', 'espagne', 'italie', 'belgique']) else 0
    )

# %%
# TRAITEMENT DU JEU DE DONNEES DE TEST
major_distributors = ['Disney', 'Warner', 'Universal', 'Sony', 'Paramount', 'Fox', 
                         'Gaumont', 'Pathé', 'Netflix', 'Amazon', 'StudioCanal']
    
for distributor in major_distributors:
        df_test[f'distributor_{distributor.lower()}'] = df_test['distributor'].apply(
            lambda x: 1 if isinstance(x, str) and distributor.lower() in str(x).lower() else 0
        )
    
    # Indicateur pour les grands studios (majors)
major_studios = ['Disney', 'Warner', 'Universal', 'Sony', 'Paramount', 'Fox']
df_test['is_major_studio'] = df_test['distributor'].apply(
        lambda x: 1 if isinstance(x, str) and any(studio.lower() in str(x).lower() for studio in major_studios) else 0
    )

# Création et nationalités via "language"
df_test['is_english'] = df_test['languages'].apply(
        lambda x: 1 if isinstance(x, str) and 'anglais' in str(x).lower() else 0
    )
df_test['is_french'] = df_test['languages'].apply(
        lambda x: 1 if isinstance(x, str) and 'français' in str(x).lower() else 0
    )

# Création et nationalités via "film_nationality"
df_test['is_usa'] = df_test['film_nationality'].apply(
        lambda x: 1 if isinstance(x, str) and any(term in str(x).lower() for term in ['u.s.a', 'usa', 'états-unis']) else 0
    )
df_test['is_france'] = df_test['film_nationality'].apply(
        lambda x: 1 if isinstance(x, str) and 'france' in str(x).lower() else 0
    )
df_test['is_europe'] = df_test['film_nationality'].apply(
        lambda x: 1 if isinstance(x, str) and any(term in str(x).lower() for term in ['royaume-uni', 'allemagne', 'espagne', 'italie', 'belgique']) else 0
    )

# %% [markdown]
# Traitement des informations ayant une portée sur le public cible
#
# Catégoriser par popularité

# %%
# Classification d'âge (restriction)
if 'age_classification' in df_clean.columns:
    df_clean['is_adult_only'] = df_clean['age_classification'].apply(
        lambda x: 1 if isinstance(x, str) and any(term in str(x).lower() 
                                              for term in ['interdit', '16 ans', '18 ans', 'adulte'])
        else 0
    )

# Nombre de critiques presse (indicateur d'attente médiatique avant sortie)
if 'press_critics_count' in df_clean.columns:
    # Extraire le nombre de critiques
    df_clean['press_critics_count_num'] = df_clean['press_critics_count'].apply(
        lambda x: int(re.search(r'(\d+)', str(x)).group(1)) if isinstance(x, str) and re.search(r'(\d+)', str(x)) else 0
    )
    
    # Catégoriser par popularité
    critics_median = df_clean['press_critics_count_num'].median()
    df_clean['press_critics_count_high'] = (df_clean['press_critics_count_num'] > critics_median).astype(int)

# %%
# TRAITEMENT DU JEU DE DONNEES DE TEST
if 'age_classification' in df_test.columns:
    df_test['is_adult_only'] = df_test['age_classification'].apply(
        lambda x: 1 if isinstance(x, str) and any(term in str(x).lower() 
                                              for term in ['interdit', '16 ans', '18 ans', 'adulte'])
        else 0
    )

# Nombre de critiques presse (indicateur d'attente médiatique avant sortie)
if 'press_critics_count' in df_test.columns:
    # Extraire le nombre de critiques
    df_test['press_critics_count_num'] = df_test['press_critics_count'].apply(
        lambda x: int(re.search(r'(\d+)', str(x)).group(1)) if isinstance(x, str) and re.search(r'(\d+)', str(x)) else 0
    )
    
    # Catégoriser par popularité
    critics_median = df_test['press_critics_count_num'].median()
    df_test['press_critics_count_high'] = (df_test['press_critics_count_num'] > critics_median).astype(int)

# %% [markdown]
# Traitement approfondi de age_classification

# %%
# Classification par niveau de restriction
def get_age_rating(classification):
        if pd.isna(classification):
            return np.nan
            
        classification = str(classification).lower()
        
        if 'tous publics' in classification or 'tout public' in classification:
            return 0  # Tous publics
        elif any(term in classification for term in ['10 ans', '10+']):
            return 1  # 10+
        elif any(term in classification for term in ['12 ans', '12+']):
            return 2  # 12+
        elif any(term in classification for term in ['13 ans', 'adolescent', '13+']):
            return 2  # 13+
        elif any(term in classification for term in ['16 ans', '16+']):
            return 3  # 16+
        elif any(term in classification for term in ['18 ans', 'interdit -18', 'interdit aux mineurs', 'adulte']):
            return 4  # 18+
        else:
            return 0  # Par défaut tous publics si non spécifié
        

    # Classification binaire (tout public vs. restreint)
df_clean['is_adult_only'] = df_clean['age_classification'].apply(
        lambda x: 1 if isinstance(x, str) and any(term in str(x).lower() 
                                   for term in ['interdit', '16 ans', '18 ans', 'adulte'])
        else 0
    )
    
df_clean['age_rating'] = df_clean['age_classification'].apply(get_age_rating)
    
    # Interaction avec le genre (certains genres sont plus ou moins adaptés aux restrictions d'âge)
for genre_col in [col for col in df_clean.columns if col.startswith('genre_principale_')]:
        genre_name = genre_col.replace('genre_principale_', '')
        df_clean[f'age_rating_x_{genre_name}'] = df_clean['age_rating'] * df_clean[genre_col]
    
    # Impact sur le budget marketing (films pour adultes ont souvent un marketing différent)
if 'marketing_ratio' in df_clean.columns:
        # Pour les films adultes, un ratio marketing/budget différent
        age_factor = df_clean['age_rating'].apply(lambda x: 1 + (0.05 * x) if not pd.isna(x) else 1)
        df_clean['age_adjusted_marketing'] = df_clean['marketing_ratio'] * age_factor

# %% [markdown]
# One-hot encoding et interactions budget/genre

# %%
# One-hot encoding pour les variables catégorielles
categorical_columns = []

if 'genre_principale' in df_clean.columns:
    categorical_columns.append('genre_principale')
if 'saison_sortie' in df_clean.columns:
    categorical_columns.append('saison_sortie')
if 'categorie_budget' in df_clean.columns:
    categorical_columns.append('categorie_budget')

# One-hot encoding
if categorical_columns:
    df_clean = pd.get_dummies(df_clean, columns=categorical_columns, drop_first=False)
    
    # Lister les colonnes créées
    genre_columns = [col for col in df_clean.columns if col.startswith('genre_principale_')]
    saison_columns = [col for col in df_clean.columns if col.startswith('saison_sortie_')]
    budget_cat_columns = [col for col in df_clean.columns if col.startswith('categorie_budget_')]
    
    print(f"Colonnes de genre créées: {genre_columns}")
    print(f"Colonnes de saison créées: {saison_columns}")
    print(f"Colonnes de catégorie budget créées: {budget_cat_columns}")

# Créer des features d'interaction entre le budget et les genres
if 'budget' in df_clean.columns:
    # Utiliser seulement les genres les plus importants
    main_genres = ['action', 'comédie', 'drame', 'animation', 'fantastique', 'science-fiction']
    
    for genre in main_genres:
        genre_col = [col for col in df_clean.columns if genre.lower() in col.lower() and 'genre_' in col]
        if genre_col:
            df_clean[f'budget_x_genre_{genre}'] = df_clean['budget'] * df_clean[genre_col[0]]
    
    # Interaction entre budget et période de sortie
    if 'sortie_ete' in df_clean.columns:
        df_clean['budget_x_sortie_ete'] = df_clean['budget'] * df_clean['sortie_ete']
    if 'sortie_fetes' in df_clean.columns:
        df_clean['budget_x_sortie_fetes'] = df_clean['budget'] * df_clean['sortie_fetes']
# Out:
# Colonnes de genre créées: ['genre_principale_ Antonio, le si mielleux objet de l’affection naissante de Margo, et Eduardo Perez, le père d’Antonio, propriétaire du restaurant Salsa & Salsa et l’homme qui se cache peut-être derrière le masque d’El Macho, le plus impitoyable et, comme son nom l’indique, méchant macho que la terre ait jamais porté."', 'genre_principale_ Dev’Reaux, le liftier novice et Odessa, la femme de ménage belliqueuse, jouissent néanmoins d’un atout majeur : ils connaissent le bâtiment de fond en comble. Sans jamais s’en être rendu compte, ils repèrent les lieux du crime depuis des années."', 'genre_principale_ Roscoe Means, expert en explosifs ', "genre_principale_ enfin, Jeanne, prostituée, capable d'assassiner de sang froid.", 'genre_principale_- Artus | François Berléand', 'genre_principale_- Queen Latifah | Luc Besson', 'genre_principale_Adam Driver | Camille Cottin | Salma Hayek | Jeremy Irons | Jared Leto | Al Pacino | Ridley Scott', 'genre_principale_Adam Sandler | Chris Rock | Burt Reynolds | Courteney Cox | Adam Sandler', 'genre_principale_Adam Sandler | Gad Elmaleh | Al Pacino | Adam Sandler', 'genre_principale_Adam Sandler | Jack Nicholson | Woody Harrelson | John C. Reilly | Heather Graham | Adam Sandler', 'genre_principale_Adam Sandler | Philip Seymour Hoffman | Emily Watson', 'genre_principale_Adam Sandler | Steve Buscemi | Virginie Efira | Kevin James | Adam Sandler', 'genre_principale_Adam Sandler | Tea Leoni | Hans Zimmer', 'genre_principale_Adrien Brody | Guy Pearce', 'genre_principale_Adrien Brody | Owen Wilson | Bill Murray | Natalie Portman', 'genre_principale_Adrien Brody | Penelope Cruz', 'genre_principale_Adèle Exarchopoulos', 'genre_principale_Adèle Exarchopoulos | Reda Kateb', 'genre_principale_Agnès Jaoui | Sandrine Kiberlain | Pierre Arditi | Denis Podalydès', 'genre_principale_Alain Chabat | Judith Godrèche', 'genre_principale_Alain Chabat | Lorant Deutsch | Laurent Lafitte | Géraldine Nakache | Elie Semoun | René Goscinny', 'genre_principale_Alain Chabat | Mathilde Seigner | Fanny Ardant', 'genre_principale_Alain Chabat | Sandrine Kiberlain | Patrick Bruel', 'genre_principale_Alan Rickman', 'genre_principale_Alban Ivanov', 'genre_principale_Albert Dupontel', 'genre_principale_Albert Dupontel | Benoît Poelvoorde | Yolande Moreau', 'genre_principale_Albert Dupontel | Virginie Efira', 'genre_principale_Alec Baldwin | Hugh Jackman | Jude Law | Chris Pine | Alexandre Desplat', 'genre_principale_Alec Baldwin | Steve Buscemi | Donald Sutherland', 'genre_principale_Alec Baldwin | Steve Buscemi | Tobey Maguire | Hans Zimmer', 'genre_principale_Alexandra Lamy', 'genre_principale_Alice Pol', 'genre_principale_Amy Adams', 'genre_principale_Amy Adams | Philip Seymour Hoffman | Meryl Streep | Viola Davis | Howard Shore', 'genre_principale_André Dussollier', 'genre_principale_André Dussollier | Catherine Frot | Agatha Christie', 'genre_principale_André Dussollier | Sophie Marceau | Charlotte Rampling', 'genre_principale_Angelina Jolie | Brendan Gleeson | Anthony Hopkins | Alison Lohman | John Malkovich | Robin Wright', 'genre_principale_Animation', 'genre_principale_Anna Faris', 'genre_principale_Anna Faris | Emma Stone | Adam Sandler', 'genre_principale_Anna Faris | Marlon Wayans', 'genre_principale_Anne Heche | Denzel Washington | Ray Liotta | Robert Duvall', 'genre_principale_Annette Bening | Julianne Moore | Mark Ruffalo', 'genre_principale_Annette Bening | Kristen Wiig | Matt Dillon', 'genre_principale_Annette Bening | Naomi Watts | Samuel L. Jackson', 'genre_principale_Anthony Hopkins | Chris Rock | Jerry Brukheimer', 'genre_principale_Anthony Hopkins | Helena Bonham Carter', 'genre_principale_Antonio Banderas', 'genre_principale_Antonio Banderas | Alain Chabat | Cameron Diaz | Eddie Murphy | Mike Myers | Seth Rogen | Justin Timberlake', 'genre_principale_Arnold Schwarzenegger', 'genre_principale_Ashton Kutcher', 'genre_principale_Audrey Tautou | Cécile De France | Romain Duris', 'genre ...
# Colonnes de saison créées: ['saison_sortie_1.0', 'saison_sortie_2.0', 'saison_sortie_3.0', 'saison_sortie_4.0']
# Colonnes de catégorie budget créées: ['categorie_budget_1.0']

# %%
# TRAITEMENT DU JEU DE DONNEES DE TEST
# One-hot encoding pour les variables catégorielles
categorical_columns = []

if 'genre_principale' in df_test.columns:
    categorical_columns.append('genre_principale')
if 'saison_sortie' in df_test.columns:
    categorical_columns.append('saison_sortie')
if 'categorie_budget' in df_test.columns:
    categorical_columns.append('categorie_budget')

# One-hot encoding
if categorical_columns:
    df_test= pd.get_dummies(df_test, columns=categorical_columns, drop_first=False)
    
    # Lister les colonnes créées
    genre_columns = [col for col in df_test.columns if col.startswith('genre_principale_')]
    saison_columns = [col for col in df_test.columns if col.startswith('saison_sortie_')]
    budget_cat_columns = [col for col in df_test.columns if col.startswith('categorie_budget_')]
    
    print(f"Colonnes de genre créées: {genre_columns}")
    print(f"Colonnes de saison créées: {saison_columns}")
    print(f"Colonnes de catégorie budget créées: {budget_cat_columns}")

# Créer des features d'interaction entre le budget et les genres
if 'budget' in df_test.columns:
    # Utiliser seulement les genres les plus importants
    main_genres = ['action', 'comédie', 'drame', 'animation', 'fantastique', 'science-fiction']
    
    for genre in main_genres:
        genre_col = [col for col in df_test.columns if genre.lower() in col.lower() and 'genre_' in col]
        if genre_col:
            df_test[f'budget_x_genre_{genre}'] = df_test['budget'] * df_test[genre_col[0]]
    
    # Interaction entre budget et période de sortie
    if 'sortie_ete' in df_test.columns:
        df_test['budget_x_sortie_ete'] = df_test['budget'] * df_test['sortie_ete']
    if 'sortie_fetes' in df_test.columns:
        df_test['budget_x_sortie_fetes'] = df_test['budget'] * df_test['sortie_fetes']
# Out:
# Colonnes de genre créées: ['genre_principale_Animation', 'genre_principale_Aventure - Action', 'genre_principale_Comédie', 'genre_principale_Comédie dramatique', 'genre_principale_Drame']
# Colonnes de saison créées: ['saison_sortie_2']
# Colonnes de catégorie budget créées: ['categorie_budget_2.0', 'categorie_budget_4.0']

# %% [markdown]
# Traitement de "trailer_views" approfondi
#
# Création d'une feature pour le nombre de prix et nominations

# %%
# Traitement des vues de bande-annonce (feature prédictive importante)
if 'trailer_views' in df_clean.columns:
    # Nettoyer les vues de bande-annonce en tenant compte des caractères spéciaux
    df_clean['trailer_views_clean'] = df_clean['trailer_views'].apply(
        lambda x: float(re.sub(r'[^\d.]', '', str(x))) 
        if isinstance(x, str) and any(c.isdigit() for c in str(x)) else np.nan
    )
    
    # Transformation logarithmique des vues (pour normaliser)
    df_clean['log_trailer_views'] = np.log1p(df_clean['trailer_views_clean'])
    
    # Catégorisation des vues
    trailer_views_median = df_clean['trailer_views_clean'].median()
    df_clean['high_trailer_views'] = (df_clean['trailer_views_clean'] > trailer_views_median).astype(int)

# Traitement des récompenses et nominations (comme indicateurs de qualité prévisible)
if 'awards' in df_clean.columns:
    # Extraction du nombre de prix et nominations
    def extract_awards_count(awards_text):
        if pd.isna(awards_text):
            return 0, 0
        
        awards_text = str(awards_text).lower()
        
        # Extraire le nombre de prix
        prix_match = re.search(r'(\d+)\s+prix', awards_text)
        prix_count = int(prix_match.group(1)) if prix_match else 0
        
        # Extraire le nombre de nominations
        nom_match = re.search(r'(\d+)\s+nomination', awards_text)
        nom_count = int(nom_match.group(1)) if nom_match else 0
        
        return prix_count, nom_count
    
    # Créer des colonnes pour les prix et nominations
    df_clean[['prix_count', 'nomination_count']] = pd.DataFrame(
        df_clean['awards'].apply(extract_awards_count).tolist(),
        index=df_clean.index
    )
    
    # Feature combinée (prix ont plus de poids)
    df_clean['award_score'] = df_clean['prix_count'] * 2 + df_clean['nomination_count']
    
    # Indicateur de film primé
    df_clean['is_awarded'] = (df_clean['prix_count'] > 0).astype(int)

     # Interaction avec les prix (effet multiplicateur des récompenses sur les vues)
    df_clean['trailer_views_x_awards'] = df_clean['trailer_views_clean'] * df_clean['prix_count']
        
        # Ratio prix/vues (efficacité de conversion des récompenses en vues)
    non_zero_views = df_clean['trailer_views_clean'].replace(0, np.nan)
    df_clean['awards_per_view'] = df_clean['prix_count'] / non_zero_views
        
    if 'nomination_count' in df_clean.columns:
        # Interaction avec les nominations
        df_clean['trailer_views_x_nominations'] = df_clean['trailer_views_clean'] * df_clean['nomination_count']
        
    if 'award_score' in df_clean.columns:
        # Interaction avec le score combiné awards/nominations
        df_clean['trailer_views_x_award_score'] = df_clean['trailer_views_clean'] * df_clean['award_score']
        
        # Indicateur des films à haute visibilité et reconnaissance critique
        views_threshold = df_clean['trailer_views_clean'].quantile(0.75)
        df_clean['high_visibility_acclaimed'] = ((df_clean['trailer_views_clean'] > views_threshold) & 
                                               (df_clean['award_score'] > 0)).astype(int)

# %%
# TRAITEMENT DU JEU DE DONNEES DE TEST
# Traitement des vues de bande-annonce
if 'trailer_views' in df_test.columns:
    # Nettoyer les vues de bande-annonce en tenant compte des caractères spéciaux
    df_test['trailer_views_clean'] = df_test['trailer_views'].apply(
        lambda x: float(re.sub(r'[^\d.]', '', str(x))) 
        if isinstance(x, str) and any(c.isdigit() for c in str(x)) else np.nan
    )
    
    # Transformation logarithmique des vues
    df_test['log_trailer_views'] = np.log1p(df_test['trailer_views_clean'])
    
    # Catégorisation des vues
    trailer_views_median = df_test['trailer_views_clean'].median()
    df_test['high_trailer_views'] = (df_test['trailer_views_clean'] > trailer_views_median).astype(int)

# Traitement des récompenses et nominations
if 'awards' in df_test.columns:
    # Extraction du nombre de prix et nominations
    def extract_awards_count(awards_text):
        if pd.isna(awards_text):
            return 0, 0
        
        awards_text = str(awards_text).lower()
        
        # Extraire le nombre de prix
        prix_match = re.search(r'(\d+)\s+prix', awards_text)
        prix_count = int(prix_match.group(1)) if prix_match else 0
        
        # Extraire le nombre de nominations
        nom_match = re.search(r'(\d+)\s+nomination', awards_text)
        nom_count = int(nom_match.group(1)) if nom_match else 0
        
        return prix_count, nom_count
    
    # Extraire les prix et nominations avec une approche plus robuste
    awards_data = df_test['awards'].apply(extract_awards_count)
    prix_data = [item[0] for item in awards_data]
    nomination_data = [item[1] for item in awards_data]
    
    # Assigner les valeurs individuellement
    df_test['prix_count'] = prix_data
    df_test['nomination_count'] = nomination_data
    
    # Feature combinée (prix ont plus de poids)
    df_test['award_score'] = df_test['prix_count'] * 2 + df_test['nomination_count']
    
    # Indicateur de film primé
    df_test['is_awarded'] = (df_test['prix_count'] > 0).astype(int)
    
    # Interaction avec les prix (effet multiplicateur des récompenses sur les vues)
    if 'trailer_views_clean' in df_test.columns:
        df_test['trailer_views_x_awards'] = df_test['trailer_views_clean'] * df_test['prix_count']
        
        # Ratio prix/vues (efficacité de conversion des récompenses en vues)
        non_zero_views = df_test['trailer_views_clean'].replace(0, np.nan)
        df_test['awards_per_view'] = df_test['prix_count'] / non_zero_views
        
        if 'nomination_count' in df_test.columns:
            # Interaction avec les nominations
            df_test['trailer_views_x_nominations'] = df_test['trailer_views_clean'] * df_test['nomination_count']
        
        if 'award_score' in df_test.columns:
            # Interaction avec le score combiné awards/nominations
            df_test['trailer_views_x_award_score'] = df_test['trailer_views_clean'] * df_test['award_score']
            
            # Indicateur des films à haute visibilité et reconnaissance critique
            views_threshold = df_test['trailer_views_clean'].quantile(0.75)
            df_test['high_visibility_acclaimed'] = ((df_test['trailer_views_clean'] > views_threshold) & 
                                                 (df_test['award_score'] > 0)).astype(int)

# %% [markdown]
# Préparation de la Target

# %%
# Transformation logarithmique de la variable cible
if 'box_office_demarrage' in df_clean.columns:
    # Vérifier le type et convertir toutes les valeurs en numériques
    df_clean['box_office_demarrage'] = pd.to_numeric(df_clean['box_office_demarrage'], errors='coerce')
    
    # Remplacer les valeurs négatives par NaN (car log ne fonctionne pas sur les nombres négatifs)
    df_clean.loc[df_clean['box_office_demarrage'] < 0, 'box_office_demarrage'] = np.nan
    
    # Appliquer la transformation logarithmique
    df_clean['log_box_office_demarrage'] = np.log1p(df_clean['box_office_demarrage'])
    
    # Afficher des informations sur les transformations
    print(f"Valeurs nulles après conversion: {df_clean['box_office_demarrage'].isna().sum()}")
    print(f"Valeurs transformées en log: {df_clean['log_box_office_demarrage'].notna().sum()}")
# Out:
# Valeurs nulles après conversion: 7865
# Valeurs transformées en log: 66

# %%
# Transformation logarithmique de la variable cible
if 'box_office_demarrage' in df_test.columns:
    df_test['log_box_office_demarrage'] = np.log1p(df_test['box_office_demarrage'])

# %% [markdown]
# Sélection des features

# %%
features_selection = {
    # 1. Features de base (durée et info film)
    'base': [col for col in df_clean.columns if col in ['duree_minutes', 'duree', 'duree_film']],
    
    # 2. Features budgétaires
    'budget': [col for col in df_clean.columns 
               if 'budget' in col.lower() 
               and 'budget_x_' not in col],
    
    # 3. Marketing
    'marketing': [col for col in df_clean.columns if 'marketing' in col.lower()],
    
    # 4. Features temporelles
    'temporel': [
        col for col in df_clean.columns 
        if any(term in col for term in [
            'mois_sortie', 'annee_sortie', 'saison_sortie', 
            'vacances_scolaires', 'sortie_ete', 'sortie_fetes', 'post_covid'
        ]) or col.startswith('saison_sortie_') or col.startswith('mois_')
    ],
    
    # 5. Features de jour de sortie
    'jour_sortie': [
        col for col in df_clean.columns 
        if 'wednesday' in col.lower() or 'weekend' in col.lower() or 'mercredi' in col.lower()
    ],
    
    # 6. Genre principal
    'genre_principal': [col for col in df_clean.columns if col.startswith('genre_principale_')],
    
    # 7. Genres associés
    'genre_associe': [
        col for col in df_clean.columns 
        if col.startswith('genre_') and not col.startswith('genre_principale_')
        and not 'budget_x_genre' in col
    ],
    
    # 8. Interaction budget-genre
    'interaction': [col for col in df_clean.columns if 'budget_x_' in col],
    
    # 9. Distributeur
    'distributeur': [
        col for col in df_clean.columns 
        if col.startswith('distributor_') or col == 'is_major_studio'
    ],
    
    # 10. Origine et langue
    'origine': [col for col in df_clean.columns 
                if col in ['is_english', 'is_french', 'is_usa', 'is_europe']],
    
    # 11. Acteurs et franchise
    'acteurs': [col for col in df_clean.columns 
                if col in ['star_count', 'has_famous_actor', 'is_franchise']],
    
    # 12. Press rating (disponible avant sortie)
    'presse': [col for col in df_clean.columns if 'press_rating' in col.lower()],
    
    # 13. Trailer views
    'trailer': [col for col in df_clean.columns 
                if 'trailer_views' in col.lower() or 'log_trailer_views' in col.lower() 
                or 'high_trailer_views' in col.lower()],
    
    # 14. Awards/nominations (provenant de festivals avant sortie générale)
    'awards': [col for col in df_clean.columns 
               if 'award' in col.lower() or 'prix_count' in col.lower() 
               or 'nomination_count' in col.lower() or 'is_awarded' in col.lower()],
    
    # 15. Public cible
    'target_audience': [col for col in df_clean.columns 
                      if col in ['is_adult_only']]
}

features_to_exclude = [
    'box_office_france', 'fr_entry_week', 'us_entry_week', 'fr_entries', 
    'note_moyenne', 'viewer_critics_count', 'viewer_rating'
]

# Aplatir la liste de features
selected_features = []
for category, features in features_selection.items():
    # Filtrer uniquement les colonnes qui existent réellement et qui ne sont pas à exclure
    existing_features = [f for f in features if f in df_clean.columns 
                         and not any(exclude in f for exclude in features_to_exclude)]
    selected_features.extend(existing_features)
    print(f"{category}: {len(existing_features)} features")

# Éliminer les doublons
selected_features = list(set(selected_features))

print(f"\nNombre total de features sélectionnées: {len(selected_features)}")
# Out:
# base: 2 features
# budget: 6 features
# marketing: 3 features
# temporel: 12 features
# jour_sortie: 2 features
# genre_principal: 836 features
# genre_associe: 0 features
# interaction: 6 features
# distributeur: 12 features
# origine: 4 features
# acteurs: 2 features
# presse: 1 features
# trailer: 7 features
# awards: 8 features
# target_audience: 1 features
#
# Nombre total de features sélectionnées: 897

# %%
print(selected_features)
# Out:
# ['has_famous_actor', 'genre_principale_Adrien Brody | Owen Wilson | Bill Murray | Natalie Portman', 'is_awarded', 'genre_principale_Christian Bale | Tom Hardy | Anne Hathaway | Michael Caine | Marion Cotillard | Morgan Freeman | Joseph Gordon-Levitt | Gary Oldman | Aaron Eckhart | Cillian Murphy', 'genre_principale_Dwayne Johnson | Sean William Scott | Christopher Walken | Arnold Schwarzenegger', 'genre_principale_Kad Merad | Benoît Poelvoorde | Zabou Breitman | Léa Drucker | Denis Podalydès', 'distributor_warner', 'genre_principale_Robert Pattinson | Kristen Stewart | Dakota Fanning | Bryce Dallas Howard | Stephenie Meyer | Howard Shore', 'genre_principale_Cameron Diaz', 'genre_principale_Melvil Poupaud | Laure Calamy', 'genre_principale_Pio Marmaï | Camille Cottin', 'genre_principale_Elodie Bouchez | Gérard Depardieu | Romain Duris', 'distributor_paramount', 'genre_principale_Chris Tucker | Jackie Chan | Yvan Attal | Julie Depardieu', 'genre_principale_Yun-Fat Chow | Brian Tyler', 'genre_principale_Benoît Magimel', 'genre_principale_Mélanie Laurent | Ryan Reynolds', 'is_weekend_release', 'genre_principale_Yolande Moreau', 'genre_principale_Monica Bellucci | Jim Caviezel', 'genre_principale_Steve Carell | Gad Elmaleh | Jason Segel | Kristen Wiig', 'genre_principale_Michael Caine | Morgan Freeman | Matt Dillon | Christopher Lloyd', 'genre_principale_Helen Mirren | Clive Owen', 'trailer_views_x_nominations', 'genre_principale_Nicole Garcia', 'genre_principale_Philippe Torreton | Pascal Elbé', 'genre_principale_Leïla Bekhti | Elodie Bouchez | Adèle Exarchopoulos | Jean-Pierre Darroussin | Gilles Lellouche | Miou-Miou | Denis Podalydès | Alain Attal', 'genre_principale_François Civil', 'genre_principale_Russell Crowe | Cate Blanchett | Léa Seydoux | Luke Evans | Brian Grazer | Ridley Scott | Brian Helgeland', 'genre_principale_Gad Elmaleh | Gérard Depardieu | Manu Payet', 'genre_principale_Catherine Deneuve', 'genre_principale_Jason Statham | Jet Li | Brian Tyler', 'genre_principale_- Queen Latifah | Luc Besson', 'genre_principale_Leslie Nielsen', 'genre_principale_Jessica Alba | Robert De Niro | Steven Seagal', 'genre_principale_Mathieu Amalric', 'genre_principale_Josiane Balasko | Nathalie Baye | Catherine Deneuve | Vincent Elbaz', 'genre_principale_Roschdy Zem | Lorant Deutsch | Josiane Balasko | Gérard Jugnot | Pascal Elbé | Marina Foïs | Omar Sy', 'genre_principale_Jude Law | Natalie Portman | Rachel Weisz', 'genre_principale_Lorant Deutsch', 'genre_principale_Michael Fassbender | James McAvoy | Jessica Chastain | Jennifer Lawrence | Hans Zimmer', 'genre_principale_Toni Collette | Elle Fanning | Simon Pegg', 'genre_principale_Alec Baldwin | Steve Buscemi | Tobey Maguire | Hans Zimmer', 'genre_principale_Tea Leoni | Luke Wilson | Bill Pullman', 'genre_principale_Juliette Binoche', 'genre_principale_Dany Boon | Benoît Poelvoorde | François Damiens | Oliver Gourmet | Karin Viard | Jérôme Commandeur', 'genre_principale_Nicole Garcia | Gaspard Ulliel', 'genre_principale_Adam Driver | Camille Cottin | Salma Hayek | Jeremy Irons | Jared Leto | Al Pacino | Ridley Scott', 'genre_principale_Greg Kinnear', 'genre_principale_Kevin Hart | Alexandre Desplat', 'genre_principale_Matt Damon | Pedro Pascal', 'genre_principale_Manu Payet | Jérémy Renier', 'genre_principale_Reda Kateb', 'genre_principale_Jennifer Lawrence | Woody Harrelson | Philip Seymour Hoffman | Donald Sutherland | James Newton Howard', 'genre_principale_Aventure - Action', 'genre_principale_Tom Holland | Robert Pattinson | Brad Pitt', 'genre_principale_Gilles Lellouche | Karin Viard', 'genre_principale_François Berléand | Samuel Le Bihan | Oliver Gourmet | Lorant Deutsch', 'genre_principale_Guillaume Canet | Marion Cotillard', 'genre_principale_Pierre Arditi', 'genre_principale_Jet Li | Jason Statham', 'genre_principale_Patrick Bruel | Nathalie Baye | François Berléand', 'sortie_ete', 'genre_principale_Comédie dramatique', 'genre_principale_Alain Chabat | Mathilde Seigner  ...

# %% [markdown]
# Préparation des données pour la modélisation

# %%
# Préparer X et y
X = df_clean[selected_features].copy()
y = df_clean['box_office_demarrage'].copy()
y_log = df_clean['log_box_office_demarrage'].copy()

# 1. Vérifier et corriger les colonnes non numériques
for col in X.columns:
    # Vérifier si la colonne contient des valeurs non numériques
    if X[col].dtype == 'object':
        print(f"Colonne non numérique détectée: {col}")
        
        # Tentative de conversion
        try:
            X[col] = X[col].apply(lambda x: str(x).replace(' ', '') if isinstance(x, str) else x)
            X[col] = pd.to_numeric(X[col], errors='coerce')
            print(f"  → Conversion réussie pour {col}")
        except Exception as e:
            print(f"  → Erreur lors de la conversion: {e}")
            # Supprimer les colonnes qui ne peuvent pas être converties
            X = X.drop(columns=[col])
            print(f"  → Colonne {col} supprimée")

print(f"Nombre de colonnes après nettoyage: {X.shape[1]}")

# 2. Vérifier les valeurs manquantes avant imputation
print(f"Valeurs manquantes par colonne:")
missing_values = X.isna().sum()
print(missing_values[missing_values > 0])

# 3. Imputation avec gestion d'erreurs
try:
    imputer = SimpleImputer(strategy='median')
    X_imputed = imputer.fit_transform(X)
    print("Imputation réussie!")
except Exception as e:
    print(f"Erreur lors de l'imputation: {e}")
    # Stratégie alternative: utiliser la moyenne au lieu de la médiane
    try:
        print("Tentative avec la stratégie 'mean'...")
        imputer = SimpleImputer(strategy='mean')
        X_imputed = imputer.fit_transform(X)
        print("Imputation avec 'mean' réussie!")
    except Exception as e2:
        print(f"Erreur avec 'mean': {e2}")
        # Dernier recours: suppression des valeurs manquantes
        print("Suppression des lignes avec valeurs manquantes...")
        # Obtenez les indices des lignes sans valeurs manquantes
        complete_indices = X.dropna().index
        X = X.loc[complete_indices]
        y = y.loc[complete_indices]
        y_log = y_log.loc[complete_indices]
        X_imputed = X.values
        print(f"Données réduites à {len(X)} lignes")

# 4. Standardisation avec gestion d'erreurs
try:
    scaler = RobustScaler()
    X_scaled = scaler.fit_transform(X_imputed)
    print("Standardisation réussie!")
except Exception as e:
    print(f"Erreur lors de la standardisation: {e}")
    # Si la standardisation échoue, utilisez les données imputées sans standardisation
    X_scaled = X_imputed
    print("Utilisation des données imputées sans standardisation")

# 5. Vérifiez que X_scaled ne contient pas de NaN ou d'infini
if np.isnan(X_scaled).any() or np.isinf(X_scaled).any():
    print("Attention: X_scaled contient des NaN ou infini")
    # Remplacer les NaN et infini par 0
    X_scaled = np.nan_to_num(X_scaled)
    print("Les valeurs NaN et infini ont été remplacées par 0")

print(f"Dimensions finales de X_scaled: {X_scaled.shape}")

# 6. Train-test split
X_train, X_test, y_train_log, y_test_log = train_test_split(
    X_scaled, y_log, test_size=0.2, random_state=42
)

# Conserver également les valeurs y non logarithmiques pour l'évaluation
_, _, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)
# Out:
# Colonne non numérique détectée: duree_film
#   → Conversion réussie pour duree_film
# Colonne non numérique détectée: trailer_views
#   → Conversion réussie pour trailer_views
# Colonne non numérique détectée: duree_minutes
#   → Conversion réussie pour duree_minutes
# Colonne non numérique détectée: awards
#   → Conversion réussie pour awards
# Nombre de colonnes après nettoyage: 897
# Valeurs manquantes par colonne:
# trailer_views_x_nominations    7436
# trailer_views_x_award_score    7436
# log_total_budget               7925
# budget                         7925
# duree_film                     1455
# press_rating                   4005
# awards_per_view                7436
# estimated_marketing_budget     7925
# budget_x_genre_action          7925
# log_budget                     7925
# trailer_views                  7931
# mois_sortie                    2713
# estimated_total_budget         7925
# annee_sortie                   2713
# budget_x_sortie_fetes          7925
# vacances_scolaires             2713
# budget_x_genre_comédie         7925
# duree_minutes                  1455
# budget_x_sortie_ete            7925
# trailer_views_x_awards         7436
# budget_x_genre_animation       7925
# budget_x_genre_drame           7925
# trailer_views_clean            7436
# awards                         7931
# log_trailer_views              7436
# dtype: int64
# Imputation réussie!
# Standardisation réussie!
# Dimensions finales de X_scaled: (7931, 895)

# %% [markdown]
# Entrainement du modèle XGBoost

# %%
# Vérifier et nettoyer les valeurs problématiques dans y_train_log
print(f"NaN dans y_train_log: {np.isnan(y_train_log).sum()}")
print(f"Min: {y_train_log.min()}, Max: {y_train_log.max()}")

# Filtrer les entrées avec des valeurs NaN
valid_indices = ~np.isnan(y_train_log)
if valid_indices.sum() < len(y_train_log):
    print(f"Suppression de {len(y_train_log) - valid_indices.sum()} entrées avec valeurs NaN")
    X_train = X_train[valid_indices]
    y_train_log = y_train_log[valid_indices]
    y_train = y_train[valid_indices]
    
print(f"Nombre final d'entrées: {len(y_train_log)}")

# Entraînement du modèle XGBoost
print("Entraînement du modèle XGBoost...")
xgb_model = XGBRegressor(
    objective='reg:squarederror',
    n_estimators=200,
    learning_rate=0.05,
    max_depth=6,
    min_child_weight=3,
    subsample=0.8,
    colsample_bytree=0.8,
    gamma=0.1,
    reg_alpha=0.1,
    reg_lambda=1.0,
    random_state=42
)

xgb_model.fit(X_train, y_train_log)
# Out:
# NaN dans y_train_log: 6291
# Min: 1.3862943611198906, Max: 7.607381425639791
# Suppression de 6291 entrées avec valeurs NaN
# Nombre final d'entrées: 53
# Entraînement du modèle XGBoost...
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.1, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=3, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# Gridsearch

# %%
#GRIDSEARCH 1 
from sklearn.model_selection import GridSearchCV, KFold
import numpy as np
import time
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Définition de la fonction d'évaluation
def evaluate_model(model, X, y_log, y_original, model_name="Modèle"):
    """Évalue un modèle et affiche les métriques"""
    # Filtrer les valeurs NaN
    valid_indices = ~np.isnan(y_log) & ~np.isnan(y_original)
    if valid_indices.sum() < len(y_log):
        print(f"Suppression de {len(y_log) - valid_indices.sum()} entrées avec NaN")
        X = X[valid_indices]
        y_log = y_log[valid_indices]
        y_original = y_original[valid_indices]
    
    # Prédictions et conversion
    y_pred_log = model.predict(X)
    y_pred = np.expm1(y_pred_log)
    
    # Calcul des métriques
    r2 = r2_score(y_original, y_pred)
    rmse = np.sqrt(mean_squared_error(y_original, y_pred))
    mae = mean_absolute_error(y_original, y_pred)
    r2_log = r2_score(y_log, y_pred_log)
    
    # Affichage des résultats
    print(f"\nRésultats du modèle {model_name}:")
    print(f"R² = {r2:.4f}, R² (log) = {r2_log:.4f}")
    print(f"RMSE = {rmse:.2f}, MAE = {mae:.2f}")
    
    return {'r2': r2, 'rmse': rmse, 'r2_log': r2_log, 'y_pred': y_pred, 'mae': mae}

# Enregistrer le temps de début
start_time = time.time()

# Pour réduire le temps de calcul, utilisez une recherche par étapes
# D'abord, optimisez max_depth et learning_rate
param_grid_step1 = {
    'max_depth': [5, 6, 7, 8],
    'learning_rate': [0.03, 0.05, 0.08]
}

# Modèle XGBoost avec les autres paramètres comme dans votre modèle original
xgb_model_grid = XGBRegressor(
    objective='reg:squarederror',
    n_estimators=200,
    min_child_weight=3,
    subsample=0.8,
    colsample_bytree=0.8,
    gamma=0.1,
    reg_alpha=0.1,
    reg_lambda=1.0,
    random_state=42
)

# Configuration de la validation croisée
cv = KFold(n_splits=5, shuffle=True, random_state=42)

# Configuration du GridSearchCV
print("Étape 1: Optimisation de max_depth et learning_rate...")
grid_search_step1 = GridSearchCV(
    estimator=xgb_model_grid,
    param_grid=param_grid_step1,
    scoring='neg_mean_squared_error',
    cv=cv,
    n_jobs=-1,
    verbose=1
)

# Exécuter la recherche étape 1
grid_search_step1.fit(X_train, y_train_log, eval_set=[(X_train, y_train_log)])

# Récupérer les meilleurs paramètres de l'étape 1
best_params_step1 = grid_search_step1.best_params_
print(f"Meilleurs paramètres de l'étape 1: {best_params_step1}")

# Étape 2: Optimiser min_child_weight et gamma avec les meilleurs max_depth et learning_rate
param_grid_step2 = {
    'min_child_weight': [2, 3, 4],
    'gamma': [0.05, 0.1, 0.15]
}

# Créer un nouveau modèle avec les meilleurs paramètres de l'étape 1
xgb_model_grid2 = XGBRegressor(
    objective='reg:squarederror',
    n_estimators=200,
    max_depth=best_params_step1['max_depth'],
    learning_rate=best_params_step1['learning_rate'],
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0.1,
    reg_lambda=1.0,
    random_state=42
)

print("Étape 2: Optimisation de min_child_weight et gamma...")
grid_search_step2 = GridSearchCV(
    estimator=xgb_model_grid2,
    param_grid=param_grid_step2,
    scoring='neg_mean_squared_error',
    cv=cv,
    n_jobs=-1,
    verbose=1
)

# Exécuter la recherche étape 2
grid_search_step2.fit(X_train, y_train_log, eval_set=[(X_train, y_train_log)])

# Récupérer les meilleurs paramètres de l'étape 2
best_params_step2 = grid_search_step2.best_params_
print(f"Meilleurs paramètres de l'étape 2: {best_params_step2}")

# Étape 3: Optimiser subsample et colsample_bytree
param_grid_step3 = {
    'subsample': [0.7, 0.8, 0.9],
    'colsample_bytree': [0.7, 0.8, 0.9]
}

# Créer un nouveau modèle avec les meilleurs paramètres des étapes 1 et 2
xgb_model_grid3 = XGBRegressor(
    objective='reg:squarederror',
    n_estimators=200,
    max_depth=best_params_step1['max_depth'],
    learning_rate=best_params_step1['learning_rate'],
    min_child_weight=best_params_step2['min_child_weight'],
    gamma=best_params_step2['gamma'],
    reg_alpha=0.1,
    reg_lambda=1.0,
    random_state=42
)

print("Étape 3: Optimisation de subsample et colsample_bytree...")
grid_search_step3 = GridSearchCV(
    estimator=xgb_model_grid3,
    param_grid=param_grid_step3,
    scoring='neg_mean_squared_error',
    cv=cv,
    n_jobs=-1,
    verbose=1
)

# Exécuter la recherche étape 3
grid_search_step3.fit(X_train, y_train_log, eval_set=[(X_train, y_train_log)])

# Récupérer les meilleurs paramètres de l'étape 3
best_params_step3 = grid_search_step3.best_params_
print(f"Meilleurs paramètres de l'étape 3: {best_params_step3}")

# Créer le modèle final avec tous les meilleurs paramètres
final_params = {**best_params_step1, **best_params_step2, **best_params_step3}
print("\nMeilleurs paramètres combinés:")
for param, value in final_params.items():
    print(f"  {param}: {value}")

# Entraîner le modèle final
final_model = XGBRegressor(
    objective='reg:squarederror',
    n_estimators=200,
    **final_params,
    reg_alpha=0.1,
    reg_lambda=1.0,
    random_state=42
)

print("\nEntraînement du modèle final avec les meilleurs paramètres...")
final_model.fit(X_train, y_train_log, eval_set=[(X_train, y_train_log)])

# Afficher le temps total d'exécution
end_time = time.time()
print(f"Temps total de l'optimisation: {(end_time - start_time)/60:.2f} minutes")

# Évaluer d'abord le modèle original
original_model = xgb_model  # Votre modèle XGBoost original déjà entraîné
original_results = evaluate_model(original_model, X_test, y_test_log, y_test, "XGBoost Original")

# Évaluation du modèle final
final_results = evaluate_model(final_model, X_test, y_test_log, y_test, "XGBoost Final")

# Comparaison avec le modèle original
print("\n===== COMPARAISON DES MODÈLES =====")
print(f"R² Original: {original_results['r2']:.4f}, R² Optimisé: {final_results['r2']:.4f}")
improvement_r2 = ((final_results['r2'] - original_results['r2']) / abs(original_results['r2'])) * 100
print(f"Amélioration R²: {improvement_r2:.2f}%")

print(f"RMSE Original: {original_results['rmse']:.2f}, RMSE Optimisé: {final_results['rmse']:.2f}")
improvement_rmse = ((original_results['rmse'] - final_results['rmse']) / original_results['rmse']) * 100
print(f"Réduction RMSE: {improvement_rmse:.2f}%")
# Out:
# Étape 1: Optimisation de max_depth et learning_rate...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [0]	validation_0-rmse:1.08904
# [1]	validation_0-rmse:1.07558
# [2]	validation_0-rmse:1.06702
# [3]	validation_0-rmse:1.05046
# [4]	validation_0-rmse:1.03629
# [5]	validation_0-rmse:1.02686
# [6]	validation_0-rmse:1.01974
# [7]	validation_0-rmse:1.01263
# [8]	validation_0-rmse:1.00944
# [9]	validation_0-rmse:1.00276
# [10]	validation_0-rmse:0.99042
# [11]	validation_0-rmse:0.98156
# [12]	validation_0-rmse:0.97343
# [13]	validation_0-rmse:0.97019
# [14]	validation_0-rmse:0.96582
# [15]	validation_0-rmse:0.96005
# [0]	validation_0-rmse:1.09201
# [16]	validation_0-rmse:0.95119
# [1]	validation_0-rmse:1.08547
# [17]	validation_0-rmse:0.94535
# [2]	validation_0-rmse:1.08198
# [18]	validation_0-rmse:0.93726
# [3]	validation_0-rmse:1.07113
# [19]	validation_0-rmse:0.93134
# [4]	validation_0-rmse:1.06486
# [20]	validation_0-rmse:0.92452
# [5]	validation_0-rmse:1.05612
# [21]	validation_0-rmse:0.91877
# [6]	validation_0-rmse:1.05311
# [22]	validation_0-rmse:0.91106
# [7]	validation_0-rmse:1.04476
# [23]	validation_0-rmse:0.90309
# [8]	validation_0-rmse:1.03467
# [24]	validation_0-rmse:0.89713[9]	validation_0-rmse:1.02723
#
# [10]	validation_0-rmse:1.01925[25]	validation_0-rmse:0.88887
#
# [26]	validation_0-rmse:0.88065
# [11]	validation_0-rmse:1.01589
# [0]	validation_0-rmse:1.09201
# [27]	validation_0-rmse:0.87710
# [12]	validation_0-rmse:1.00919
# [1]	validation_0-rmse:1.08547[28]	validation_0-rmse:0.87331
#
# [13]	validation_0-rmse:1.00220
# [2]	validation_0-rmse:1.08197
# [29]	validation_0-rmse:0.86804
# [14]	validation_0-rmse:0.99556
# [3]	validation_0-rmse:1.07111
# [30]	validation_0-rmse:0.86133
# [15]	validation_0-rmse:0.99226
# [31]	validation_0-rmse:0.85623
# [16]	validation_0-rmse:0.98535
# [32]	validation_0-rmse:0.84991
# [17]	validation_0-rmse:0.98404
# [33]	validation_0-rmse:0.84721
# [18]	validation_0-rmse:0.98203
# [4]	validation_0-rmse:1.06484
# [34]	validation_0-rmse:0.84449
# [19]	validation_0-rmse:0.97687
# [35]	validation_0-rmse:0.83885[5]	validation_0-rmse:1.05607
# [20]	validation_0-rmse:0.96964
#
# [21]	validation_0-rmse:0.96535[36]	validation_0-rmse:0.83564
#
# [6]	validation_0-rmse:1.05305
# [37]	validation_0-rmse:0.83154
# [22]	validation_0-rmse:0.96020
# [7]	validation_0-rmse:1.04470
# [38]	validation_0-rmse:0.82834
# [23]	validation_0-rmse:0.95549
# [8]	validation_0-rmse:1.03462
# [39]	validation_0-rmse:0.82335
# [24]	validation_0-rmse:0.94979
# [40]	validation_0-rmse:0.82025
# [9]	validation_0-rmse:1.02717
# [25]	validation_0-rmse:0.94535
# [41]	validation_0-rmse:0.81648
# [26]	validation_0-rmse:0.94413
# [10]	validation_0-rmse:1.01925
# [42]	validation_0-rmse:0.81150
# [27]	validation_0-rmse:0.93825
# [11]	validation_0-rmse:1.01575
# [43]	validation_0-rmse:0.80615
# [28]	validation_0-rmse:0.93391
# [0]	validation_0-rmse:1.08904
# [12]	validation_0-rmse:1.00904
# [44]	validation_0-rmse:0.80457
# [29]	validation_0-rmse:0.93146
# [13]	validation_0-rmse:1.00226
# [1]	validation_0-rmse:1.07558
# [45]	validation_0-rmse:0.80232
# [30]	validation_0-rmse:0.92617
# [46]	validation_0-rmse:0.79618[2]	validation_0-rmse:1.06702
# [14]	validation_0-rmse:0.99556
# [31]	validation_0-rmse:0.91906
#
# [47]	validation_0-rmse:0.79459
# [3]	validation_0-rmse:1.05046
# [32]	validation_0-rmse:0.91454
# [15]	validation_0-rmse:0.99226
# [33]	validation_0-rmse:0.91209[4]	validation_0-rmse:1.03629
#
# [16]	validation_0-rmse:0.98534
# [5]	validation_0-rmse:1.02713[34]	validation_0-rmse:0.91002
# [48]	validation_0-rmse:0.79341
#
# [17]	validation_0-rmse:0.98397
# [35]	validation_0-rmse:0.90630[49]	validation_0-rmse:0.79065
#
# [6]	validation_0-rmse:1.02001
# [18]	validation_0-rmse:0.98198
# [36]	validation_0-rmse:0.90288
# [50]	validation_0-rmse:0.78940
# [7]	validation_0-rmse:1.01287
# [51]	validation_0-rmse:0.78622
# [37]	validation_0-rmse:0.90106[8]	validation_0-rmse:1.00974
#
# [19]	validation_0-rmse:0.97680
# [9]	validation_0-rmse:1.00303[38]	validation_0-rmse:0.89792
# [52]	validation_0-rmse:0.78140
#
# [53]	validation_0-rmse:0.77602
# [20]	validation_0-rmse:0.96955[39]	validation_0-rmse:0.89362
#
# [10]	validation_0-rmse:0.99066
# [54]	validation_0-rmse:0.77392
# [21]	validation_0-rmse:0.96498[40]	validation_0-rmse:0.88957
# [11]	validation_0-rmse:0.98421
#
# [55]	validation_0-rmse:0.77061
# [41]	validation_0-rmse:0.88879
# [12]	validation_0-rmse:0.97606
# [22]	validation_0-rmse:0.95985
# [56]	validation_0-rmse:0.76655
# [42]	validation_0-rmse:0.88557
# [13]	validation_0-rmse:0.97280
# [23]	validation_0-rmse:0.95512
# [57]	validation_0-rmse:0.76287
# [43]	validation_0-rmse:0.88046
# [14]	validation_0-rmse:0.96840
# [24]	validation_0-rmse:0.94943
# [58]	validation_0-rmse:0.75965
# [44]	validation_0-rmse:0.87682
# [15]	validation_0-rmse:0.96282
# [25]	validation_0-rmse:0.94502
# [45]	validation_0-rmse:0.87385
# [59]	validation_0-rmse:0.75755
# [16]	validation_0-rmse:0.95393
# [26]	validation_0-rmse:0.94381[46]	validation_0-rmse:0.87098
#
# [60]	validation_0-rmse:0.75437
# [17]	validation_0-rmse:0.94794[47]	validation_0-rmse:0.86959
#
# [27]	validation_0-rmse:0.93792
# [61]	validation_0-rmse:0.75263
# [48]	validation_0-rmse:0.86849[28]	validation_0-rmse:0.93358
# [18]	validation_0-rmse:0.93990
#
# [62]	validation_0-rmse:0.75042
# [19]	validation_0-rmse:0.93394
# [49]	validation_0-rmse:0.86763
# [29]	validation_0-rmse:0.93115
# [63]	validation_0-rmse:0.74476
# [20]	validation_0-rmse:0.92727
# [50]	validation_0-rmse:0.86478
# [30]	validation_0-rmse:0.92596
# [64]	validation_0-rmse:0.74003
# [51]	validation_0-rmse:0.86181
# [31]	validation_0-rmse:0.91858
# [65]	validation_0-rmse:0.73498
# [52]	validation_0-rmse:0.85862
# [32]	validation_0-rmse:0.91408
# [53]	validation_0-rmse:0.85870[66]	validation_0-rmse:0.73163
#
# [33]	validation_0-rmse:0.91164
# [67]	validation_0-rmse:0.72854[54]	validation_0-rmse:0.85640
#
# [21]	validation_0-rmse:0.92146
# [34]	validation_0-rmse:0.90981
# [55]	validation_0-rmse:0.85493
# [68]	validation_0-rmse:0.72368
# [22]	validation_0-rmse:0.91366
# [35]	validation_0-rmse:0.90611
# [56]	validation_0-rmse:0.85283
# [69]	validation_0-rmse:0.72091
# [23]	validation_0-rmse:0.90560
# [36]	validation_0-rmse:0.90270
# [57]	validation_0-rmse:0.85072
# [24]	validation_0-rmse:0.89959
# [37]	validation_0-rmse:0.90120
# [58]	validation_0-rmse:0.84850
# [25]	validation_0-rmse:0.89125
# [38]	validation_0-rmse:0.89812
# [59]	validation_0-rmse:0.84616
# [70]	validation_0-rmse:0.71740
# [26]	validation_0-rmse:0.88295
# [39]	validation_0-rmse:0.89383
# [60]	validation_0-rmse:0.84339
# [71]	validation_0-rmse:0.71533
# [27]	validation_0-rmse:0.87936
# [40]	validation_0-rmse:0.88977
# [61]	validation_0-rmse:0.84362
# [72]	validation_0-rmse:0.71385[28]	validation_0-rmse:0.87554
#
# [41]	validation_0-rmse:0.88903
# [62]	validation_0-rmse:0.84146[29]	validation_0-rmse:0.87042
#
# [42]	validation_0-rmse:0.88579
# [30]	validation_0-rmse:0.86362
# [63]	validation_0-rmse:0.83864
# [73]	validation_0-rmse:0.71201
# [31]	validation_0-rmse:0.85848
# [64]	validation_0-rmse:0.83701
# [43]	validation_0-rmse:0.88069
# [74]	validation_0-rmse:0.71017
# [65]	validation_0-rmse:0.83526
# [44]	validation_0-rmse:0.87708
# [32]	validation_0-rmse:0.85213[66]	validation_0-rmse:0.83184
# [75]	validation_0-rmse:0.70792
#
# [45]	validation_0-rmse:0.87456
# [67]	validation_0-rmse:0.83007
# [76]	validation_0-rmse:0.70640
# [33]	validation_0-rmse:0.84941
# [46]	validation_0-rmse:0.87174
# [68]	validation_0-rmse:0.82841[77]	validation_0-rmse:0.70270
#
# [47]	validation_0-rmse:0.87035[34]	validation_0-rmse:0.84665
#
# [78]	validation_0-rmse:0.69928[69]	validation_0-rmse:0.82894
# [35]	validation_0-rmse:0.84087
#
# [48]	validation_0-rmse:0.86922
# [70]	validation_0-rmse:0.82634[36]	validation_0-rmse:0.83766
#
# [79]	validation_0-rmse:0.69442
# [49]	validation_0-rmse:0.86840
# [37]	validation_0-rmse:0.83354
# [71]	validation_0-rmse:0.82368
# [80]	validation_0-rmse:0.69350
# [50]	validation_0-rmse:0.86557
# [38]	validation_0-rmse:0.83021[72]	validation_0-rmse:0.82208
#
# [81]	validation_0-rmse:0.69057
# [51]	validation_0-rmse:0.86261
# [73]	validation_0-rmse:0.81798
# [82]	validation_0-rmse:0.68747
# [74]	validation_0-rmse:0.81928
# [52]	validation_0-rmse:0.85939
# [53]	validation_0-rmse:0.85947[83]	validation_0-rmse:0.68647
#
# [75]	validation_0-rmse:0.81748
# [84]	validation_0-rmse:0.68269
# [54]	validation_0-rmse:0.85681
# [76]	validation_0-rmse:0.81781
# [55]	validation_0-rmse:0.85537
# [77]	validation_0-rmse:0.81728[85]	validation_0-rmse:0.68092
#
# [0]	validation_0-rmse:1.08567
# [78]	validation_0-rmse:0.81559[56]	validation_0-rmse:0.85328
#
# [39]	validation_0-rmse:0.82518
# [79]	validation_0-rmse:0.81291
# [57]	validation_0-rmse:0.85119
# [1]	validation_0-rmse:1.07484
# [58]	validation_0-rmse:0.84896[80]	validation_0-rmse:0.81165
#
# [2]	validation_0-rmse:1.06484
# [81]	validation_0-rmse:0.80727
# [59]	validation_0-rmse:0.84664
# [40]	validation_0-rmse:0.82207
# [3]	validation_0-rmse:1.05147
# [82]	validation_0-rmse:0.80435
# [41]	validation_0-rmse:0.81827
# [86]	validation_0-rmse:0.67950
# [83]	validation_0-rmse:0.80372
# [4]	validation_0-rmse:1.04135
# [60]	validation_0-rmse:0.84380
# [42]	validation_0-rmse:0.81363
# [87]	validation_0-rmse:0.67495
# [61]	validation_0-rmse:0.84404[84]	validation_0-rmse:0.80062
#
# [43]	validation_0-rmse:0.80824
# [5]	validation_0-rmse:1.03165[88]	validation_0-rmse:0.67109
#
# [85]	validation_0-rmse:0.80002
# [62]	validation_0-rmse:0.84202
# [44]	validation_0-rmse:0.80659
# [86]	validation_0-rmse:0.79968
# [89]	validation_0-rmse:0.66526
# [63]	validation_0-rmse:0.83922
# [45]	validation_0-rmse:0.80431
# [6]	validation_0-rmse:1.02197
# [64]	validation_0-rmse:0.83765[87]	validation_0-rmse:0.79882
#
# [7]	validation_0-rmse:1.01460[46]	validation_0-rmse:0.79820
#
# [90]	validation_0-rmse:0.66111
# [88]	validation_0-rmse:0.79786
# [47]	validation_0-rmse:0.79660
# [65]	validation_0-rmse:0.83592
# [8]	validation_0-rmse:1.00845
# [89]	validation_0-rmse:0.79768
# [91]	validation_0-rmse:0.65994
# [48]	validation_0-rmse:0.79542
# [66]	validation_0-rmse:0.83256
# [9]	validation_0-rmse:0.99970
# [49]	validation_0-rmse:0.79266[92]	validation_0-rmse:0.65843
# [90]	validation_0-rmse:0.79192
#
# [67]	validation_0-rmse:0.83080
# [0]	validation_0-rmse:1.09316
# [91]	validation_0-rmse:0.79139[93]	validation_0-rmse:0.65811
#
# [50]	validation_0-rmse:0.79121
# [68]	validation_0-rmse:0.82917
# [1]	validation_0-rmse:1.08636
# [10]	validation_0-rmse:0.98695[92]	validation_0-rmse:0.78887
# [94]	validation_0-rmse:0.65720
#
# [51]	validation_0-rmse:0.78820
# [69]	validation_0-rmse:0.82972
# [2]	validation_0-rmse:1.07721[93]	validation_0-rmse:0.78460
#
# [52]	validation_0-rmse:0.78371
# [94]	validation_0-rmse:0.78377[70]	validation_0-rmse:0.82713
#
# [3]	validation_0-rmse:1.06797[11]	validation_0-rmse:0.98132
#
# [53]	validation_0-rmse:0.77828
# [95]	validation_0-rmse:0.65699
# [71]	validation_0-rmse:0.82447
# [95]	validation_0-rmse:0.78224
# [4]	validation_0-rmse:1.06150
# [12]	validation_0-rmse:0.97313
# [96]	validation_0-rmse:0.65708
# [54]	validation_0-rmse:0.77619
# [72]	validation_0-rmse:0.82288
# [96]	validation_0-rmse:0.78023
# [5]	validation_0-rmse:1.05619
# [13]	validation_0-rmse:0.96560
# [55]	validation_0-rmse:0.77264
# [97]	validation_0-rmse:0.77980
# [73]	validation_0-rmse:0.81878
# [6]	validation_0-rmse:1.05054
# [97]	validation_0-rmse:0.65234
# [14]	validation_0-rmse:0.95816
# [56]	validation_0-rmse:0.76846
# [98]	validation_0-rmse:0.77439
# [74]	validation_0-rmse:0.82009
# [7]	validation_0-rmse:1.04886
# [98]	validation_0-rmse:0.65019
# [15]	validation_0-rmse:0.95239
# [57]	validation_0-rmse:0.76466
# [99]	validation_0-rmse:0.77177
# [75]	validation_0-rmse:0.81839
# [8]	validation_0-rmse:1.04828
# [16]	validation_0-rmse:0.94340
# [99]	validation_0-rmse:0.64453
# [58]	validation_0-rmse:0.76177[100]	validation_0-rmse:0.77213
#
# [76]	validation_0-rmse:0.81905
# [9]	validation_0-rmse:1.04253
# [101]	validation_0-rmse:0.76995[59]	validation_0-rmse:0.75986
# [100]	validation_0-rmse:0.64087
#
# [77]	validation_0-rmse:0.81855
# [17]	validation_0-rmse:0.93619[10]	validation_0-rmse:1.03402
# [101]	validation_0-rmse:0.63928
#
# [102]	validation_0-rmse:0.76558
# [78]	validation_0-rmse:0.81685
# [103]	validation_0-rmse:0.76468[102]	validation_0-rmse:0.63334
#
# [79]	validation_0-rmse:0.81416
# [11]	validation_0-rmse:1.02462[18]	validation_0-rmse:0.92570
#
# [104]	validation_0-rmse:0.76318
# [12]	validation_0-rmse:1.01487
# [19]	validation_0-rmse:0.92043[105]	validation_0-rmse:0.76004[60]	validation_0-rmse:0.75658
#
# [103]	validation_0-rmse:0.62982
#
# [13]	validation_0-rmse:1.01343
# [106]	validation_0-rmse:0.75439
# [61]	validation_0-rmse:0.75525
# [104]	validation_0-rmse:0.62788
# [80]	validation_0-rmse:0.81292
# [20]	validation_0-rmse:0.91301
# [14]	validation_0-rmse:1.00489
# [107]	validation_0-rmse:0.75168
# [62]	validation_0-rmse:0.75059
# [105]	validation_0-rmse:0.62417
# [108]	validation_0-rmse:0.75198
# [21]	validation_0-rmse:0.90639[15]	validation_0-rmse:1.00520
#
# [63]	validation_0-rmse:0.74528
# [106]	validation_0-rmse:0.62047
# [109]	validation_0-rmse:0.75042
# [16]	validation_0-rmse:1.00555
# [110]	validation_0-rmse:0.74886[64]	validation_0-rmse:0.74488
#
# [107]	validation_0-rmse:0.62021
# [81]	validation_0-rmse:0.80854
# [17]	validation_0-rmse:1.00024[22]	validation_0-rmse:0.89988
#
# [108]	validation_0-rmse:0.62086[111]	validation_0-rmse:0.74904
#
# [65]	validation_0-rmse:0.73922
# [82]	validation_0-rmse:0.80562
# [18]	validation_0-rmse:0.99069
# [109]	validation_0-rmse:0.62020[112]	validation_0-rmse:0.74646
#
# [83]	validation_0-rmse:0.80500
# [113]	validation_0-rmse:0.74691[19]	validation_0-rmse:0.98999
# [23]	validation_0-rmse:0.89074
# [66]	validation_0-rmse:0.73483
#
# [84]	validation_0-rmse:0.80156
# [20]	validation_0-rmse:0.98370
# [110]	validation_0-rmse:0.61752
# [67]	validation_0-rmse:0.73232
# [24]	validation_0-rmse:0.87971
# [114]	validation_0-rmse:0.74438
# [21]	validation_0-rmse:0.98510
# [85]	validation_0-rmse:0.80097
# [25]	validation_0-rmse:0.87218
# [68]	validation_0-rmse:0.72748
# [115]	validation_0-rmse:0.74253
# [86]	validation_0-rmse:0.80064
# [22]	validation_0-rmse:0.98006
# [69]	validation_0-rmse:0.72475[116]	validation_0-rmse:0.74289
# [111]	validation_0-rmse:0.61618
#
# [26]	validation_0-rmse:0.86720
# [23]	validation_0-rmse:0.97203
# [112]	validation_0-rmse:0.61573[70]	validation_0-rmse:0.72148
# [117]	validation_0-rmse:0.74016
#
# [27]	validation_0-rmse:0.86222[87]	validation_0-rmse:0.79979
#
# [24]	validation_0-rmse:0.97248[71]	validation_0-rmse:0.71743
#
# [118]	validation_0-rmse:0.73829
# [113]	validation_0-rmse:0.61221
# [88]	validation_0-rmse:0.79881[28]	validation_0-rmse:0.85658
# [72]	validation_0-rmse:0.71611
# [119]	validation_0-rmse:0.73687
# [25]	validation_0-rmse:0.96509
#
# [114]	validation_0-rmse:0.60983
# [120]	validation_0-rmse:0.73330[73]	validation_0-rmse:0.71383
# [29]	validation_0-rmse:0.84818
# [26]	validation_0-rmse:0.96097
#
# [89]	validation_0-rmse:0.79866
# [115]	validation_0-rmse:0.60803
# [30]	validation_0-rmse:0.84369[74]	validation_0-rmse:0.71258
#
# [27]	validation_0-rmse:0.95518
# [121]	validation_0-rmse:0.73105
# [90]	validation_0-rmse:0.79292
# [116]	validation_0-rmse:0.60469
# [75]	validation_0-rmse:0.71045
# [122]	validation_0-rmse:0.73177
# [28]	validation_0-rmse:0.94756
# [31]	validation_0-rmse:0.83712
# [91]	validation_0-rmse:0.79240
# [117]	validation_0-rmse:0.60270
# [123]	validation_0-rmse:0.73219
# [76]	validation_0-rmse:0.70895
# [29]	validation_0-rmse:0.94357
# [32]	validation_0-rmse:0.82874
# [92]	validation_0-rmse:0.78987
# [124]	validation_0-rmse:0.73047
# [118]	validation_0-rmse:0.59973
# [77]	validation_0-rmse:0.70526
# [30]	validation_0-rmse:0.93530
# [93]	validation_0-rmse:0.78559[33]	validation_0-rmse:0.82729
#
# [119]	validation_0-rmse:0.59850[78]	validation_0-rmse:0.70126
# [31]	validation_0-rmse:0.92605[94]	validation_0-rmse:0.78479
# [34]	validation_0-rmse:0.82508
#
#
# [125]	validation_0-rmse:0.72872
# [35]	validation_0-rmse:0.82153
# [79]	validation_0-rmse:0.69622
# [32]	validation_0-rmse:0.92452[126]	validation_0-rmse:0.72773
#
# [95]	validation_0-rmse:0.78328
# [120]	validation_0-rmse:0.59705
# [36]	validation_0-rmse:0.81701
# [127]	validation_0-rmse:0.72497
# [80]	validation_0-rmse:0.69529
# [96]	validation_0-rmse:0.78133
# [33]	validation_0-rmse:0.92390
# [121]	validation_0-rmse:0.59490
# [128]	validation_0-rmse:0.72363
# [34]	validation_0-rmse:0.92361
# [97]	validation_0-rmse:0.78090
# [37]	validation_0-rmse:0.81137[81]	validation_0-rmse:0.69277
#
# [122]	validation_0-rmse:0.59308
# [129]	validation_0-rmse:0.72477
# [38]	validation_0-rmse:0.80723
# [98]	validation_0-rmse:0.77549
# [35]	validation_0-rmse:0.91507
# [123]	validation_0-rmse:0.59275
# [130]	validation_0-rmse:0.72188
# [39]	validation_0-rmse:0.80203
# [124]	validation_0-rmse:0.59212
# [99]	validation_0-rmse:0.77288
# [131]	validation_0-rmse:0.72059
# [36]	validation_0-rmse:0.90987
# [100]	validation_0-rmse:0.77324[132]	validation_0-rmse:0.71924
#
# [37]	validation_0-rmse:0.90699[82]	validation_0-rmse:0.68968
# [125]	validation_0-rmse:0.59077
#
# [133]	validation_0-rmse:0.71930[38]	validation_0-rmse:0.89956
# [126]	validation_0-rmse:0.58847
#
# [83]	validation_0-rmse:0.68806
# [39]	validation_0-rmse:0.89231
# [134]	validation_0-rmse:0.71665[101]	validation_0-rmse:0.77105
#
# [40]	validation_0-rmse:0.79828
# [84]	validation_0-rmse:0.68424[135]	validation_0-rmse:0.71704
# [102]	validation_0-rmse:0.76667
# [40]	validation_0-rmse:0.88577[127]	validation_0-rmse:0.58582
#
#
# [136]	validation_0-rmse:0.71534
# [85]	validation_0-rmse:0.68264
# [41]	validation_0-rmse:0.88155[103]	validation_0-rmse:0.76581
#
# [41]	validation_0-rmse:0.79317
# [128]	validation_0-rmse:0.58077
# [137]	validation_0-rmse:0.71227
# [104]	validation_0-rmse:0.76432
# [86]	validation_0-rmse:0.68000
# [42]	validation_0-rmse:0.87542
# [42]	validation_0-rmse:0.79005
# [129]	validation_0-rmse:0.57769
# [138]	validation_0-rmse:0.70962
# [105]	validation_0-rmse:0.76119
# [87]	validation_0-rmse:0.67566
# [43]	validation_0-rmse:0.78600
# [43]	validation_0-rmse:0.86724
# [130]	validation_0-rmse:0.57653
# [139]	validation_0-rmse:0.71015
# [106]	validation_0-rmse:0.75556
# [44]	validation_0-rmse:0.78254
# [88]	validation_0-rmse:0.67189
# [44]	validation_0-rmse:0.86127
# [140]	validation_0-rmse:0.70866
# [131]	validation_0-rmse:0.57619
# [107]	validation_0-rmse:0.75286
# [45]	validation_0-rmse:0.77664
# [89]	validation_0-rmse:0.66609
# [45]	validation_0-rmse:0.85504
# [141]	validation_0-rmse:0.70683
# [108]	validation_0-rmse:0.75317
# [90]	validation_0-rmse:0.66246[142]	validation_0-rmse:0.70637
# [46]	validation_0-rmse:0.77600
# [46]	validation_0-rmse:0.85520
#
# [109]	validation_0-rmse:0.75157
# [132]	validation_0-rmse:0.57510[47]	validation_0-rmse:0.85254
# [47]	validation_0-rmse:0.77358
#
# [91]	validation_0-rmse:0.66019
# [110]	validation_0-rmse:0.75001
# [48]	validation_0-rmse:0.77072[48]	validation_0-rmse:0.85188
#
# [92]	validation_0-rmse:0.65865
# [111]	validation_0-rmse:0.75008[133]	validation_0-rmse:0.57373
#
# [143]	validation_0-rmse:0.70265
# [49]	validation_0-rmse:0.84626
# [49]	validation_0-rmse:0.76558
# [93]	validation_0-rmse:0.65842
# [134]	validation_0-rmse:0.57297
# [112]	validation_0-rmse:0.74749
# [144]	validation_0-rmse:0.70044
# [50]	validation_0-rmse:0.84402
# [50]	validation_0-rmse:0.76335
# [94]	validation_0-rmse:0.65839
# [145]	validation_0-rmse:0.69920
# [113]	validation_0-rmse:0.74795
# [135]	validation_0-rmse:0.56992
# [51]	validation_0-rmse:0.76029
# [51]	validation_0-rmse:0.84061
# [95]	validation_0-rmse:0.65819
# [114]	validation_0-rmse:0.74516
# [146]	validation_0-rmse:0.69760
# [136]	validation_0-rmse:0.56896
# [52]	validation_0-rmse:0.84172
# [96]	validation_0-rmse:0.65861[52]	validation_0-rmse:0.75366
#
# [147]	validation_0-rmse:0.69564
# [115]	validation_0-rmse:0.74333
# [137]	validation_0-rmse:0.56785
# [53]	validation_0-rmse:0.83907
# [97]	validation_0-rmse:0.65379[138]	validation_0-rmse:0.56774
#
# [116]	validation_0-rmse:0.74369[53]	validation_0-rmse:0.75111
#
# [148]	validation_0-rmse:0.69449[54]	validation_0-rmse:0.83562
#
# [98]	validation_0-rmse:0.65175[54]	validation_0-rmse:0.74869
# [139]	validation_0-rmse:0.56572
#
# [149]	validation_0-rmse:0.69576[117]	validation_0-rmse:0.74195
# [55]	validation_0-rmse:0.83123
#
# [55]	validation_0-rmse:0.74653[140]	validation_0-rmse:0.56419
#
# [99]	validation_0-rmse:0.64614
# [118]	validation_0-rmse:0.74007
# [56]	validation_0-rmse:0.82392
# [150]	validation_0-rmse:0.69655
# [141]	validation_0-rmse:0.56312
# [56]	validation_0-rmse:0.73863[100]	validation_0-rmse:0.64250
#
# [119]	validation_0-rmse:0.73870
# [57]	validation_0-rmse:0.81811
# [142]	validation_0-rmse:0.56176
# [151]	validation_0-rmse:0.69295
# [120]	validation_0-rmse:0.73515[101]	validation_0-rmse:0.64089[57]	validation_0-rmse:0.73048
#
#
# [143]	validation_0-rmse:0.56060
# [152]	validation_0-rmse:0.69124
# [58]	validation_0-rmse:0.81033
# [121]	validation_0-rmse:0.73287
# [58]	validation_0-rmse:0.72349
# [102]	validation_0-rmse:0.63471
# [144]	validation_0-rmse:0.55935
# [153]	validation_0-rmse:0.68729
# [122]	validation_0-rmse:0.73360[59]	validation_0-rmse:0.80605
#
# [59]	validation_0-rmse:0.71676[145]	validation_0-rmse:0.55879
#
# [123]	validation_0-rmse:0.73406[60]	validation_0-rmse:0.80137
#
# [146]	validation_0-rmse:0.55684
# [154]	validation_0-rmse:0.68528
# [60]	validation_0-rmse:0.71002
# [155]	validation_0-rmse:0.68583
# [124]	validation_0-rmse:0.73231
# [147]	validation_0-rmse:0.55622
# [61]	validation_0-rmse:0.79587
# [156]	validation_0-rmse:0.68496
# [148]	validation_0-rmse:0.55559
# [103]	validation_0-rmse:0.63116
# [125]	validation_0-rmse:0.73062
# [62]	validation_0-rmse:0.79612
# [149]	validation_0-rmse:0.55486
# [157]	validation_0-rmse:0.68132
# [126]	validation_0-rmse:0.72779
# [63]	validation_0-rmse:0.79759
# [61]	validation_0-rmse:0.70708
# [104]	validation_0-rmse:0.62719
# [158]	validation_0-rmse:0.68190[150]	validation_0-rmse:0.55214
#
# [127]	validation_0-rmse:0.72514
# [64]	validation_0-rmse:0.79377
# [105]	validation_0-rmse:0.62373
# [62]	validation_0-rmse:0.70151
# [151]	validation_0-rmse:0.55179
# [159]	validation_0-rmse:0.68088
# [65]	validation_0-rmse:0.78960
# [63]	validation_0-rmse:0.69829[160]	validation_0-rmse:0.68108[128]	validation_0-rmse:0.72383
#
# [106]	validation_0-rmse:0.62003
# [152]	validation_0-rmse:0.55120[66]	validation_0-rmse:0.78969
#
# [107]	validation_0-rmse:0.61975
# [129]	validation_0-rmse:0.72497
# [161]	validation_0-rmse:0.68018
# [67]	validation_0-rmse:0.78264
# [108]	validation_0-rmse:0.62040
#
# [153]	validation_0-rmse:0.55058
# [162]	validation_0-rmse:0.67945[130]	validation_0-rmse:0.72316
#
# [68]	validation_0-rmse:0.77778
# [109]	validation_0-rmse:0.61980
# [131]	validation_0-rmse:0.72186[64]	validation_0-rmse:0.69266
# [154]	validation_0-rmse:0.55047
#
# [163]	validation_0-rmse:0.67921
# [69]	validation_0-rmse:0.77348
# [110]	validation_0-rmse:0.61713
# [155]	validation_0-rmse:0.55047[65]	validation_0-rmse:0.68921
# [132]	validation_0-rmse:0.72054
#
# [164]	validation_0-rmse:0.67656[111]	validation_0-rmse:0.61571
#
# [70]	validation_0-rmse:0.77458
# [133]	validation_0-rmse:0.72065
# [66]	validation_0-rmse:0.68394
# [156]	validation_0-rmse:0.54967
# [165]	validation_0-rmse:0.67712
# [112]	validation_0-rmse:0.61516
# [71]	validation_0-rmse:0.77150
# [134]	validation_0-rmse:0.71803
# [67]	validation_0-rmse:0.67889
# [166]	validation_0-rmse:0.67538
# [113]	validation_0-rmse:0.61167
# [135]	validation_0-rmse:0.71844
# [72]	validation_0-rmse:0.76599
# [167]	validation_0-rmse:0.67605
# [68]	validation_0-rmse:0.67361
# [136]	validation_0-rmse:0.71671
# [114]	validation_0-rmse:0.61009
# [157]	validation_0-rmse:0.54792
# [168]	validation_0-rmse:0.67652
# [73]	validation_0-rmse:0.76118
# [69]	validation_0-rmse:0.67190
# [74]	validation_0-rmse:0.76128[137]	validation_0-rmse:0.71368
#
# [115]	validation_0-rmse:0.60831
# [158]	validation_0-rmse:0.54698
# [70]	validation_0-rmse:0.66802
# [169]	validation_0-rmse:0.67519
# [138]	validation_0-rmse:0.71104[75]	validation_0-rmse:0.75773
#
# [116]	validation_0-rmse:0.60503
# [170]	validation_0-rmse:0.67363
# [71]	validation_0-rmse:0.66365
# [139]	validation_0-rmse:0.71158[76]	validation_0-rmse:0.75305
#
# [117]	validation_0-rmse:0.60304[159]	validation_0-rmse:0.54534
#
# [171]	validation_0-rmse:0.67259
# [72]	validation_0-rmse:0.65904
# [140]	validation_0-rmse:0.70974
# [77]	validation_0-rmse:0.74939
# [118]	validation_0-rmse:0.60015
# [160]	validation_0-rmse:0.54440
# [172]	validation_0-rmse:0.67163
# [73]	validation_0-rmse:0.65487
# [78]	validation_0-rmse:0.75015
# [141]	validation_0-rmse:0.70790
# [119]	validation_0-rmse:0.59895
# [173]	validation_0-rmse:0.67009[79]	validation_0-rmse:0.74573
# [161]	validation_0-rmse:0.54417
#
# [142]	validation_0-rmse:0.70733
# [74]	validation_0-rmse:0.64998
# [120]	validation_0-rmse:0.59750[80]	validation_0-rmse:0.74296
# [162]	validation_0-rmse:0.54425
#
# [143]	validation_0-rmse:0.70367
# [75]	validation_0-rmse:0.64759
# [174]	validation_0-rmse:0.66887
# [144]	validation_0-rmse:0.70153
# [81]	validation_0-rmse:0.74363[121]	validation_0-rmse:0.59597
#
# [76]	validation_0-rmse:0.64565
# [175]	validation_0-rmse:0.66574
# [163]	validation_0-rmse:0.54359
# [82]	validation_0-rmse:0.74036[145]	validation_0-rmse:0.69920
#
# [122]	validation_0-rmse:0.59412[77]	validation_0-rmse:0.63984
#
# [176]	validation_0-rmse:0.66421[146]	validation_0-rmse:0.69971
#
# [83]	validation_0-rmse:0.73432
# [78]	validation_0-rmse:0.63911
# [123]	validation_0-rmse:0.59379
# [164]	validation_0-rmse:0.54235
# [147]	validation_0-rmse:0.69775
# [177]	validation_0-rmse:0.66371
# [84]	validation_0-rmse:0.73194
# [165]	validation_0-rmse:0.54123
# [124]	validation_0-rmse:0.59249
# [79]	validation_0-rmse:0.63771
# [148]	validation_0-rmse:0.69813
# [178]	validation_0-rmse:0.66319
# [166]	validation_0-rmse:0.54055
# [85]	validation_0-rmse:0.72848
# [149]	validation_0-rmse:0.69940
# [125]	validation_0-rmse:0.59058
# [80]	validation_0-rmse:0.63508
# [179]	validation_0-rmse:0.66306
# [150]	validation_0-rmse:0.70023
# [167]	validation_0-rmse:0.53743
# [86]	validation_0-rmse:0.72917
# [81]	validation_0-rmse:0.62982
# [180]	validation_0-rmse:0.66142
# [168]	validation_0-rmse:0.53718
# [151]	validation_0-rmse:0.69902
# [82]	validation_0-rmse:0.62897
# [181]	validation_0-rmse:0.66297
# [87]	validation_0-rmse:0.72573
# [182]	validation_0-rmse:0.66206
# [169]	validation_0-rmse:0.53591
# [152]	validation_0-rmse:0.69744[88]	validation_0-rmse:0.72314
#
# [126]	validation_0-rmse:0.58939[170]	validation_0-rmse:0.53347
# [183]	validation_0-rmse:0.65945
#
# [89]	validation_0-rmse:0.71884
# [184]	validation_0-rmse:0.65702[171]	validation_0-rmse:0.53244
#
# [127]	validation_0-rmse:0.58590
# [90]	validation_0-rmse:0.71646
# [83]	validation_0-rmse:0.62362
# [153]	validation_0-rmse:0.69368
# [172]	validation_0-rmse:0.53219[185]	validation_0-rmse:0.65536
# [91]	validation_0-rmse:0.71782
#
# [128]	validation_0-rmse:0.58084
# [84]	validation_0-rmse:0.62016
# [154]	validation_0-rmse:0.69153
# [186]	validation_0-rmse:0.65302[92]	validation_0-rmse:0.71852[173]	validation_0-rmse:0.53265
#
# [85]	validation_0-rmse:0.61681
# [155]	validation_0-rmse:0.69210[129]	validation_0-rmse:0.57622
#
# [93]	validation_0-rmse:0.71597[174]	validation_0-rmse:0.53172
#
# [156]	validation_0-rmse:0.69125
# [130]	validation_0-rmse:0.57507
# [187]	validation_0-rmse:0.65147[175]	validation_0-rmse:0.53210
#
#
# [94]	validation_0-rmse:0.71254
# [131]	validation_0-rmse:0.57483[188]	validation_0-rmse:0.65131
#
# [176]	validation_0-rmse:0.53194
# [95]	validation_0-rmse:0.70935[157]	validation_0-rmse:0.68756
#
# [189]	validation_0-rmse:0.64931[86]	validation_0-rmse:0.61217
#
# [132]	validation_0-rmse:0.57362
# [158]	validation_0-rmse:0.68658
# [190]	validation_0-rmse:0.64927
# [96]	validation_0-rmse:0.70509
# [133]	validation_0-rmse:0.57243
# [87]	validation_0-rmse:0.60888
# [177]	validation_0-rmse:0.53141
# [191]	validation_0-rmse:0.64803
# [159]	validation_0-rmse:0.68556
# [97]	validation_0-rmse:0.70124
# [134]	validation_0-rmse:0.57169
# [88]	validation_0-rmse:0.60835
# [160]	validation_0-rmse:0.68576
# [192]	validation_0-rmse:0.64670
# [98]	validation_0-rmse:0.69821
# [178]	validation_0-rmse:0.53163
# [89]	validation_0-rmse:0.60548
# [135]	validation_0-rmse:0.56873
# [193]	validation_0-rmse:0.64495
# [161]	validation_0-rmse:0.68487
# [194]	validation_0-rmse:0.64508
# [99]	validation_0-rmse:0.69412[90]	validation_0-rmse:0.60300
# [136]	validation_0-rmse:0.56750
#
# [162]	validation_0-rmse:0.68414
# [137]	validation_0-rmse:0.56641[195]	validation_0-rmse:0.64442
#
# [91]	validation_0-rmse:0.60064[100]	validation_0-rmse:0.69157
#
# [179]	validation_0-rmse:0.52958
# [163]	validation_0-rmse:0.68389
# [196]	validation_0-rmse:0.64263
# [101]	validation_0-rmse:0.68674
# [92]	validation_0-rmse:0.59992[138]	validation_0-rmse:0.56591
#
# [180]	validation_0-rmse:0.52918
# [197]	validation_0-rmse:0.64266
# [164]	validation_0-rmse:0.68126
# [181]	validation_0-rmse:0.52914
# [102]	validation_0-rmse:0.68349
# [139]	validation_0-rmse:0.56393
# [93]	validation_0-rmse:0.59628
# [165]	validation_0-rmse:0.68183
# [198]	validation_0-rmse:0.64101
# [182]	validation_0-rmse:0.52891
# [140]	validation_0-rmse:0.56196
# [94]	validation_0-rmse:0.59272
# [103]	validation_0-rmse:0.67957
# [166]	validation_0-rmse:0.67959
# [199]	validation_0-rmse:0.63970
# [183]	validation_0-rmse:0.52785
# [167]	validation_0-rmse:0.68027
# [95]	validation_0-rmse:0.59204
# [141]	validation_0-rmse:0.55850
# [184]	validation_0-rmse:0.52786[104]	validation_0-rmse:0.67604
#
# [168]	validation_0-rmse:0.68079
# [185]	validation_0-rmse:0.52786
# [96]	validation_0-rmse:0.58842
# [142]	validation_0-rmse:0.55695
# [105]	validation_0-rmse:0.67180
# [186]	validation_0-rmse:0.52856
# [169]	validation_0-rmse:0.67948
# [97]	validation_0-rmse:0.58601[143]	validation_0-rmse:0.55589
#
# [106]	validation_0-rmse:0.66766
# [187]	validation_0-rmse:0.52756[170]	validation_0-rmse:0.67795
#
# [144]	validation_0-rmse:0.55466
# [107]	validation_0-rmse:0.66498
# [98]	validation_0-rmse:0.58157
# [171]	validation_0-rmse:0.67694
# [108]	validation_0-rmse:0.66195[188]	validation_0-rmse:0.52662[145]	validation_0-rmse:0.55463
#
#
# [99]	validation_0-rmse:0.57942
# [172]	validation_0-rmse:0.67596
# [146]	validation_0-rmse:0.55274
# [109]	validation_0-rmse:0.66057
# [189]	validation_0-rmse:0.52594
# [100]	validation_0-rmse:0.57806
# [110]	validation_0-rmse:0.65659
# [147]	validation_0-rmse:0.55213
# [173]	validation_0-rmse:0.67446
# [190]	validation_0-rmse:0.52396
# [101]	validation_0-rmse:0.57385
# [111]	validation_0-rmse:0.65295
# [174]	validation_0-rmse:0.67301
# [191]	validation_0-rmse:0.52232
# [102]	validation_0-rmse:0.57241
# [112]	validation_0-rmse:0.65110
# [192]	validation_0-rmse:0.52167
# [175]	validation_0-rmse:0.67118
# [103]	validation_0-rmse:0.57005
# [193]	validation_0-rmse:0.52171
# [176]	validation_0-rmse:0.66962
# [148]	validation_0-rmse:0.55153
# [113]	validation_0-rmse:0.64747
# [177]	validation_0-rmse:0.66914[104]	validation_0-rmse:0.56771
# [194]	validation_0-rmse:0.52238
#
# [114]	validation_0-rmse:0.64396[149]	validation_0-rmse:0.55083
#
# [178]	validation_0-rmse:0.66723[115]	validation_0-rmse:0.64193
# [150]	validation_0-rmse:0.54955
# [195]	validation_0-rmse:0.51940
# [116]	validation_0-rmse:0.63949
# [151]	validation_0-rmse:0.54925
#
# [196]	validation_0-rmse:0.51914
# [117]	validation_0-rmse:0.63628
# [179]	validation_0-rmse:0.66708
# [105]	validation_0-rmse:0.56568
# [180]	validation_0-rmse:0.66531
# [197]	validation_0-rmse:0.51913
# [106]	validation_0-rmse:0.56249
# [118]	validation_0-rmse:0.63201
# [181]	validation_0-rmse:0.66683
# [119]	validation_0-rmse:0.63094[107]	validation_0-rmse:0.56167
#
# [198]	validation_0-rmse:0.51832
# [182]	validation_0-rmse:0.66598
# [120]	validation_0-rmse:0.62759
# [199]	validation_0-rmse:0.51884
# [183]	validation_0-rmse:0.66372
# [121]	validation_0-rmse:0.62378
# [108]	validation_0-rmse:0.55773
# [184]	validation_0-rmse:0.66127
# [122]	validation_0-rmse:0.62096
# [109]	validation_0-rmse:0.55566
# [152]	validation_0-rmse:0.54866
# [185]	validation_0-rmse:0.65970
# [123]	validation_0-rmse:0.61803
# [186]	validation_0-rmse:0.65741
# [110]	validation_0-rmse:0.55180
# [124]	validation_0-rmse:0.61683
# [111]	validation_0-rmse:0.54866
# [187]	validation_0-rmse:0.65549
# [188]	validation_0-rmse:0.65533[125]	validation_0-rmse:0.61415
#
# [153]	validation_0-rmse:0.54809
# [112]	validation_0-rmse:0.54688
# [154]	validation_0-rmse:0.54806
# [189]	validation_0-rmse:0.65334
# [126]	validation_0-rmse:0.61134
# [113]	validation_0-rmse:0.54357
# [190]	validation_0-rmse:0.65328
# [155]	validation_0-rmse:0.54455
# [127]	validation_0-rmse:0.60962
# [114]	validation_0-rmse:0.54179
# [191]	validation_0-rmse:0.65202
# [156]	validation_0-rmse:0.54476
# [128]	validation_0-rmse:0.60782
# [192]	validation_0-rmse:0.65078
# [115]	validation_0-rmse:0.53983
# [129]	validation_0-rmse:0.60492
# [157]	validation_0-rmse:0.54271
# [116]	validation_0-rmse:0.53679
# [193]	validation_0-rmse:0.64899
# [158]	validation_0-rmse:0.54177
# [130]	validation_0-rmse:0.60347
# [194]	validation_0-rmse:0.64914
# [117]	validation_0-rmse:0.53431
# [131]	validation_0-rmse:0.59993
# [159]	validation_0-rmse:0.53954
# [195]	validation_0-rmse:0.64846
# [118]	validation_0-rmse:0.53137
# [132]	validation_0-rmse:0.59783
# [196]	validation_0-rmse:0.64665
# [119]	validation_0-rmse:0.52935
# [133]	validation_0-rmse:0.59695
# [197]	validation_0-rmse:0.64698
# [134]	validation_0-rmse:0.59668
# [120]	validation_0-rmse:0.52596
# [198]	validation_0-rmse:0.64529
# [160]	validation_0-rmse:0.53865
# [135]	validation_0-rmse:0.59454
# [121]	validation_0-rmse:0.52403
# [136]	validation_0-rmse:0.59450
# [199]	validation_0-rmse:0.64405
# [161]	validation_0-rmse:0.53845
# [137]	validation_0-rmse:0.59528
# [122]	validation_0-rmse:0.52083
# [162]	validation_0-rmse:0.53861
# [138]	validation_0-rmse:0.59215
# [123]	validation_0-rmse:0.51995
# [139]	validation_0-rmse:0.58932[163]	validation_0-rmse:0.53794
#
# [124]	validation_0-rmse:0.51760
# [140]	validation_0-rmse:0.58919
# [164]	validation_0-rmse:0.53675
# [125]	validation_0-rmse:0.51414
# [141]	validation_0-rmse:0.58762
# [126]	validation_0-rmse:0.51113
# [142]	validation_0-rmse:0.58754
# [127]	validation_0-rmse:0.50830
# [143]	validation_0-rmse:0.58492
# [144]	validation_0-rmse:0.58581
# [165]	validation_0-rmse:0.53584
# [145]	validation_0-rmse:0.58422
# [166]	validation_0-rmse:0.53518
# [146]	validation_0-rmse:0.58239
# [147]	validation_0-rmse:0.58237
# [167]	validation_0-rmse:0.53468
# [148]	validation_0-rmse:0.58031
# [168]	validation_0-rmse:0.53450[128]	validation_0-rmse:0.50571
#
# [149]	validation_0-rmse:0.57918
# [169]	validation_0-rmse:0.53341
# [150]	validation_0-rmse:0.57676
# [129]	validation_0-rmse:0.50425
# [170]	validation_0-rmse:0.53111
# [151]	validation_0-rmse:0.57394
# [130]	validation_0-rmse:0.50213
# [171]	validation_0-rmse:0.53024
# [152]	validation_0-rmse:0.57174
# [131]	validation_0-rmse:0.50044
# [172]	validation_0-rmse:0.52791
# [153]	validation_0-rmse:0.57026
# [173]	validation_0-rmse:0.52827
# [154]	validation_0-rmse:0.56813
# [132]	validation_0-rmse:0.49866
# [133]	validation_0-rmse:0.49757
# [155]	validation_0-rmse:0.56654
# [174]	validation_0-rmse:0.52745[134]	validation_0-rmse:0.49593
#
# [156]	validation_0-rmse:0.56700
# [175]	validation_0-rmse:0.52779
# [135]	validation_0-rmse:0.49461
# [176]	validation_0-rmse:0.52727
# [157]	validation_0-rmse:0.56544
# [136]	validation_0-rmse:0.49346
# [177]	validation_0-rmse:0.52642
# [158]	validation_0-rmse:0.56592
# [137]	validation_0-rmse:0.49241
# [178]	validation_0-rmse:0.52676
# [179]	validation_0-rmse:0.52667
# [159]	validation_0-rmse:0.56647
# [138]	validation_0-rmse:0.49022
# [180]	validation_0-rmse:0.52632
# [160]	validation_0-rmse:0.56479
# [181]	validation_0-rmse:0.52628
# [161]	validation_0-rmse:0.56391
# [139]	validation_0-rmse:0.48746[182]	validation_0-rmse:0.52590
#
# [162]	validation_0-rmse:0.56172
# [183]	validation_0-rmse:0.52495
# [0]	validation_0-rmse:1.09313
# [163]	validation_0-rmse:0.55936
# [184]	validation_0-rmse:0.52496
# [140]	validation_0-rmse:0.48658
# [185]	validation_0-rmse:0.52496
# [164]	validation_0-rmse:0.56031
# [1]	validation_0-rmse:1.08632
# [186]	validation_0-rmse:0.52565
# [141]	validation_0-rmse:0.48504
# [165]	validation_0-rmse:0.55936
# [2]	validation_0-rmse:1.07718
# [187]	validation_0-rmse:0.52474
# [142]	validation_0-rmse:0.48481
# [166]	validation_0-rmse:0.56013
# [188]	validation_0-rmse:0.52393
# [167]	validation_0-rmse:0.55862
# [143]	validation_0-rmse:0.48454
# [3]	validation_0-rmse:1.06793
# [189]	validation_0-rmse:0.52274[168]	validation_0-rmse:0.55734
#
# [4]	validation_0-rmse:1.06147[144]	validation_0-rmse:0.48340
#
# [169]	validation_0-rmse:0.55790
# [145]	validation_0-rmse:0.48114
# [5]	validation_0-rmse:1.05610[170]	validation_0-rmse:0.55550
# [146]	validation_0-rmse:0.48127
#
# [147]	validation_0-rmse:0.48032[171]	validation_0-rmse:0.55194
# [190]	validation_0-rmse:0.52097
# [6]	validation_0-rmse:1.05046
#
# [172]	validation_0-rmse:0.55117
# [7]	validation_0-rmse:1.04878
# [173]	validation_0-rmse:0.54855
# [8]	validation_0-rmse:1.04834[191]	validation_0-rmse:0.51952
#
# [148]	validation_0-rmse:0.47842
# [174]	validation_0-rmse:0.54658
# [192]	validation_0-rmse:0.51893
# [149]	validation_0-rmse:0.47676
# [175]	validation_0-rmse:0.54658
# [193]	validation_0-rmse:0.51883
# [176]	validation_0-rmse:0.54655
# [150]	validation_0-rmse:0.47462
# [194]	validation_0-rmse:0.51948[9]	validation_0-rmse:1.04240
#
# [177]	validation_0-rmse:0.54583
# [151]	validation_0-rmse:0.47354[178]	validation_0-rmse:0.54386
# [195]	validation_0-rmse:0.51963
# [10]	validation_0-rmse:1.03389
#
# [179]	validation_0-rmse:0.54386
# [196]	validation_0-rmse:0.51943
# [180]	validation_0-rmse:0.54282
# [11]	validation_0-rmse:1.02449[197]	validation_0-rmse:0.51944
#
# [181]	validation_0-rmse:0.54183
# [198]	validation_0-rmse:0.51864
# [152]	validation_0-rmse:0.46936
# [182]	validation_0-rmse:0.54006
# [12]	validation_0-rmse:1.01474
# [199]	validation_0-rmse:0.51921
# [153]	validation_0-rmse:0.46812
# [183]	validation_0-rmse:0.53889
# [13]	validation_0-rmse:1.01330
# [184]	validation_0-rmse:0.53749
# [154]	validation_0-rmse:0.46703
# [185]	validation_0-rmse:0.53747
# [14]	validation_0-rmse:1.00476
# [155]	validation_0-rmse:0.46588
# [186]	validation_0-rmse:0.53620
# [156]	validation_0-rmse:0.46547[187]	validation_0-rmse:0.53658
# [188]	validation_0-rmse:0.53715
#
# [15]	validation_0-rmse:1.00508
# [189]	validation_0-rmse:0.53576
# [190]	validation_0-rmse:0.53527[157]	validation_0-rmse:0.46430
#
# [16]	validation_0-rmse:1.00543
# [191]	validation_0-rmse:0.53381
# [17]	validation_0-rmse:1.00012
# [158]	validation_0-rmse:0.46412
# [192]	validation_0-rmse:0.53442
# [193]	validation_0-rmse:0.53442
# [18]	validation_0-rmse:0.99059
# [159]	validation_0-rmse:0.46406
# [194]	validation_0-rmse:0.53299
# [19]	validation_0-rmse:0.98989
# [160]	validation_0-rmse:0.46387
# [195]	validation_0-rmse:0.53100
# [20]	validation_0-rmse:0.98360
# [161]	validation_0-rmse:0.46293
# [196]	validation_0-rmse:0.52898
# [21]	validation_0-rmse:0.98502
# [197]	validation_0-rmse:0.52811
# [162]	validation_0-rmse:0.46305
# [198]	validation_0-rmse:0.52850
# [22]	validation_0-rmse:0.97999
# [163]	validation_0-rmse:0.45978
# [199]	validation_0-rmse:0.52704
# [23]	validation_0-rmse:0.97196[164]	validation_0-rmse:0.45723
#
# [165]	validation_0-rmse:0.45587
# [24]	validation_0-rmse:0.97241
# [25]	validation_0-rmse:0.96502[166]	validation_0-rmse:0.45531
# [167]	validation_0-rmse:0.45465
#
# [168]	validation_0-rmse:0.45365
# [26]	validation_0-rmse:0.96091
# [27]	validation_0-rmse:0.95507
# [28]	validation_0-rmse:0.94749
# [29]	validation_0-rmse:0.94341[169]	validation_0-rmse:0.45217
#
# [170]	validation_0-rmse:0.44954
# [30]	validation_0-rmse:0.93513
# [171]	validation_0-rmse:0.44868
# [31]	validation_0-rmse:0.92587
# [172]	validation_0-rmse:0.44755
# [32]	validation_0-rmse:0.92434
# [33]	validation_0-rmse:0.92374
# [173]	validation_0-rmse:0.44691
# [174]	validation_0-rmse:0.44611
# [175]	validation_0-rmse:0.44586
# [34]	validation_0-rmse:0.92458
# [35]	validation_0-rmse:0.91595
# [36]	validation_0-rmse:0.91071
# [176]	validation_0-rmse:0.44473[37]	validation_0-rmse:0.90784
# [38]	validation_0-rmse:0.90039
# [39]	validation_0-rmse:0.89310
#
# [177]	validation_0-rmse:0.44437[0]	validation_0-rmse:1.09414
# [0]	validation_0-rmse:1.08567
# [1]	validation_0-rmse:1.09225
# [1]	validation_0-rmse:1.07484
# [2]	validation_0-rmse:1.08438
# [3]	validation_0-rmse:1.07519
# [2]	validation_0-rmse:1.06484
#
# [178]	validation_0-rmse:0.44396
# [40]	validation_0-rmse:0.88652
# [3]	validation_0-rmse:1.05130
# [41]	validation_0-rmse:0.88231
# [4]	validation_0-rmse:1.04119
# [42]	validation_0-rmse:0.87620
# [179]	validation_0-rmse:0.44290
# [43]	validation_0-rmse:0.86798
# [180]	validation_0-rmse:0.44297
# [44]	validation_0-rmse:0.86198
# [5]	validation_0-rmse:1.03137
# [181]	validation_0-rmse:0.44310
# [45]	validation_0-rmse:0.85576
# [182]	validation_0-rmse:0.44183
# [4]	validation_0-rmse:1.06532
# [183]	validation_0-rmse:0.44093
# [6]	validation_0-rmse:1.02168
# [5]	validation_0-rmse:1.05628
# [6]	validation_0-rmse:1.05438
# [7]	validation_0-rmse:1.01432
# [8]	validation_0-rmse:1.00815
# [46]	validation_0-rmse:0.85617
# [47]	validation_0-rmse:0.85351
# [48]	validation_0-rmse:0.85287[184]	validation_0-rmse:0.44015
#
# [9]	validation_0-rmse:0.99934
# [49]	validation_0-rmse:0.84725
# [185]	validation_0-rmse:0.43922
# [50]	validation_0-rmse:0.84626
# [186]	validation_0-rmse:0.43841
# [10]	validation_0-rmse:0.98655
# [187]	validation_0-rmse:0.43568
# [188]	validation_0-rmse:0.43500
# [7]	validation_0-rmse:1.04830
# [11]	validation_0-rmse:0.98091
# [189]	validation_0-rmse:0.43436
# [8]	validation_0-rmse:1.04492
# [12]	validation_0-rmse:0.97233[190]	validation_0-rmse:0.43394
#
# [9]	validation_0-rmse:1.03541
# [191]	validation_0-rmse:0.43266
# [13]	validation_0-rmse:0.96482
# [14]	validation_0-rmse:0.95736
# [10]	validation_0-rmse:1.02766
# [15]	validation_0-rmse:0.95064
# [11]	validation_0-rmse:1.02281
# [16]	validation_0-rmse:0.93952
# [12]	validation_0-rmse:1.01358
# [192]	validation_0-rmse:0.42991
# [13]	validation_0-rmse:1.00736
# [17]	validation_0-rmse:0.93232
# [193]	validation_0-rmse:0.42945
# [14]	validation_0-rmse:0.99874
# [18]	validation_0-rmse:0.92192
# [194]	validation_0-rmse:0.42811
# [195]	validation_0-rmse:0.42797
# [19]	validation_0-rmse:0.91644[196]	validation_0-rmse:0.42777
#
# [197]	validation_0-rmse:0.42785
# [51]	validation_0-rmse:0.84284
# [20]	validation_0-rmse:0.90909
# [52]	validation_0-rmse:0.84309
# [21]	validation_0-rmse:0.90250
# [53]	validation_0-rmse:0.84039
# [54]	validation_0-rmse:0.83698
# [22]	validation_0-rmse:0.89599
# [55]	validation_0-rmse:0.83260
# [23]	validation_0-rmse:0.88687
# [24]	validation_0-rmse:0.87594
# [15]	validation_0-rmse:0.99266
# [16]	validation_0-rmse:0.98904
# [17]	validation_0-rmse:0.98359
# [25]	validation_0-rmse:0.86842
# [18]	validation_0-rmse:0.97762
# [198]	validation_0-rmse:0.42657
# [56]	validation_0-rmse:0.82578
# [26]	validation_0-rmse:0.86348
# [199]	validation_0-rmse:0.42496
# [27]	validation_0-rmse:0.85853
# [57]	validation_0-rmse:0.82009
# [28]	validation_0-rmse:0.85271
# [58]	validation_0-rmse:0.81236
# [29]	validation_0-rmse:0.84420
# [59]	validation_0-rmse:0.80809
# [30]	validation_0-rmse:0.83844
# [60]	validation_0-rmse:0.80347
# [61]	validation_0-rmse:0.79800
# [0]	validation_0-rmse:1.09414
# [31]	validation_0-rmse:0.83195
# [19]	validation_0-rmse:0.97114
# [32]	validation_0-rmse:0.82376
# [1]	validation_0-rmse:1.09225
# [33]	validation_0-rmse:0.82233
# [2]	validation_0-rmse:1.08438
# [34]	validation_0-rmse:0.81968
# [20]	validation_0-rmse:0.96941
# [3]	validation_0-rmse:1.07508[35]	validation_0-rmse:0.81617
#
# [21]	validation_0-rmse:0.96110
# [36]	validation_0-rmse:0.81159
# [22]	validation_0-rmse:0.95423
# [4]	validation_0-rmse:1.06520[23]	validation_0-rmse:0.94837
# [37]	validation_0-rmse:0.80718
#
# [24]	validation_0-rmse:0.94398
# [38]	validation_0-rmse:0.80261
# [25]	validation_0-rmse:0.93872
# [5]	validation_0-rmse:1.05616
# [39]	validation_0-rmse:0.79726
# [62]	validation_0-rmse:0.79868
# [40]	validation_0-rmse:0.79347
# [6]	validation_0-rmse:1.05425
# [63]	validation_0-rmse:0.80012
# [64]	validation_0-rmse:0.79630
# [41]	validation_0-rmse:0.78794
# [7]	validation_0-rmse:1.04817
# [65]	validation_0-rmse:0.79207
# [42]	validation_0-rmse:0.78485
# [66]	validation_0-rmse:0.79215
# [43]	validation_0-rmse:0.78070
# [8]	validation_0-rmse:1.04487
# [67]	validation_0-rmse:0.78717
# [44]	validation_0-rmse:0.77774
# [68]	validation_0-rmse:0.78230
# [9]	validation_0-rmse:1.03532
# [45]	validation_0-rmse:0.76996
# [69]	validation_0-rmse:0.77815
# [10]	validation_0-rmse:1.02759
# [46]	validation_0-rmse:0.76942
# [47]	validation_0-rmse:0.76701
# [26]	validation_0-rmse:0.93371
# [11]	validation_0-rmse:1.02281
# [48]	validation_0-rmse:0.76419
# [27]	validation_0-rmse:0.92733
# [28]	validation_0-rmse:0.91993[49]	validation_0-rmse:0.75902
# [12]	validation_0-rmse:1.01361
#
# [50]	validation_0-rmse:0.75681
# [51]	validation_0-rmse:0.75364
# [29]	validation_0-rmse:0.91579
# [70]	validation_0-rmse:0.77930
# [52]	validation_0-rmse:0.74635
# [30]	validation_0-rmse:0.91025
# [53]	validation_0-rmse:0.74385
# [31]	validation_0-rmse:0.90656
# [71]	validation_0-rmse:0.77629
# [54]	validation_0-rmse:0.74109
# [32]	validation_0-rmse:0.90285
# [13]	validation_0-rmse:1.00739[72]	validation_0-rmse:0.77195
#
# [55]	validation_0-rmse:0.73881
# [33]	validation_0-rmse:0.89881
# [73]	validation_0-rmse:0.76710
# [14]	validation_0-rmse:0.99872
# [34]	validation_0-rmse:0.89291
# [56]	validation_0-rmse:0.73099
# [74]	validation_0-rmse:0.76718
# [15]	validation_0-rmse:0.99262
# [35]	validation_0-rmse:0.88775
# [57]	validation_0-rmse:0.72290
# [75]	validation_0-rmse:0.76363
# [36]	validation_0-rmse:0.88387
# [76]	validation_0-rmse:0.75890
# [58]	validation_0-rmse:0.71601
# [77]	validation_0-rmse:0.75519
# [78]	validation_0-rmse:0.75606
# [59]	validation_0-rmse:0.70932
# [16]	validation_0-rmse:0.98905
# [79]	validation_0-rmse:0.75165
# [60]	validation_0-rmse:0.70257
# [80]	validation_0-rmse:0.74901
# [17]	validation_0-rmse:0.98366
# [61]	validation_0-rmse:0.69966
# [81]	validation_0-rmse:0.74950
# [18]	validation_0-rmse:0.97767[62]	validation_0-rmse:0.69418
#
# [82]	validation_0-rmse:0.74662
# [63]	validation_0-rmse:0.69094
# [19]	validation_0-rmse:0.97119
# [83]	validation_0-rmse:0.74058
# [64]	validation_0-rmse:0.68524
# [84]	validation_0-rmse:0.73625
# [20]	validation_0-rmse:0.96942
# [85]	validation_0-rmse:0.73276
# [65]	validation_0-rmse:0.68196
# [21]	validation_0-rmse:0.96114
# [37]	validation_0-rmse:0.87974
# [86]	validation_0-rmse:0.73356
# [66]	validation_0-rmse:0.67633
# [22]	validation_0-rmse:0.95428
# [38]	validation_0-rmse:0.87307
# [67]	validation_0-rmse:0.67043
# [39]	validation_0-rmse:0.86848
# [23]	validation_0-rmse:0.94842
# [68]	validation_0-rmse:0.66522
# [69]	validation_0-rmse:0.66363[24]	validation_0-rmse:0.94384
#
# [40]	validation_0-rmse:0.86853
# [25]	validation_0-rmse:0.93908[41]	validation_0-rmse:0.86488
#
# [87]	validation_0-rmse:0.73018[42]	validation_0-rmse:0.86103
# [70]	validation_0-rmse:0.65972
#
# [26]	validation_0-rmse:0.93397
# [88]	validation_0-rmse:0.72762
# [43]	validation_0-rmse:0.85360
# [71]	validation_0-rmse:0.65536
# [44]	validation_0-rmse:0.85213
# [89]	validation_0-rmse:0.72364
# [72]	validation_0-rmse:0.65078
# [45]	validation_0-rmse:0.84854
# [73]	validation_0-rmse:0.64657
# [90]	validation_0-rmse:0.72135
# [74]	validation_0-rmse:0.64187
# [27]	validation_0-rmse:0.92682
# [46]	validation_0-rmse:0.84804
# [91]	validation_0-rmse:0.72244
# [92]	validation_0-rmse:0.72321
# [28]	validation_0-rmse:0.91942
# [47]	validation_0-rmse:0.84324
# [75]	validation_0-rmse:0.63952
# [93]	validation_0-rmse:0.72061
# [48]	validation_0-rmse:0.84181
# [76]	validation_0-rmse:0.63845
# [94]	validation_0-rmse:0.71738
# [49]	validation_0-rmse:0.83936[29]	validation_0-rmse:0.91526
#
# [77]	validation_0-rmse:0.63228
# [50]	validation_0-rmse:0.83593
# [78]	validation_0-rmse:0.63152
# [30]	validation_0-rmse:0.90975[95]	validation_0-rmse:0.71423
#
# [51]	validation_0-rmse:0.83330
# [79]	validation_0-rmse:0.63009
# [96]	validation_0-rmse:0.71119
# [52]	validation_0-rmse:0.82890
# [80]	validation_0-rmse:0.62757
# [97]	validation_0-rmse:0.70743
# [53]	validation_0-rmse:0.82568
# [31]	validation_0-rmse:0.90580
# [81]	validation_0-rmse:0.62249
# [98]	validation_0-rmse:0.70457
# [0]	validation_0-rmse:1.09313
# [82]	validation_0-rmse:0.62214
# [0]	validation_0-rmse:1.09201
# [83]	validation_0-rmse:0.61698
# [32]	validation_0-rmse:0.90204
# [1]	validation_0-rmse:1.08547
# [54]	validation_0-rmse:0.82233
# [84]	validation_0-rmse:0.61361
# [2]	validation_0-rmse:1.08197
# [55]	validation_0-rmse:0.82083
# [85]	validation_0-rmse:0.61016[3]	validation_0-rmse:1.07111
#
# [56]	validation_0-rmse:0.82062
# [0]	validation_0-rmse:1.08904
# [4]	validation_0-rmse:1.06484[86]	validation_0-rmse:0.60553
#
# [33]	validation_0-rmse:0.89795[99]	validation_0-rmse:0.70057
# [57]	validation_0-rmse:0.81830[1]	validation_0-rmse:1.08632
#
# [87]	validation_0-rmse:0.60201
# [2]	validation_0-rmse:1.07718
# [88]	validation_0-rmse:0.60153
# [100]	validation_0-rmse:0.69837
#
# [89]	validation_0-rmse:0.59898[101]	validation_0-rmse:0.69350
#
# [1]	validation_0-rmse:1.07558
# [90]	validation_0-rmse:0.59662
# [34]	validation_0-rmse:0.89204
# [102]	validation_0-rmse:0.69036[3]	validation_0-rmse:1.06793
# [58]	validation_0-rmse:0.81551
# [35]	validation_0-rmse:0.88737
# [91]	validation_0-rmse:0.59362
# [59]	validation_0-rmse:0.81470
# [4]	validation_0-rmse:1.06147
# [5]	validation_0-rmse:1.05607
#
# [36]	validation_0-rmse:0.88345
# [60]	validation_0-rmse:0.80948
# [5]	validation_0-rmse:1.05610
# [6]	validation_0-rmse:1.05305
# [103]	validation_0-rmse:0.68663
# [37]	validation_0-rmse:0.87928
# [61]	validation_0-rmse:0.80617[6]	validation_0-rmse:1.05046
# [7]	validation_0-rmse:1.04470
# [38]	validation_0-rmse:0.87258
# [7]	validation_0-rmse:1.04878
# [8]	validation_0-rmse:1.03462
# [8]	validation_0-rmse:1.04834
# [39]	validation_0-rmse:0.86797
# [9]	validation_0-rmse:1.02717
# [104]	validation_0-rmse:0.68314
#
# [9]	validation_0-rmse:1.04240
# [40]	validation_0-rmse:0.86800
# [105]	validation_0-rmse:0.67889
# [2]	validation_0-rmse:1.06702
# [62]	validation_0-rmse:0.80241
# [41]	validation_0-rmse:0.86433
# [106]	validation_0-rmse:0.67474
# [92]	validation_0-rmse:0.59314
# [63]	validation_0-rmse:0.80066
# ...
# [160]	validation_0-rmse:0.50194
# [158]	validation_0-rmse:0.73276
# [159]	validation_0-rmse:0.73335
# [161]	validation_0-rmse:0.50019
# [162]	validation_0-rmse:0.50020
# [163]	validation_0-rmse:0.50007
# [160]	validation_0-rmse:0.73416
# [164]	validation_0-rmse:0.50051
# [161]	validation_0-rmse:0.73419
# [165]	validation_0-rmse:0.50052
# [162]	validation_0-rmse:0.73420
# [166]	validation_0-rmse:0.50055
# [163]	validation_0-rmse:0.73421
# [167]	validation_0-rmse:0.50055
# [164]	validation_0-rmse:0.73391
# [165]	validation_0-rmse:0.73395
# [168]	validation_0-rmse:0.49884
# [166]	validation_0-rmse:0.73398
# [169]	validation_0-rmse:0.49885
# [167]	validation_0-rmse:0.73401
# [170]	validation_0-rmse:0.49887
# [171]	validation_0-rmse:0.49889
# [168]	validation_0-rmse:0.73469
# [172]	validation_0-rmse:0.49890
# [169]	validation_0-rmse:0.73470
# [170]	validation_0-rmse:0.73540
# [173]	validation_0-rmse:0.49741
# [174]	validation_0-rmse:0.49738[171]	validation_0-rmse:0.73541
#
# [175]	validation_0-rmse:0.49732
# [172]	validation_0-rmse:0.73589
# [176]	validation_0-rmse:0.49732
# [173]	validation_0-rmse:0.73592
# [177]	validation_0-rmse:0.49732
# [174]	validation_0-rmse:0.73592
# [175]	validation_0-rmse:0.73650
# [178]	validation_0-rmse:0.49557
# [176]	validation_0-rmse:0.73652
# [179]	validation_0-rmse:0.49557[177]	validation_0-rmse:0.73709
#
# [180]	validation_0-rmse:0.49557
# [178]	validation_0-rmse:0.73794
# [179]	validation_0-rmse:0.73795
# [180]	validation_0-rmse:0.73795
# [181]	validation_0-rmse:0.49587
# [181]	validation_0-rmse:0.73850
# [182]	validation_0-rmse:0.49587
# [182]	validation_0-rmse:0.73841
# [183]	validation_0-rmse:0.49587
# [183]	validation_0-rmse:0.73841
# [184]	validation_0-rmse:0.73897
# [185]	validation_0-rmse:0.73897
# [184]	validation_0-rmse:0.49544
# [186]	validation_0-rmse:0.73897
# [187]	validation_0-rmse:0.73900
# [188]	validation_0-rmse:0.73903
# [185]	validation_0-rmse:0.49542
# [189]	validation_0-rmse:0.73982[186]	validation_0-rmse:0.49454
#
# [187]	validation_0-rmse:0.49512
# [190]	validation_0-rmse:0.74072
# [188]	validation_0-rmse:0.49514
# [191]	validation_0-rmse:0.74072
# [189]	validation_0-rmse:0.49372
# [192]	validation_0-rmse:0.74115
# [190]	validation_0-rmse:0.49363
# [193]	validation_0-rmse:0.74117
# [191]	validation_0-rmse:0.49363
# [194]	validation_0-rmse:0.74117
# [195]	validation_0-rmse:0.74118
# [192]	validation_0-rmse:0.49428
# [196]	validation_0-rmse:0.74118
# [193]	validation_0-rmse:0.49428
# [197]	validation_0-rmse:0.74122
# [194]	validation_0-rmse:0.49424
# [195]	validation_0-rmse:0.49423
# [198]	validation_0-rmse:0.74194
# [196]	validation_0-rmse:0.49420
# [199]	validation_0-rmse:0.74193
# [197]	validation_0-rmse:0.49432
# [198]	validation_0-rmse:0.49415
# [199]	validation_0-rmse:0.49415
# [0]	validation_0-rmse:1.09537
# [1]	validation_0-rmse:1.08469
# [2]	validation_0-rmse:1.07063
# [3]	validation_0-rmse:1.05186
# [4]	validation_0-rmse:1.04764
# [5]	validation_0-rmse:1.03756
# [6]	validation_0-rmse:1.02992
# [7]	validation_0-rmse:1.01728
# [8]	validation_0-rmse:1.01018
# [9]	validation_0-rmse:1.00097
# [10]	validation_0-rmse:0.98798
# [11]	validation_0-rmse:0.97951
# [12]	validation_0-rmse:0.97381
# [13]	validation_0-rmse:0.96176
# [14]	validation_0-rmse:0.95537
# [15]	validation_0-rmse:0.93988
# [16]	validation_0-rmse:0.92937
# [17]	validation_0-rmse:0.92259
# [18]	validation_0-rmse:0.91019
# [19]	validation_0-rmse:0.90132
# [20]	validation_0-rmse:0.89492
# [21]	validation_0-rmse:0.88898
# [22]	validation_0-rmse:0.87817
# [23]	validation_0-rmse:0.87480
# [24]	validation_0-rmse:0.86355
# [25]	validation_0-rmse:0.85288
# [26]	validation_0-rmse:0.84498
# [27]	validation_0-rmse:0.83879
# [28]	validation_0-rmse:0.82901
# [29]	validation_0-rmse:0.82278
# [30]	validation_0-rmse:0.81376
# [31]	validation_0-rmse:0.80296
# [32]	validation_0-rmse:0.79685
# [33]	validation_0-rmse:0.79011
# [34]	validation_0-rmse:0.78521
# [35]	validation_0-rmse:0.77745
# [36]	validation_0-rmse:0.77353
# [37]	validation_0-rmse:0.77269
# [38]	validation_0-rmse:0.76714
# [39]	validation_0-rmse:0.76351
# [40]	validation_0-rmse:0.76083
# [41]	validation_0-rmse:0.75383
# [42]	validation_0-rmse:0.74768
# [43]	validation_0-rmse:0.73797
# [44]	validation_0-rmse:0.73518
# [45]	validation_0-rmse:0.72475
# [46]	validation_0-rmse:0.71928
# [47]	validation_0-rmse:0.71245
# [48]	validation_0-rmse:0.70889
# [49]	validation_0-rmse:0.69871
# [50]	validation_0-rmse:0.69028
# [51]	validation_0-rmse:0.68071
# [52]	validation_0-rmse:0.67593
# [53]	validation_0-rmse:0.66953
# [54]	validation_0-rmse:0.66757
# [55]	validation_0-rmse:0.66238
# [56]	validation_0-rmse:0.65735
# [57]	validation_0-rmse:0.65115
# [58]	validation_0-rmse:0.64912
# [59]	validation_0-rmse:0.64541
# [60]	validation_0-rmse:0.64126
# [61]	validation_0-rmse:0.63338
# [62]	validation_0-rmse:0.62922
# [63]	validation_0-rmse:0.62666
# [64]	validation_0-rmse:0.62254
# [65]	validation_0-rmse:0.61871
# [66]	validation_0-rmse:0.61484
# [67]	validation_0-rmse:0.60772
# [68]	validation_0-rmse:0.60163
# [69]	validation_0-rmse:0.59908
# [70]	validation_0-rmse:0.59473
# [71]	validation_0-rmse:0.58787
# [72]	validation_0-rmse:0.58171
# [73]	validation_0-rmse:0.57922
# [74]	validation_0-rmse:0.57365
# [75]	validation_0-rmse:0.57141
# [76]	validation_0-rmse:0.56597
# [77]	validation_0-rmse:0.56108
# [78]	validation_0-rmse:0.55923
# [79]	validation_0-rmse:0.55466
# [80]	validation_0-rmse:0.54914
# [81]	validation_0-rmse:0.54529
# [82]	validation_0-rmse:0.54330
# [83]	validation_0-rmse:0.53860
# [84]	validation_0-rmse:0.53347
# [85]	validation_0-rmse:0.52987
# [86]	validation_0-rmse:0.52510
# [87]	validation_0-rmse:0.52317
# [88]	validation_0-rmse:0.51929
# [89]	validation_0-rmse:0.51914
# [90]	validation_0-rmse:0.51746
# [91]	validation_0-rmse:0.51413
# [92]	validation_0-rmse:0.51003
# [93]	validation_0-rmse:0.50525
# [94]	validation_0-rmse:0.50320
# [95]	validation_0-rmse:0.50172
# [96]	validation_0-rmse:0.49811
# [97]	validation_0-rmse:0.49376
# [98]	validation_0-rmse:0.49286
# [99]	validation_0-rmse:0.48940
# [100]	validation_0-rmse:0.48562
# [101]	validation_0-rmse:0.48554
# [102]	validation_0-rmse:0.48211
# [103]	validation_0-rmse:0.47921
# [104]	validation_0-rmse:0.47722
# [105]	validation_0-rmse:0.47590
# [106]	validation_0-rmse:0.47464
# [107]	validation_0-rmse:0.47031
# [108]	validation_0-rmse:0.46760
# [109]	validation_0-rmse:0.46485
# [110]	validation_0-rmse:0.46287
# [111]	validation_0-rmse:0.46017
# [112]	validation_0-rmse:0.45696
# [113]	validation_0-rmse:0.45441
# [114]	validation_0-rmse:0.45339
# [115]	validation_0-rmse:0.44850
# [116]	validation_0-rmse:0.44571
# [117]	validation_0-rmse:0.44456
# [118]	validation_0-rmse:0.44250
# [119]	validation_0-rmse:0.43924
# [120]	validation_0-rmse:0.43849
# [121]	validation_0-rmse:0.43783
# [122]	validation_0-rmse:0.43482
# [123]	validation_0-rmse:0.43411
# [124]	validation_0-rmse:0.43237
# [125]	validation_0-rmse:0.43257
# [126]	validation_0-rmse:0.43049
# [127]	validation_0-rmse:0.43008
# [128]	validation_0-rmse:0.42974
# [129]	validation_0-rmse:0.42783
# [130]	validation_0-rmse:0.42362
# [131]	validation_0-rmse:0.42224
# [132]	validation_0-rmse:0.42085
# [133]	validation_0-rmse:0.41880
# [134]	validation_0-rmse:0.41694
# [135]	validation_0-rmse:0.41495
# [136]	validation_0-rmse:0.41361
# [137]	validation_0-rmse:0.41225
# [138]	validation_0-rmse:0.41165
# [139]	validation_0-rmse:0.40959
# [140]	validation_0-rmse:0.40801
# [141]	validation_0-rmse:0.40443
# [142]	validation_0-rmse:0.40281
# [143]	validation_0-rmse:0.40126
# [144]	validation_0-rmse:0.39936
# [145]	validation_0-rmse:0.39966
# [146]	validation_0-rmse:0.39889
# [147]	validation_0-rmse:0.39791
# [148]	validation_0-rmse:0.39641
# [149]	validation_0-rmse:0.39620
# [150]	validation_0-rmse:0.39434
# [151]	validation_0-rmse:0.39255
# [152]	validation_0-rmse:0.38762
# [153]	validation_0-rmse:0.38617
# [154]	validation_0-rmse:0.38575
# [155]	validation_0-rmse:0.38448
# [156]	validation_0-rmse:0.38290
# [157]	validation_0-rmse:0.38145
# [158]	validation_0-rmse:0.38148
# [159]	validation_0-rmse:0.38125
# [160]	validation_0-rmse:0.37886
# [161]	validation_0-rmse:0.37789
# [162]	validation_0-rmse:0.37731
# [163]	validation_0-rmse:0.37630
# [164]	validation_0-rmse:0.37626
# [165]	validation_0-rmse:0.37526
# [166]	validation_0-rmse:0.37402
# [167]	validation_0-rmse:0.37166
# [168]	validation_0-rmse:0.37138
# [169]	validation_0-rmse:0.37112
# [170]	validation_0-rmse:0.36724
# [171]	validation_0-rmse:0.36609
# [172]	validation_0-rmse:0.36465
# [173]	validation_0-rmse:0.36372
# [174]	validation_0-rmse:0.36114
# [175]	validation_0-rmse:0.36091
# [176]	validation_0-rmse:0.36029
# [177]	validation_0-rmse:0.35946
# [178]	validation_0-rmse:0.35861
# [179]	validation_0-rmse:0.35772
# [180]	validation_0-rmse:0.35662
# [181]	validation_0-rmse:0.35590
# [182]	validation_0-rmse:0.35423
# [183]	validation_0-rmse:0.35240
# [184]	validation_0-rmse:0.35152
# [185]	validation_0-rmse:0.35049
# [186]	validation_0-rmse:0.35007
# [187]	validation_0-rmse:0.34897
# [188]	validation_0-rmse:0.34897
# [189]	validation_0-rmse:0.34818
# [190]	validation_0-rmse:0.34742
# [191]	validation_0-rmse:0.34649
# [192]	validation_0-rmse:0.34577
# [193]	validation_0-rmse:0.34486
# [194]	validation_0-rmse:0.34500
# [195]	validation_0-rmse:0.34298
# [196]	validation_0-rmse:0.34082
# [197]	validation_0-rmse:0.33823
# [198]	validation_0-rmse:0.33673
# [199]	validation_0-rmse:0.33587
# Meilleurs paramètres de l'étape 3: {'colsample_bytree': 0.9, 'subsample': 0.7}
#
# Meilleurs paramètres combinés:
#   learning_rate: 0.03
#   max_depth: 8
#   gamma: 0.1
#   min_child_weight: 2
#   colsample_bytree: 0.9
#   subsample: 0.7
#
# Entraînement du modèle final avec les meilleurs paramètres...
# [0]	validation_0-rmse:1.09537
# [1]	validation_0-rmse:1.08469
# [2]	validation_0-rmse:1.07063
# [3]	validation_0-rmse:1.05186
# [4]	validation_0-rmse:1.04764
# [5]	validation_0-rmse:1.03756
# [6]	validation_0-rmse:1.02992
# [7]	validation_0-rmse:1.01728
# [8]	validation_0-rmse:1.01018
# [9]	validation_0-rmse:1.00097
# [10]	validation_0-rmse:0.98798
# [11]	validation_0-rmse:0.97951
# [12]	validation_0-rmse:0.97381
# [13]	validation_0-rmse:0.96176
# [14]	validation_0-rmse:0.95537
# [15]	validation_0-rmse:0.93988
# [16]	validation_0-rmse:0.92937
# [17]	validation_0-rmse:0.92259
# [18]	validation_0-rmse:0.91019
# [19]	validation_0-rmse:0.90132
# [20]	validation_0-rmse:0.89492
# [21]	validation_0-rmse:0.88898
# [22]	validation_0-rmse:0.87817
# [23]	validation_0-rmse:0.87480
# [24]	validation_0-rmse:0.86355
# [25]	validation_0-rmse:0.85288
# [26]	validation_0-rmse:0.84498
# [27]	validation_0-rmse:0.83879
# [28]	validation_0-rmse:0.82901
# [29]	validation_0-rmse:0.82278
# [30]	validation_0-rmse:0.81376
# [31]	validation_0-rmse:0.80296
# [32]	validation_0-rmse:0.79685
# [33]	validation_0-rmse:0.79011
# [34]	validation_0-rmse:0.78521
# [35]	validation_0-rmse:0.77745
# [36]	validation_0-rmse:0.77353
# [37]	validation_0-rmse:0.77269
# [38]	validation_0-rmse:0.76714
# [39]	validation_0-rmse:0.76351
# [40]	validation_0-rmse:0.76083
# [41]	validation_0-rmse:0.75383
# [42]	validation_0-rmse:0.74768
# [43]	validation_0-rmse:0.73797
# [44]	validation_0-rmse:0.73518
# [45]	validation_0-rmse:0.72475
# [46]	validation_0-rmse:0.71928
# [47]	validation_0-rmse:0.71245
# [48]	validation_0-rmse:0.70889
# [49]	validation_0-rmse:0.69871
# [50]	validation_0-rmse:0.69028
# [51]	validation_0-rmse:0.68071
# [52]	validation_0-rmse:0.67593
# [53]	validation_0-rmse:0.66953
# [54]	validation_0-rmse:0.66757
# [55]	validation_0-rmse:0.66238
# [56]	validation_0-rmse:0.65735
# [57]	validation_0-rmse:0.65115
# [58]	validation_0-rmse:0.64912
# [59]	validation_0-rmse:0.64541
# [60]	validation_0-rmse:0.64126
# [61]	validation_0-rmse:0.63338
# [62]	validation_0-rmse:0.62922
# [63]	validation_0-rmse:0.62666
# [64]	validation_0-rmse:0.62254
# [65]	validation_0-rmse:0.61871
# [66]	validation_0-rmse:0.61484
# [67]	validation_0-rmse:0.60772
# [68]	validation_0-rmse:0.60163
# [69]	validation_0-rmse:0.59908
# [70]	validation_0-rmse:0.59473
# [71]	validation_0-rmse:0.58787
# [72]	validation_0-rmse:0.58171
# [73]	validation_0-rmse:0.57922
# [74]	validation_0-rmse:0.57365
# [75]	validation_0-rmse:0.57141
# [76]	validation_0-rmse:0.56597
# [77]	validation_0-rmse:0.56108
# [78]	validation_0-rmse:0.55923
# [79]	validation_0-rmse:0.55466
# [80]	validation_0-rmse:0.54914
# [81]	validation_0-rmse:0.54529
# [82]	validation_0-rmse:0.54330
# [83]	validation_0-rmse:0.53860
# [84]	validation_0-rmse:0.53347
# [85]	validation_0-rmse:0.52987
# [86]	validation_0-rmse:0.52510
# [87]	validation_0-rmse:0.52317
# [88]	validation_0-rmse:0.51929
# [89]	validation_0-rmse:0.51914
# [90]	validation_0-rmse:0.51746
# [91]	validation_0-rmse:0.51413
# [92]	validation_0-rmse:0.51003
# [93]	validation_0-rmse:0.50525
# [94]	validation_0-rmse:0.50320
# [95]	validation_0-rmse:0.50172
# [96]	validation_0-rmse:0.49811
# [97]	validation_0-rmse:0.49376
# [98]	validation_0-rmse:0.49286
# [99]	validation_0-rmse:0.48940
# [100]	validation_0-rmse:0.48562
# [101]	validation_0-rmse:0.48554
# [102]	validation_0-rmse:0.48211
# [103]	validation_0-rmse:0.47921
# [104]	validation_0-rmse:0.47722
# [105]	validation_0-rmse:0.47590
# [106]	validation_0-rmse:0.47464
# [107]	validation_0-rmse:0.47031
# [108]	validation_0-rmse:0.46760
# [109]	validation_0-rmse:0.46485
# [110]	validation_0-rmse:0.46287
# [111]	validation_0-rmse:0.46017
# [112]	validation_0-rmse:0.45696
# [113]	validation_0-rmse:0.45441
# [114]	validation_0-rmse:0.45339
# [115]	validation_0-rmse:0.44850
# [116]	validation_0-rmse:0.44571
# [117]	validation_0-rmse:0.44456
# [118]	validation_0-rmse:0.44250
# [119]	validation_0-rmse:0.43924
# [120]	validation_0-rmse:0.43849
# [121]	validation_0-rmse:0.43783
# [122]	validation_0-rmse:0.43482
# [123]	validation_0-rmse:0.43411
# [124]	validation_0-rmse:0.43237
# [125]	validation_0-rmse:0.43257
# [126]	validation_0-rmse:0.43049
# [127]	validation_0-rmse:0.43008
# [128]	validation_0-rmse:0.42974
# [129]	validation_0-rmse:0.42783
# [130]	validation_0-rmse:0.42362
# [131]	validation_0-rmse:0.42224
# [132]	validation_0-rmse:0.42085
# [133]	validation_0-rmse:0.41880
# [134]	validation_0-rmse:0.41694
# [135]	validation_0-rmse:0.41495
# [136]	validation_0-rmse:0.41361
# [137]	validation_0-rmse:0.41225
# [138]	validation_0-rmse:0.41165
# [139]	validation_0-rmse:0.40959
# [140]	validation_0-rmse:0.40801
# [141]	validation_0-rmse:0.40443
# [142]	validation_0-rmse:0.40281
# [143]	validation_0-rmse:0.40126
# [144]	validation_0-rmse:0.39936
# [145]	validation_0-rmse:0.39966
# [146]	validation_0-rmse:0.39889
# [147]	validation_0-rmse:0.39791
# [148]	validation_0-rmse:0.39641
# [149]	validation_0-rmse:0.39620
# [150]	validation_0-rmse:0.39434
# [151]	validation_0-rmse:0.39255
# [152]	validation_0-rmse:0.38762
# [153]	validation_0-rmse:0.38617
# [154]	validation_0-rmse:0.38575
# [155]	validation_0-rmse:0.38448
# [156]	validation_0-rmse:0.38290
# [157]	validation_0-rmse:0.38145
# [158]	validation_0-rmse:0.38148
# [159]	validation_0-rmse:0.38125
# [160]	validation_0-rmse:0.37886
# [161]	validation_0-rmse:0.37789
# [162]	validation_0-rmse:0.37731
# [163]	validation_0-rmse:0.37630
# [164]	validation_0-rmse:0.37626
# [165]	validation_0-rmse:0.37526
# [166]	validation_0-rmse:0.37402
# [167]	validation_0-rmse:0.37166
# [168]	validation_0-rmse:0.37138
# [169]	validation_0-rmse:0.37112
# [170]	validation_0-rmse:0.36724
# [171]	validation_0-rmse:0.36609
# [172]	validation_0-rmse:0.36465
# [173]	validation_0-rmse:0.36372
# [174]	validation_0-rmse:0.36114
# [175]	validation_0-rmse:0.36091
# [176]	validation_0-rmse:0.36029
# [177]	validation_0-rmse:0.35946
# [178]	validation_0-rmse:0.35861
# [179]	validation_0-rmse:0.35772
# [180]	validation_0-rmse:0.35662
# [181]	validation_0-rmse:0.35590
# [182]	validation_0-rmse:0.35423
# [183]	validation_0-rmse:0.35240
# [184]	validation_0-rmse:0.35152
# [185]	validation_0-rmse:0.35049
# [186]	validation_0-rmse:0.35007
# [187]	validation_0-rmse:0.34897
# [188]	validation_0-rmse:0.34897
# [189]	validation_0-rmse:0.34818
# [190]	validation_0-rmse:0.34742
# [191]	validation_0-rmse:0.34649
# [192]	validation_0-rmse:0.34577
# [193]	validation_0-rmse:0.34486
# [194]	validation_0-rmse:0.34500
# [195]	validation_0-rmse:0.34298
# [196]	validation_0-rmse:0.34082
# [197]	validation_0-rmse:0.33823
# [198]	validation_0-rmse:0.33673
# [199]	validation_0-rmse:0.33587
# Temps total de l'optimisation: 0.21 minutes
# Suppression de 1574 entrées avec NaN
#
# Résultats du modèle XGBoost Original:
# R² = -0.2969, R² (log) = -0.4320
# RMSE = 319.70, MAE = 290.18
# Suppression de 1574 entrées avec NaN
#
# Résultats du modèle XGBoost Final:
# R² = -0.2984, R² (log) = -0.4334
# RMSE = 319.88, MAE = 283.06
#
# ===== COMPARAISON DES MODÈLES =====
# R² Original: -0.2969, R² Optimisé: -0.2984
# Amélioration R²: -0.49%
# RMSE Original: 319.70, RMSE Optimisé: 319.88
# Réduction RMSE: -0.06%

# %%
# ⏱ Enregistrer le temps de début
start_time = time.time()

# 🔧 Grille d'hyperparamètres stratégique
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1],
    'n_estimators': [100, 200],
    'colsample_bytree': [0.7, 0.9],
    'subsample': [0.8, 1.0]
}

# 📦 Modèle XGBoost avec early stopping intégré
xgb_model_grid = XGBRegressor(
    objective='reg:squarederror',
    min_child_weight=3,
    gamma=0.1,
    reg_alpha=0.1,
    reg_lambda=1.0,
    random_state=42,
    early_stopping_rounds=20
)

# 🔁 Validation croisée
cv = KFold(n_splits=3, shuffle=True, random_state=42)

# 🔍 GridSearchCV
grid_search = GridSearchCV(
    estimator=xgb_model_grid,
    param_grid=param_grid,
    scoring='neg_mean_squared_error',
    cv=cv,
    n_jobs=-1,
    verbose=1
)

# 🎯 Ensemble de validation pour early stopping
eval_set = [(X_train, y_train_log)]

print("🚀 Début de la recherche par grille...")
grid_search.fit(X_train, y_train_log, eval_set=eval_set)

# ⏱ Temps d’exécution
end_time = time.time()
print(f"🕒 Temps total de recherche: {(end_time - start_time)/60:.2f} minutes")

# ✅ Meilleurs hyperparamètres
print("🏆 Meilleurs hyperparamètres trouvés :")
for param, value in grid_search.best_params_.items():
    print(f"  {param}: {value}")
print(f"💡 Meilleur score (neg_mean_squared_error): {-grid_search.best_score_:.4f}")

# 📌 Récupérer le meilleur modèle
best_xgb_model = grid_search.best_estimator_

# 📊 Prédictions
y_pred_log = best_xgb_model.predict(X_test)
y_pred = np.expm1(y_pred_log)
y_test_real = np.expm1(y_test_log)

# 🧪 Vérif NaN
print("🔍 Vérification des NaN :")
print(f"  → y_test_real contient {np.isnan(y_test_real).sum()} NaN")
print(f"  → y_pred contient {np.isnan(y_pred).sum()} NaN")

# 🧹 Nettoyage
mask = ~np.isnan(y_test_real) & ~np.isnan(y_pred)
y_test_real_clean = y_test_real[mask]
y_pred_clean = y_pred[mask]

# 📈 Calcul des métriques
rmse = np.sqrt(mean_squared_error(y_test_real_clean, y_pred_clean))
r2 = r2_score(y_test_real_clean, y_pred_clean)

# 🧾 Résultats
print("\n✅ Évaluation sur le jeu de test :")
print(f"  → RMSE : {rmse:.2f}")
print(f"  → R²   : {r2:.4f}")
# Out:
# 🚀 Début de la recherche par grille...
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [0]	validation_0-rmse:1.10311
# [1]	validation_0-rmse:1.10171
# [2]	validation_0-rmse:1.09846
# [3]	validation_0-rmse:1.09491
# [4]	validation_0-rmse:1.09285
# [5]	validation_0-rmse:1.09025
# [6]	validation_0-rmse:1.08757
# [7]	validation_0-rmse:1.08580
# [0]	validation_0-rmse:1.09751
# [8]	validation_0-rmse:1.08330
# [1]	validation_0-rmse:1.09762
# [9]	validation_0-rmse:1.08228
# [0]	validation_0-rmse:1.09975
# [10]	validation_0-rmse:1.08127
# [2]	validation_0-rmse:1.09591
# [11]	validation_0-rmse:1.07815
# [1]	validation_0-rmse:1.09731
# [3]	validation_0-rmse:1.09287
# [12]	validation_0-rmse:1.07570
# [2]	validation_0-rmse:1.09587
# [13]	validation_0-rmse:1.07314
# [4]	validation_0-rmse:1.09287
# [3]	validation_0-rmse:1.09269
# [0]	validation_0-rmse:1.10079
# [14]	validation_0-rmse:1.07142
# [5]	validation_0-rmse:1.09065
# [1]	validation_0-rmse:1.09777
# [4]	validation_0-rmse:1.09019
# [15]	validation_0-rmse:1.07022
# [6]	validation_0-rmse:1.08957
# [2]	validation_0-rmse:1.09478
# [16]	validation_0-rmse:1.06745
# [5]	validation_0-rmse:1.08806
# [7]	validation_0-rmse:1.08671
# [17]	validation_0-rmse:1.06610
# [3]	validation_0-rmse:1.09177
# [8]	validation_0-rmse:1.08277
# [6]	validation_0-rmse:1.08585
# [18]	validation_0-rmse:1.06420[4]	validation_0-rmse:1.08850
#
# [9]	validation_0-rmse:1.08054
# [5]	validation_0-rmse:1.08582[7]	validation_0-rmse:1.08436
#
# [19]	validation_0-rmse:1.06161
# [10]	validation_0-rmse:1.07965[6]	validation_0-rmse:1.08293[8]	validation_0-rmse:1.08420
#
# [20]	validation_0-rmse:1.05927
#
# [9]	validation_0-rmse:1.08173
# [7]	validation_0-rmse:1.07974[0]	validation_0-rmse:1.09736
#
# [10]	validation_0-rmse:1.08086
# [21]	validation_0-rmse:1.05753
# [0]	validation_0-rmse:1.09737
# [8]	validation_0-rmse:1.07712
# [11]	validation_0-rmse:1.07757[11]	validation_0-rmse:1.08036
#
# [22]	validation_0-rmse:1.05587
# [12]	validation_0-rmse:1.07833[9]	validation_0-rmse:1.07431
# [12]	validation_0-rmse:1.07748[1]	validation_0-rmse:1.09639
#
#
# [23]	validation_0-rmse:1.05505
# [24]	validation_0-rmse:1.05265
# [13]	validation_0-rmse:1.07652
# [13]	validation_0-rmse:1.07737
# [2]	validation_0-rmse:1.09438[25]	validation_0-rmse:1.05031
#
# [14]	validation_0-rmse:1.07470
# [14]	validation_0-rmse:1.07551[10]	validation_0-rmse:1.07214
# [26]	validation_0-rmse:1.04937
#
# [3]	validation_0-rmse:1.09122
# [15]	validation_0-rmse:1.07463
# [27]	validation_0-rmse:1.04719
# [11]	validation_0-rmse:1.06934
# [1]	validation_0-rmse:1.09518
# [15]	validation_0-rmse:1.07397
# [16]	validation_0-rmse:1.07218
# [4]	validation_0-rmse:1.08933
# [28]	validation_0-rmse:1.04642
# [12]	validation_0-rmse:1.06659
# [17]	validation_0-rmse:1.07001[16]	validation_0-rmse:1.07317
#
# [13]	validation_0-rmse:1.06413
# [2]	validation_0-rmse:1.09305
# [29]	validation_0-rmse:1.04616
# [5]	validation_0-rmse:1.08611
# [18]	validation_0-rmse:1.07027
# [17]	validation_0-rmse:1.07179
# [30]	validation_0-rmse:1.04359
# [14]	validation_0-rmse:1.06145
# [6]	validation_0-rmse:1.08423
# [3]	validation_0-rmse:1.09041
# [19]	validation_0-rmse:1.06959
# [18]	validation_0-rmse:1.06969
# [31]	validation_0-rmse:1.04134
# [15]	validation_0-rmse:1.05944
# [7]	validation_0-rmse:1.08235
# [4]	validation_0-rmse:1.08782
# [20]	validation_0-rmse:1.06722
# [32]	validation_0-rmse:1.03903
# [19]	validation_0-rmse:1.06787
# [16]	validation_0-rmse:1.05682
# [8]	validation_0-rmse:1.07927
# [5]	validation_0-rmse:1.08541
# [21]	validation_0-rmse:1.06647
# [33]	validation_0-rmse:1.03735
# [20]	validation_0-rmse:1.06456
# [9]	validation_0-rmse:1.07744
# [6]	validation_0-rmse:1.08415
# [34]	validation_0-rmse:1.03722
# [22]	validation_0-rmse:1.06352
# [10]	validation_0-rmse:1.07620
# [21]	validation_0-rmse:1.06230
# [35]	validation_0-rmse:1.03502
# [23]	validation_0-rmse:1.06005
# [11]	validation_0-rmse:1.07314
# [7]	validation_0-rmse:1.08164
# [22]	validation_0-rmse:1.05987
# [36]	validation_0-rmse:1.03456
# [12]	validation_0-rmse:1.07173
# [24]	validation_0-rmse:1.05745
# [8]	validation_0-rmse:1.07958
# [23]	validation_0-rmse:1.05674
# [37]	validation_0-rmse:1.03379
# [13]	validation_0-rmse:1.07073
# [25]	validation_0-rmse:1.05409
# [24]	validation_0-rmse:1.05644
# [38]	validation_0-rmse:1.03201[14]	validation_0-rmse:1.06898
#
# [26]	validation_0-rmse:1.05132
# [15]	validation_0-rmse:1.06722
# [39]	validation_0-rmse:1.03139
# [27]	validation_0-rmse:1.04938
# [9]	validation_0-rmse:1.07835
# [25]	validation_0-rmse:1.05319
# [17]	validation_0-rmse:1.05471
# [16]	validation_0-rmse:1.06438
# [40]	validation_0-rmse:1.02938
# [10]	validation_0-rmse:1.07731
# [18]	validation_0-rmse:1.05242
# [26]	validation_0-rmse:1.05299
# [17]	validation_0-rmse:1.06265
# [41]	validation_0-rmse:1.02901
# [11]	validation_0-rmse:1.07499[19]	validation_0-rmse:1.04945
# [18]	validation_0-rmse:1.06098
# [28]	validation_0-rmse:1.04801[42]	validation_0-rmse:1.02812
#
# [27]	validation_0-rmse:1.05096[20]	validation_0-rmse:1.04715
# [19]	validation_0-rmse:1.05825
#
# [43]	validation_0-rmse:1.02635
# [29]	validation_0-rmse:1.04582
# [21]	validation_0-rmse:1.04424
# [44]	validation_0-rmse:1.02434
# [20]	validation_0-rmse:1.05557
# [12]	validation_0-rmse:1.07298
# [30]	validation_0-rmse:1.04397
# [45]	validation_0-rmse:1.02232
# [22]	validation_0-rmse:1.04138
#
# [21]	validation_0-rmse:1.05288
# [13]	validation_0-rmse:1.07234
# [31]	validation_0-rmse:1.04027
# [23]	validation_0-rmse:1.03895
# [22]	validation_0-rmse:1.05023
# [14]	validation_0-rmse:1.07118
# [0]	validation_0-rmse:1.10311
# [46]	validation_0-rmse:1.02058
# [32]	validation_0-rmse:1.03847
# [28]	validation_0-rmse:1.04994
# [15]	validation_0-rmse:1.06955
# [23]	validation_0-rmse:1.04767[24]	validation_0-rmse:1.03651
#
# [1]	validation_0-rmse:1.10171
# [33]	validation_0-rmse:1.03610[47]	validation_0-rmse:1.01885
# [16]	validation_0-rmse:1.06714[29]	validation_0-rmse:1.04843
#
# [25]	validation_0-rmse:1.03451[2]	validation_0-rmse:1.09846
#
#
# [24]	validation_0-rmse:1.04510
# [26]	validation_0-rmse:1.03231[48]	validation_0-rmse:1.01850
# [17]	validation_0-rmse:1.06569
# [3]	validation_0-rmse:1.09491[25]	validation_0-rmse:1.04248
#
#
# [30]	validation_0-rmse:1.04751
# [49]	validation_0-rmse:1.01695
# [18]	validation_0-rmse:1.06427
# [34]	validation_0-rmse:1.03395
# [27]	validation_0-rmse:1.02994[26]	validation_0-rmse:1.03997
#
# [50]	validation_0-rmse:1.01627
# [31]	validation_0-rmse:1.04631
# [19]	validation_0-rmse:1.06190
# [35]	validation_0-rmse:1.03165
# [28]	validation_0-rmse:1.02761
# [27]	validation_0-rmse:1.03752
# [51]	validation_0-rmse:1.01418
# [32]	validation_0-rmse:1.04331
# [36]	validation_0-rmse:1.03056
# [20]	validation_0-rmse:1.05957
# [29]	validation_0-rmse:1.02550
# [28]	validation_0-rmse:1.03589
# [52]	validation_0-rmse:1.01248
# [37]	validation_0-rmse:1.02872
# [33]	validation_0-rmse:1.04064
# [30]	validation_0-rmse:1.02323
# [53]	validation_0-rmse:1.01132
# [38]	validation_0-rmse:1.02804
# [31]	validation_0-rmse:1.02098
# [34]	validation_0-rmse:1.03901
# [54]	validation_0-rmse:1.00965[32]	validation_0-rmse:1.01877
# [39]	validation_0-rmse:1.02545
# [21]	validation_0-rmse:1.05767
#
# [35]	validation_0-rmse:1.03714[40]	validation_0-rmse:1.02339
# [55]	validation_0-rmse:1.00770
# [29]	validation_0-rmse:1.03347
# [0]	validation_0-rmse:1.09751[41]	validation_0-rmse:1.02181
#
#
# [56]	validation_0-rmse:1.00600
# [22]	validation_0-rmse:1.05580
# [42]	validation_0-rmse:1.02034
# [36]	validation_0-rmse:1.03721
# [57]	validation_0-rmse:1.00405
# [33]	validation_0-rmse:1.01667
# [30]	validation_0-rmse:1.03110
# [4]	validation_0-rmse:1.09285
# [43]	validation_0-rmse:1.02032
# [58]	validation_0-rmse:1.00229
# [37]	validation_0-rmse:1.03542
# [23]	validation_0-rmse:1.05447
# [34]	validation_0-rmse:1.01449
# [31]	validation_0-rmse:1.02882
# [44]	validation_0-rmse:1.01923
# [5]	validation_0-rmse:1.09025
# [59]	validation_0-rmse:1.00016
# [38]	validation_0-rmse:1.03350
# [35]	validation_0-rmse:1.01253
# [24]	validation_0-rmse:1.05264
# [45]	validation_0-rmse:1.01778
# [60]	validation_0-rmse:0.99790
# [32]	validation_0-rmse:1.02652
# [6]	validation_0-rmse:1.08757
# [39]	validation_0-rmse:1.03104
# [36]	validation_0-rmse:1.01056
# [61]	validation_0-rmse:0.99627
# [46]	validation_0-rmse:1.01618
# [7]	validation_0-rmse:1.08580
# [33]	validation_0-rmse:1.02419
# [40]	validation_0-rmse:1.02981
# [37]	validation_0-rmse:1.00862
# [47]	validation_0-rmse:1.01614
# [8]	validation_0-rmse:1.08330
# [34]	validation_0-rmse:1.02294
# [62]	validation_0-rmse:0.99483
# [38]	validation_0-rmse:1.00655
# [48]	validation_0-rmse:1.01497
# [9]	validation_0-rmse:1.08228
# [41]	validation_0-rmse:1.02753[35]	validation_0-rmse:1.02072
#
# [39]	validation_0-rmse:1.00451
# [63]	validation_0-rmse:0.99309
# [49]	validation_0-rmse:1.01486[10]	validation_0-rmse:1.08127
#
# [36]	validation_0-rmse:1.01979
# [64]	validation_0-rmse:0.99278
# [50]	validation_0-rmse:1.01390[37]	validation_0-rmse:1.01871
#
# [11]	validation_0-rmse:1.07815[1]	validation_0-rmse:1.09762
# [51]	validation_0-rmse:1.01297
# [38]	validation_0-rmse:1.01722
# [42]	validation_0-rmse:1.02725
# [65]	validation_0-rmse:0.99278
# [52]	validation_0-rmse:1.01107
# [2]	validation_0-rmse:1.09591
# [39]	validation_0-rmse:1.01511
# [66]	validation_0-rmse:0.99106
# [43]	validation_0-rmse:1.02550
# [53]	validation_0-rmse:1.01095
# [3]	validation_0-rmse:1.09287
# [40]	validation_0-rmse:1.01285
# [67]	validation_0-rmse:0.98835
# [44]	validation_0-rmse:1.02383
# [25]	validation_0-rmse:1.05041
# [54]	validation_0-rmse:1.00904
# [68]	validation_0-rmse:0.98709
# [41]	validation_0-rmse:1.01062
# [4]	validation_0-rmse:1.09287
# [45]	validation_0-rmse:1.02335
# [55]	validation_0-rmse:1.00868
# [26]	validation_0-rmse:1.04870
# [69]	validation_0-rmse:0.98634
# [42]	validation_0-rmse:1.00970
# [5]	validation_0-rmse:1.09065
# [40]	validation_0-rmse:1.00273
# [46]	validation_0-rmse:1.02203
# [56]	validation_0-rmse:1.00783
# [70]	validation_0-rmse:0.98323
# [6]	validation_0-rmse:1.08957
# [43]	validation_0-rmse:1.00762
# [47]	validation_0-rmse:1.02010
# [41]	validation_0-rmse:1.00033
# [57]	validation_0-rmse:1.00592
# [71]	validation_0-rmse:0.98215
# [44]	validation_0-rmse:1.00605
# [48]	validation_0-rmse:1.01892
# [42]	validation_0-rmse:0.99834
#
# [58]	validation_0-rmse:1.00417
# [72]	validation_0-rmse:0.98152
# [45]	validation_0-rmse:1.00478
# [43]	validation_0-rmse:0.99652
# [59]	validation_0-rmse:1.00358
# [12]	validation_0-rmse:1.07570
# [27]	validation_0-rmse:1.04609
# [73]	validation_0-rmse:0.97975
# [44]	validation_0-rmse:0.99492
# [46]	validation_0-rmse:1.00278
# [60]	validation_0-rmse:1.00266
# [74]	validation_0-rmse:0.97921[13]	validation_0-rmse:1.07314
#
# [28]	validation_0-rmse:1.04509
# [45]	validation_0-rmse:0.99315
# [47]	validation_0-rmse:1.00109
# [75]	validation_0-rmse:0.97638
# [14]	validation_0-rmse:1.07142
# [29]	validation_0-rmse:1.04272
# [49]	validation_0-rmse:1.01871
# [46]	validation_0-rmse:0.99140
# [48]	validation_0-rmse:0.99919
# [76]	validation_0-rmse:0.97474
# [15]	validation_0-rmse:1.07022
# [30]	validation_0-rmse:1.04016
# [61]	validation_0-rmse:0.99983
# [50]	validation_0-rmse:1.01829
# [49]	validation_0-rmse:0.99766[47]	validation_0-rmse:0.98951
#
# [16]	validation_0-rmse:1.06745
# [77]	validation_0-rmse:0.97476
# [31]	validation_0-rmse:1.03843
# [51]	validation_0-rmse:1.01639
# [62]	validation_0-rmse:0.99731
# [48]	validation_0-rmse:0.98799[50]	validation_0-rmse:0.99653
#
# [17]	validation_0-rmse:1.06610
# [78]	validation_0-rmse:0.97319
# [32]	validation_0-rmse:1.03591
# [63]	validation_0-rmse:0.99563
# [52]	validation_0-rmse:1.01470
# [49]	validation_0-rmse:0.98649
# [51]	validation_0-rmse:0.99449
# [79]	validation_0-rmse:0.97146
# [18]	validation_0-rmse:1.06420
# [33]	validation_0-rmse:1.03414
# [64]	validation_0-rmse:0.99477
# [53]	validation_0-rmse:1.01296[50]	validation_0-rmse:0.98477
#
# [52]	validation_0-rmse:0.99266
# [80]	validation_0-rmse:0.97048[7]	validation_0-rmse:1.08671
#
# [51]	validation_0-rmse:0.98311[54]	validation_0-rmse:1.01045
#
# [53]	validation_0-rmse:0.99087
# [55]	validation_0-rmse:1.00984[8]	validation_0-rmse:1.08277
# [34]	validation_0-rmse:1.03246
# [54]	validation_0-rmse:0.98893[52]	validation_0-rmse:0.98134
# [81]	validation_0-rmse:0.96767
#
# [9]	validation_0-rmse:1.08054[35]	validation_0-rmse:1.03000
# [53]	validation_0-rmse:0.97959
#
# [55]	validation_0-rmse:0.98719
# [19]	validation_0-rmse:1.06161
# [82]	validation_0-rmse:0.96789
# [36]	validation_0-rmse:1.02892
# [54]	validation_0-rmse:0.97812[56]	validation_0-rmse:0.98610
#
# [83]	validation_0-rmse:0.96672
# [20]	validation_0-rmse:1.05927[37]	validation_0-rmse:1.02811
#
# [57]	validation_0-rmse:0.98436[55]	validation_0-rmse:0.97641
#
# [84]	validation_0-rmse:0.96534[38]	validation_0-rmse:1.02625
#
# [10]	validation_0-rmse:1.07965
# [65]	validation_0-rmse:0.99415[56]	validation_0-rmse:0.97504
#
# [58]	validation_0-rmse:0.98256
# [85]	validation_0-rmse:0.96505
# [57]	validation_0-rmse:0.97369[11]	validation_0-rmse:1.07757
#
# [66]	validation_0-rmse:0.99434
# [59]	validation_0-rmse:0.98080
# [86]	validation_0-rmse:0.96346
# [58]	validation_0-rmse:0.97236[12]	validation_0-rmse:1.07748
# [67]	validation_0-rmse:0.99226
# [56]	validation_0-rmse:1.00711
#
# [87]	validation_0-rmse:0.96224
# [39]	validation_0-rmse:1.02383[68]	validation_0-rmse:0.98990
#
# [13]	validation_0-rmse:1.07652
# [60]	validation_0-rmse:0.97981
# [57]	validation_0-rmse:1.00468
# [88]	validation_0-rmse:0.96047
# [40]	validation_0-rmse:1.02181
# [61]	validation_0-rmse:0.97798
# [69]	validation_0-rmse:0.98829
# [89]	validation_0-rmse:0.95900
# [62]	validation_0-rmse:0.97675
# [70]	validation_0-rmse:0.98853
# [21]	validation_0-rmse:1.05753
# [90]	validation_0-rmse:0.95743
# [71]	validation_0-rmse:0.98749
# [63]	validation_0-rmse:0.97519
# [59]	validation_0-rmse:0.97073
# [22]	validation_0-rmse:1.05587
# [91]	validation_0-rmse:0.95712
# [72]	validation_0-rmse:0.98656
# [60]	validation_0-rmse:0.96911
# [64]	validation_0-rmse:0.97420
# [23]	validation_0-rmse:1.05505
# [41]	validation_0-rmse:1.02034
# [92]	validation_0-rmse:0.95620
#
# [73]	validation_0-rmse:0.98686
# [24]	validation_0-rmse:1.05265
# [93]	validation_0-rmse:0.95588
# [65]	validation_0-rmse:0.97265
# [58]	validation_0-rmse:1.00255
# [74]	validation_0-rmse:0.98402
# [42]	validation_0-rmse:1.01853
# [94]	validation_0-rmse:0.95456
# [25]	validation_0-rmse:1.05031
# [66]	validation_0-rmse:0.97163
# [95]	validation_0-rmse:0.95309[75]	validation_0-rmse:0.98297
# [14]	validation_0-rmse:1.07470
# [67]	validation_0-rmse:0.97048
# [43]	validation_0-rmse:1.01684
#
# [68]	validation_0-rmse:0.96898[96]	validation_0-rmse:0.95201
# [76]	validation_0-rmse:0.97979[44]	validation_0-rmse:1.01582
#
#
# [15]	validation_0-rmse:1.07463
# [45]	validation_0-rmse:1.01417
# [77]	validation_0-rmse:0.97728
# [97]	validation_0-rmse:0.95110
# [69]	validation_0-rmse:0.96801
# [61]	validation_0-rmse:0.96758
# [46]	validation_0-rmse:1.01182[78]	validation_0-rmse:0.97759
# [70]	validation_0-rmse:0.96711
# [98]	validation_0-rmse:0.94938
# [59]	validation_0-rmse:1.00132
# [79]	validation_0-rmse:0.97516[71]	validation_0-rmse:0.96612
#
# [62]	validation_0-rmse:0.96523
# [99]	validation_0-rmse:0.94793
# [72]	validation_0-rmse:0.96464
# [63]	validation_0-rmse:0.96395
# [60]	validation_0-rmse:0.99920
#
# [80]	validation_0-rmse:0.97407
# [73]	validation_0-rmse:0.96367
# [64]	validation_0-rmse:0.96262
# [61]	validation_0-rmse:0.99747
# [47]	validation_0-rmse:1.01067
# [81]	validation_0-rmse:0.97318
# [65]	validation_0-rmse:0.95930
# [74]	validation_0-rmse:0.96227
# [62]	validation_0-rmse:0.99631
# [48]	validation_0-rmse:1.00836
# [82]	validation_0-rmse:0.97143
# [66]	validation_0-rmse:0.95807
# [75]	validation_0-rmse:0.96075
# [63]	validation_0-rmse:0.99515
# [49]	validation_0-rmse:1.00738
# [83]	validation_0-rmse:0.97026
# [67]	validation_0-rmse:0.95660
# [76]	validation_0-rmse:0.95941
# [64]	validation_0-rmse:0.99417
# [50]	validation_0-rmse:1.00625
# [77]	validation_0-rmse:0.95812
# [65]	validation_0-rmse:0.99320
# [16]	validation_0-rmse:1.07218
# [78]	validation_0-rmse:0.95670
# [66]	validation_0-rmse:0.99310
# [17]	validation_0-rmse:1.07001[79]	validation_0-rmse:0.95527
# [84]	validation_0-rmse:0.96897
# [68]	validation_0-rmse:0.95524[80]	validation_0-rmse:0.95449
#
# [85]	validation_0-rmse:0.96666
# [69]	validation_0-rmse:0.95373[81]	validation_0-rmse:0.95299
#
# [86]	validation_0-rmse:0.96513
# [70]	validation_0-rmse:0.95234
# [82]	validation_0-rmse:0.95173
# [87]	validation_0-rmse:0.96300
# [83]	validation_0-rmse:0.95029
# [67]	validation_0-rmse:0.99193
# [84]	validation_0-rmse:0.94907[88]	validation_0-rmse:0.96049
#
#
# [68]	validation_0-rmse:0.99128
# [85]	validation_0-rmse:0.94784
# [51]	validation_0-rmse:1.00468
# [69]	validation_0-rmse:0.98992
# [18]	validation_0-rmse:1.07027
# [86]	validation_0-rmse:0.94644
# [52]	validation_0-rmse:1.00301
# [70]	validation_0-rmse:0.98841
# [87]	validation_0-rmse:0.94527
# [26]	validation_0-rmse:1.04937
# [88]	validation_0-rmse:0.94414
# [89]	validation_0-rmse:0.95901
# [71]	validation_0-rmse:0.98702
# [27]	validation_0-rmse:1.04719
# [71]	validation_0-rmse:0.95030
# [89]	validation_0-rmse:0.94319
# [28]	validation_0-rmse:1.04642
# [90]	validation_0-rmse:0.95783
# [53]	validation_0-rmse:1.00136
# [90]	validation_0-rmse:0.94193
# [29]	validation_0-rmse:1.04616
# [72]	validation_0-rmse:0.94882
# [91]	validation_0-rmse:0.95600
# [30]	validation_0-rmse:1.04359
# [73]	validation_0-rmse:0.94746
# [91]	validation_0-rmse:0.94083
# [72]	validation_0-rmse:0.98537
# [31]	validation_0-rmse:1.04134
# [92]	validation_0-rmse:0.93987[74]	validation_0-rmse:0.94618
#
# [92]	validation_0-rmse:0.95530
# [32]	validation_0-rmse:1.03903
# [75]	validation_0-rmse:0.94303
# [93]	validation_0-rmse:0.95345
# [19]	validation_0-rmse:1.06959
# [93]	validation_0-rmse:0.93863
# [54]	validation_0-rmse:1.00048
# [76]	validation_0-rmse:0.94179
# [94]	validation_0-rmse:0.95272
# [20]	validation_0-rmse:1.06722
# [77]	validation_0-rmse:0.94053
# [94]	validation_0-rmse:0.93735
# [95]	validation_0-rmse:0.95173
# [78]	validation_0-rmse:0.93929
# [95]	validation_0-rmse:0.93630
# [96]	validation_0-rmse:0.95014
# [79]	validation_0-rmse:0.93806
# [96]	validation_0-rmse:0.93528
# [97]	validation_0-rmse:0.94936
# [80]	validation_0-rmse:0.93686
# [97]	validation_0-rmse:0.93396
# [21]	validation_0-rmse:1.06647
# [81]	validation_0-rmse:0.93379[98]	validation_0-rmse:0.93297[98]	validation_0-rmse:0.94688
#
#
# [33]	validation_0-rmse:1.03735
# [99]	validation_0-rmse:0.93197
# [22]	validation_0-rmse:1.06352[99]	validation_0-rmse:0.94698
# [82]	validation_0-rmse:0.93262
#
# [55]	validation_0-rmse:0.99940
# [34]	validation_0-rmse:1.03722[83]	validation_0-rmse:0.93148
# [56]	validation_0-rmse:0.99846
#
# [84]	validation_0-rmse:0.93030
# [57]	validation_0-rmse:0.99621
# [23]	validation_0-rmse:1.06005[73]	validation_0-rmse:0.98408
#
# [58]	validation_0-rmse:0.99433
# [85]	validation_0-rmse:0.92914
# [35]	validation_0-rmse:1.03502
# [74]	validation_0-rmse:0.98258
# [86]	validation_0-rmse:0.92797
# [36]	validation_0-rmse:1.03456
# [75]	validation_0-rmse:0.98243
# [87]	validation_0-rmse:0.92682
# [37]	validation_0-rmse:1.03379
# [88]	validation_0-rmse:0.92384
# [76]	validation_0-rmse:0.98119
# [89]	validation_0-rmse:0.92272
# [59]	validation_0-rmse:0.99210
# [77]	validation_0-rmse:0.97973
# [24]	validation_0-rmse:1.05745
# [90]	validation_0-rmse:0.92160
# [60]	validation_0-rmse:0.99050
# [78]	validation_0-rmse:0.97743
# [25]	validation_0-rmse:1.05409
# [61]	validation_0-rmse:0.98866
# [26]	validation_0-rmse:1.05132
# [62]	validation_0-rmse:0.98709
# [27]	validation_0-rmse:1.04938
# [91]	validation_0-rmse:0.92051
# [63]	validation_0-rmse:0.98493
# [28]	validation_0-rmse:1.04801
# [64]	validation_0-rmse:0.98417
# [92]	validation_0-rmse:0.91944
# [29]	validation_0-rmse:1.04582
# [65]	validation_0-rmse:0.98203
# [93]	validation_0-rmse:0.91835
# [30]	validation_0-rmse:1.04397
# [66]	validation_0-rmse:0.98049
# [94]	validation_0-rmse:0.91729
# [31]	validation_0-rmse:1.04027
# [67]	validation_0-rmse:0.97840
# [32]	validation_0-rmse:1.03847
# [95]	validation_0-rmse:0.91598
# [68]	validation_0-rmse:0.97632
# [33]	validation_0-rmse:1.03610[96]	validation_0-rmse:0.91491
#
# [69]	validation_0-rmse:0.97481
# [97]	validation_0-rmse:0.91382
# [38]	validation_0-rmse:1.03201
# [98]	validation_0-rmse:0.91281
# [39]	validation_0-rmse:1.03139
# [99]	validation_0-rmse:0.91177
# [40]	validation_0-rmse:1.02938
# [70]	validation_0-rmse:0.97332
# [41]	validation_0-rmse:1.02901
# [71]	validation_0-rmse:0.97205
# [42]	validation_0-rmse:1.02812
# [79]	validation_0-rmse:0.97531
# [72]	validation_0-rmse:0.97119
# [43]	validation_0-rmse:1.02635
# [34]	validation_0-rmse:1.03395
# [80]	validation_0-rmse:0.97412
# [44]	validation_0-rmse:1.02434
# [35]	validation_0-rmse:1.03165
# [81]	validation_0-rmse:0.97208
# [45]	validation_0-rmse:1.02232
# [36]	validation_0-rmse:1.03056
# [82]	validation_0-rmse:0.97178
# [46]	validation_0-rmse:1.02058
# [83]	validation_0-rmse:0.97145
# [37]	validation_0-rmse:1.02872
# [73]	validation_0-rmse:0.96980
# [84]	validation_0-rmse:0.97013
# [38]	validation_0-rmse:1.02804
# [47]	validation_0-rmse:1.01885
# [85]	validation_0-rmse:0.96934
# [48]	validation_0-rmse:1.01850
# [39]	validation_0-rmse:1.02545
# [86]	validation_0-rmse:0.96746
# [49]	validation_0-rmse:1.01695
# [40]	validation_0-rmse:1.02339
# [50]	validation_0-rmse:1.01627
# [74]	validation_0-rmse:0.96825
# [41]	validation_0-rmse:1.02181
# [0]	validation_0-rmse:1.10079
# [51]	validation_0-rmse:1.01418
# [75]	validation_0-rmse:0.96657
# [1]	validation_0-rmse:1.09777
# [52]	validation_0-rmse:1.01248
# [42]	validation_0-rmse:1.02034
# [76]	validation_0-rmse:0.96459
# [2]	validation_0-rmse:1.09478
# [53]	validation_0-rmse:1.01132
# [43]	validation_0-rmse:1.02032
# [77]	validation_0-rmse:0.96349
# [54]	validation_0-rmse:1.00965
# [3]	validation_0-rmse:1.09177
# [44]	validation_0-rmse:1.01923
# [55]	validation_0-rmse:1.00770
# [4]	validation_0-rmse:1.08850
# [5]	validation_0-rmse:1.08582
# [78]	validation_0-rmse:0.96208
# [6]	validation_0-rmse:1.08293
# [87]	validation_0-rmse:0.96557
# [7]	validation_0-rmse:1.07974
# [79]	validation_0-rmse:0.96032
# [8]	validation_0-rmse:1.07712
# [88]	validation_0-rmse:0.96461
# [9]	validation_0-rmse:1.07431
# [89]	validation_0-rmse:0.96362
# [10]	validation_0-rmse:1.07214
# [90]	validation_0-rmse:0.96294
# [80]	validation_0-rmse:0.95960
# [11]	validation_0-rmse:1.06934
# [91]	validation_0-rmse:0.96212
# [81]	validation_0-rmse:0.95825
# [12]	validation_0-rmse:1.06659
# [92]	validation_0-rmse:0.96059
# [82]	validation_0-rmse:0.95688
# [13]	validation_0-rmse:1.06413
# [45]	validation_0-rmse:1.01778
# [14]	validation_0-rmse:1.06145
# [46]	validation_0-rmse:1.01618
# [15]	validation_0-rmse:1.05944
# [83]	validation_0-rmse:0.95526
# [16]	validation_0-rmse:1.05682
# [84]	validation_0-rmse:0.95452
# [0]	validation_0-rmse:1.09736
# [17]	validation_0-rmse:1.05471
# [85]	validation_0-rmse:0.95317
# [18]	validation_0-rmse:1.05242
# [86]	validation_0-rmse:0.95189
# [1]	validation_0-rmse:1.09518
# [19]	validation_0-rmse:1.04945[87]	validation_0-rmse:0.95097
#
# [20]	validation_0-rmse:1.04715[88]	validation_0-rmse:0.94967
#
# [0]	validation_0-rmse:1.09975
# [89]	validation_0-rmse:0.94822
# [21]	validation_0-rmse:1.04424
# [1]	validation_0-rmse:1.09731
# [90]	validation_0-rmse:0.94713
# [22]	validation_0-rmse:1.04138
# [2]	validation_0-rmse:1.09305[91]	validation_0-rmse:0.94532
# [2]	validation_0-rmse:1.09587
#
# [23]	validation_0-rmse:1.03895
# [56]	validation_0-rmse:1.00600
# [92]	validation_0-rmse:0.94406
# [3]	validation_0-rmse:1.09269
# [24]	validation_0-rmse:1.03651[3]	validation_0-rmse:1.09041
#
# [93]	validation_0-rmse:0.94291
# [4]	validation_0-rmse:1.09019
# [25]	validation_0-rmse:1.03451
# [57]	validation_0-rmse:1.00405
# [4]	validation_0-rmse:1.08782
# [26]	validation_0-rmse:1.03231
# [5]	validation_0-rmse:1.08806
# [5]	validation_0-rmse:1.08541
# [58]	validation_0-rmse:1.00229
# [27]	validation_0-rmse:1.02994
# [6]	validation_0-rmse:1.08415
# [6]	validation_0-rmse:1.08585
# [59]	validation_0-rmse:1.00016
# [7]	validation_0-rmse:1.08436
# [60]	validation_0-rmse:0.99790[28]	validation_0-rmse:1.02761
#
# [7]	validation_0-rmse:1.08164
# [93]	validation_0-rmse:0.95967
# [8]	validation_0-rmse:1.08420
# [94]	validation_0-rmse:0.94164
# [61]	validation_0-rmse:0.99627
# [29]	validation_0-rmse:1.02550
# [8]	validation_0-rmse:1.07958
# [94]	validation_0-rmse:0.95776
# [9]	validation_0-rmse:1.08173
# [9]	validation_0-rmse:1.07835
# [30]	validation_0-rmse:1.02323
# [95]	validation_0-rmse:0.95713[10]	validation_0-rmse:1.08086
# [95]	validation_0-rmse:0.94064
# [10]	validation_0-rmse:1.07731
# [31]	validation_0-rmse:1.02098
# [11]	validation_0-rmse:1.08036[47]	validation_0-rmse:1.01614
# [11]	validation_0-rmse:1.07499
#
# [32]	validation_0-rmse:1.01877
# [12]	validation_0-rmse:1.07298[96]	validation_0-rmse:0.93880
#
# [48]	validation_0-rmse:1.01497[12]	validation_0-rmse:1.07833
#
# [33]	validation_0-rmse:1.01667
# [13]	validation_0-rmse:1.07234[97]	validation_0-rmse:0.93793
# [13]	validation_0-rmse:1.07737
# [49]	validation_0-rmse:1.01486
#
# [34]	validation_0-rmse:1.01449
# [98]	validation_0-rmse:0.93672[50]	validation_0-rmse:1.01390[14]	validation_0-rmse:1.07551
#
# [14]	validation_0-rmse:1.07118
# [35]	validation_0-rmse:1.01253
# [15]	validation_0-rmse:1.06955
# [51]	validation_0-rmse:1.01297[15]	validation_0-rmse:1.07397
#
# [36]	validation_0-rmse:1.01056
#
# [16]	validation_0-rmse:1.06714
# [52]	validation_0-rmse:1.01107
# [16]	validation_0-rmse:1.07317
# [37]	validation_0-rmse:1.00862
#
# [17]	validation_0-rmse:1.06569
# [17]	validation_0-rmse:1.07179
# [99]	validation_0-rmse:0.93592
# [38]	validation_0-rmse:1.00655
# [18]	validation_0-rmse:1.06427[96]	validation_0-rmse:0.95575
# [18]	validation_0-rmse:1.06969
#
# [39]	validation_0-rmse:1.00451
# [19]	validation_0-rmse:1.06787
# [19]	validation_0-rmse:1.06190[97]	validation_0-rmse:0.95419
#
# [40]	validation_0-rmse:1.00273
# [20]	validation_0-rmse:1.06456
# [98]	validation_0-rmse:0.95234[41]	validation_0-rmse:1.00033
#
# [20]	validation_0-rmse:1.05957
# [42]	validation_0-rmse:0.99834[21]	validation_0-rmse:1.05767
# [21]	validation_0-rmse:1.06230
#
# [22]	validation_0-rmse:1.05580
# [22]	validation_0-rmse:1.05987
# [43]	validation_0-rmse:0.99652
# [23]	validation_0-rmse:1.05447
# [23]	validation_0-rmse:1.05674
# [44]	validation_0-rmse:0.99492
# [24]	validation_0-rmse:1.05264
# [45]	validation_0-rmse:0.99315
# [24]	validation_0-rmse:1.05644
# [25]	validation_0-rmse:1.05041
# [46]	validation_0-rmse:0.99140
# [25]	validation_0-rmse:1.05319
# [26]	validation_0-rmse:1.04870
# [26]	validation_0-rmse:1.05299
# [47]	validation_0-rmse:0.98951
# [62]	validation_0-rmse:0.99483
# [27]	validation_0-rmse:1.04609[48]	validation_0-rmse:0.98799
#
# [27]	validation_0-rmse:1.05096
# [63]	validation_0-rmse:0.99309
# [28]	validation_0-rmse:1.04994
# [49]	validation_0-rmse:0.98649
# [28]	validation_0-rmse:1.04509
# [64]	validation_0-rmse:0.99278
# [29]	validation_0-rmse:1.04843
# [50]	validation_0-rmse:0.98477
# [29]	validation_0-rmse:1.04272
# [65]	validation_0-rmse:0.99278
# [30]	validation_0-rmse:1.04751[51]	validation_0-rmse:0.98311
#
# [66]	validation_0-rmse:0.99106
# [30]	validation_0-rmse:1.04016
# [99]	validation_0-rmse:0.95185
# [52]	validation_0-rmse:0.98134
# [31]	validation_0-rmse:1.04631
# [67]	validation_0-rmse:0.98835
# [31]	validation_0-rmse:1.03843
# [53]	validation_0-rmse:0.97959
# [68]	validation_0-rmse:0.98709
# [54]	validation_0-rmse:0.97812[32]	validation_0-rmse:1.04331
#
# [32]	validation_0-rmse:1.03591
# [69]	validation_0-rmse:0.98634[55]	validation_0-rmse:0.97641
# [33]	validation_0-rmse:1.03414
# [33]	validation_0-rmse:1.04064
# [56]	validation_0-rmse:0.97504[34]	validation_0-rmse:1.03246
#
# [34]	validation_0-rmse:1.03901
# [57]	validation_0-rmse:0.97369
# [35]	validation_0-rmse:1.03000
# [58]	validation_0-rmse:0.97236[35]	validation_0-rmse:1.03714
#
# [36]	validation_0-rmse:1.02892[36]	validation_0-rmse:1.03721
# [59]	validation_0-rmse:0.97073
#
# [37]	validation_0-rmse:1.02811[60]	validation_0-rmse:0.96911
#
# [37]	validation_0-rmse:1.03542
# [61]	validation_0-rmse:0.96758
# [38]	validation_0-rmse:1.03350
# [38]	validation_0-rmse:1.02625[62]	validation_0-rmse:0.96523
#
# [53]	validation_0-rmse:1.01095
# [39]	validation_0-rmse:1.03104
# [63]	validation_0-rmse:0.96395[39]	validation_0-rmse:1.02383
# [54]	validation_0-rmse:1.00904
# [40]	validation_0-rmse:1.02981
#
# [40]	validation_0-rmse:1.02181
# [55]	validation_0-rmse:1.00868
# [41]	validation_0-rmse:1.02753
# [64]	validation_0-rmse:0.96262
# [41]	validation_0-rmse:1.02034
# [56]	validation_0-rmse:1.00783
# [42]	validation_0-rmse:1.02725
# [65]	validation_0-rmse:0.95930
# [42]	validation_0-rmse:1.01853
# [57]	validation_0-rmse:1.00592
# [43]	validation_0-rmse:1.02550
# [66]	validation_0-rmse:0.95807
# [43]	validation_0-rmse:1.01684
# [44]	validation_0-rmse:1.02383
# [67]	validation_0-rmse:0.95660
# [44]	validation_0-rmse:1.01582[0]	validation_0-rmse:1.09737
#
# [68]	validation_0-rmse:0.95524
# [45]	validation_0-rmse:1.02335
#
# [1]	validation_0-rmse:1.09639
# [69]	validation_0-rmse:0.95373[45]	validation_0-rmse:1.01417
# [46]	validation_0-rmse:1.02203
#
# [2]	validation_0-rmse:1.09438
# [46]	validation_0-rmse:1.01182
# [47]	validation_0-rmse:1.02010
# [70]	validation_0-rmse:0.95234
# [3]	validation_0-rmse:1.09122
# [47]	validation_0-rmse:1.01067
# [48]	validation_0-rmse:1.01892
# [71]	validation_0-rmse:0.95030
# [48]	validation_0-rmse:1.00836
# [4]	validation_0-rmse:1.08933
# [49]	validation_0-rmse:1.01871
# [72]	validation_0-rmse:0.94882
# [50]	validation_0-rmse:1.01829
# [70]	validation_0-rmse:0.98323
# [73]	validation_0-rmse:0.94746
# [49]	validation_0-rmse:1.00738
# [74]	validation_0-rmse:0.94618[50]	validation_0-rmse:1.00625
#
# [71]	validation_0-rmse:0.98215
# [51]	validation_0-rmse:1.01639
# [51]	validation_0-rmse:1.00468
# [75]	validation_0-rmse:0.94303
# [76]	validation_0-rmse:0.94179[52]	validation_0-rmse:1.00301
#
# [52]	validation_0-rmse:1.01470
# [77]	validation_0-rmse:0.94053
# [5]	validation_0-rmse:1.08611
# [53]	validation_0-rmse:1.01296[78]	validation_0-rmse:0.93929
# [6]	validation_0-rmse:1.08423
#
# [7]	validation_0-rmse:1.08235
# [79]	validation_0-rmse:0.93806
# [54]	validation_0-rmse:1.01045
# [80]	validation_0-rmse:0.93686
# [8]	validation_0-rmse:1.07927
# [81]	validation_0-rmse:0.93379[9]	validation_0-rmse:1.07744
#
# [55]	validation_0-rmse:1.00984
# [10]	validation_0-rmse:1.07620
# [82]	validation_0-rmse:0.93262
# [83]	validation_0-rmse:0.93148[11]	validation_0-rmse:1.07314
#
# [72]	validation_0-rmse:0.98152
# [56]	validation_0-rmse:1.00711
# [12]	validation_0-rmse:1.07173
# [84]	validation_0-rmse:0.93030
# [0]	validation_0-rmse:1.10283
# [73]	validation_0-rmse:0.97975
# [57]	validation_0-rmse:1.00468
# [13]	validation_0-rmse:1.07073
# [85]	validation_0-rmse:0.92914
# [53]	validation_0-rmse:1.00136
# [74]	validation_0-rmse:0.97921
# [1]	validation_0-rmse:1.10102
# [58]	validation_0-rmse:1.00255
# [86]	validation_0-rmse:0.92797
# [75]	validation_0-rmse:0.97638
# [54]	validation_0-rmse:1.00048
# [2]	validation_0-rmse:1.09769
# [87]	validation_0-rmse:0.92682
# [59]	validation_0-rmse:1.00132
# [55]	validation_0-rmse:0.99940
# [88]	validation_0-rmse:0.92384
# [3]	validation_0-rmse:1.09397
# [60]	validation_0-rmse:0.99920
# [89]	validation_0-rmse:0.92272
# [56]	validation_0-rmse:0.99846
# [58]	validation_0-rmse:1.00417
# [61]	validation_0-rmse:0.99747
# [90]	validation_0-rmse:0.92160
# [57]	validation_0-rmse:0.99621
# [59]	validation_0-rmse:1.00358
# [62]	validation_0-rmse:0.99631
# [91]	validation_0-rmse:0.92051
# [58]	validation_0-rmse:0.99433
# [60]	validation_0-rmse:1.00266
# [4]	validation_0-rmse:1.09194
# [92]	validation_0-rmse:0.91944
# [63]	validation_0-rmse:0.99515
# [59]	validation_0-rmse:0.99210
# [61]	validation_0-rmse:0.99983
# [5]	validation_0-rmse:1.08935
# [93]	validation_0-rmse:0.91835
# [64]	validation_0-rmse:0.99417
# [60]	validation_0-rmse:0.99050
# [94]	validation_0-rmse:0.91729
# [62]	validation_0-rmse:0.99731
# [6]	validation_0-rmse:1.08668
# [65]	validation_0-rmse:0.99320
# [95]	validation_0-rmse:0.91598
# [61]	validation_0-rmse:0.98866
# [63]	validation_0-rmse:0.99563
# [7]	validation_0-rmse:1.08492[96]	validation_0-rmse:0.91491
# [62]	validation_0-rmse:0.98709
# [64]	validation_0-rmse:0.99477
# [66]	validation_0-rmse:0.99310
# [97]	validation_0-rmse:0.91382
# [63]	validation_0-rmse:0.98493
# [76]	validation_0-rmse:0.97474
# [67]	validation_0-rmse:0.99193
# [98]	validation_0-rmse:0.91281
# [64]	validation_0-rmse:0.98417
# [77]	validation_0-rmse:0.97476
# [68]	validation_0-rmse:0.99128
# [65]	validation_0-rmse:0.98203
# [99]	validation_0-rmse:0.91177[78]	validation_0-rmse:0.97319
#
# [79]	validation_0-rmse:0.97146
# [100]	validation_0-rmse:0.90894
# [80]	validation_0-rmse:0.97048
# [101]	validation_0-rmse:0.90791
# [14]	validation_0-rmse:1.06898
# [81]	validation_0-rmse:0.96767
# [102]	validation_0-rmse:0.90688
# [15]	validation_0-rmse:1.06722
# [103]	validation_0-rmse:0.90587
# [16]	validation_0-rmse:1.06438
#
# [104]	validation_0-rmse:0.90464
# [17]	validation_0-rmse:1.06265
# [105]	validation_0-rmse:0.90366
# [8]	validation_0-rmse:1.08242[18]	validation_0-rmse:1.06098
#
# [106]	validation_0-rmse:0.90268
# [19]	validation_0-rmse:1.05825
# [107]	validation_0-rmse:0.90173
# [9]	validation_0-rmse:1.08126
# [108]	validation_0-rmse:0.90079[10]	validation_0-rmse:1.08022
#
# [66]	validation_0-rmse:0.98049[109]	validation_0-rmse:0.89982
# [11]	validation_0-rmse:1.07704[20]	validation_0-rmse:1.05557
# [69]	validation_0-rmse:0.98992
# [110]	validation_0-rmse:0.89885
# [21]	validation_0-rmse:1.05288
# [70]	validation_0-rmse:0.98841
#
# [111]	validation_0-rmse:0.89793
# [22]	validation_0-rmse:1.05023
# [71]	validation_0-rmse:0.98702
# [112]	validation_0-rmse:0.89678
# [23]	validation_0-rmse:1.04767
# [12]	validation_0-rmse:1.07448
# [113]	validation_0-rmse:0.89578
# [72]	validation_0-rmse:0.98537
# [24]	validation_0-rmse:1.04510
# [13]	validation_0-rmse:1.07158
# [114]	validation_0-rmse:0.89479
# [73]	validation_0-rmse:0.98408
# [25]	validation_0-rmse:1.04248
# [115]	validation_0-rmse:0.89390
# [26]	validation_0-rmse:1.03997
# [74]	validation_0-rmse:0.98258
# [116]	validation_0-rmse:0.89298
# [75]	validation_0-rmse:0.98243
# [117]	validation_0-rmse:0.89210
# [67]	validation_0-rmse:0.97840
# [14]	validation_0-rmse:1.06981
# [118]	validation_0-rmse:0.88945
# [68]	validation_0-rmse:0.97632
# [119]	validation_0-rmse:0.88859
# [15]	validation_0-rmse:1.06860
# [69]	validation_0-rmse:0.97481
# [82]	validation_0-rmse:0.96789
# [120]	validation_0-rmse:0.88776
# [76]	validation_0-rmse:0.98119
# [70]	validation_0-rmse:0.97332
# [16]	validation_0-rmse:1.06567
# [121]	validation_0-rmse:0.88682
# [83]	validation_0-rmse:0.96672
# [77]	validation_0-rmse:0.97973
# [71]	validation_0-rmse:0.97205
# [122]	validation_0-rmse:0.88500
# [17]	validation_0-rmse:1.06423
# [84]	validation_0-rmse:0.96534
# [78]	validation_0-rmse:0.97743
# [72]	validation_0-rmse:0.97119
# [123]	validation_0-rmse:0.88419
#
# [85]	validation_0-rmse:0.96505
# [79]	validation_0-rmse:0.97531
# [124]	validation_0-rmse:0.88328
# [86]	validation_0-rmse:0.96346
# [80]	validation_0-rmse:0.97412
# [18]	validation_0-rmse:1.06217
# [125]	validation_0-rmse:0.88248
# [27]	validation_0-rmse:1.03752
# [126]	validation_0-rmse:0.88170[87]	validation_0-rmse:0.96224
#
# [19]	validation_0-rmse:1.06067
# [73]	validation_0-rmse:0.96980
# [81]	validation_0-rmse:0.97208
# [127]	validation_0-rmse:0.88088
# [88]	validation_0-rmse:0.96047
# [65]	validation_0-rmse:0.99415
# [20]	validation_0-rmse:1.05839
# [128]	validation_0-rmse:0.88012
# [74]	validation_0-rmse:0.96825[82]	validation_0-rmse:0.97178
#
# [89]	validation_0-rmse:0.95900
# [129]	validation_0-rmse:0.87922
# [66]	validation_0-rmse:0.99434
# [75]	validation_0-rmse:0.96657
# [83]	validation_0-rmse:0.97145
# [130]	validation_0-rmse:0.87668
# [67]	validation_0-rmse:0.99226
# [76]	validation_0-rmse:0.96459[21]	validation_0-rmse:1.05622
# [68]	validation_0-rmse:0.98990
# [131]	validation_0-rmse:0.87594
# [28]	validation_0-rmse:1.03589
# [132]	validation_0-rmse:0.87520
# [84]	validation_0-rmse:0.97013
# [69]	validation_0-rmse:0.98829
# [22]	validation_0-rmse:1.05444
# [29]	validation_0-rmse:1.03347
# [133]	validation_0-rmse:0.87433
# [85]	validation_0-rmse:0.96934
# [70]	validation_0-rmse:0.98853
# [30]	validation_0-rmse:1.03110
# [134]	validation_0-rmse:0.87264
# [71]	validation_0-rmse:0.98749
# [86]	validation_0-rmse:0.96746
# [135]	validation_0-rmse:0.87181
# [31]	validation_0-rmse:1.02882
# [87]	validation_0-rmse:0.96557
# [32]	validation_0-rmse:1.02652
# [136]	validation_0-rmse:0.87086
# [88]	validation_0-rmse:0.96461
# [33]	validation_0-rmse:1.02419
# [23]	validation_0-rmse:1.05345
#
# [137]	validation_0-rmse:0.87003
# [138]	validation_0-rmse:0.86922
# [77]	validation_0-rmse:0.96349
# [89]	validation_0-rmse:0.96362
# [139]	validation_0-rmse:0.86679
# [78]	validation_0-rmse:0.96208
# [0]	validation_0-rmse:1.09662
# [90]	validation_0-rmse:0.96294
# [24]	validation_0-rmse:1.05067
# [140]	validation_0-rmse:0.86599
# [79]	validation_0-rmse:0.96032
# [91]	validation_0-rmse:0.96212
# [1]	validation_0-rmse:1.09680
# [141]	validation_0-rmse:0.86515
# [80]	validation_0-rmse:0.95960[2]	validation_0-rmse:1.09511[142]	validation_0-rmse:0.86439
# [34]	validation_0-rmse:1.02294
# [25]	validation_0-rmse:1.04805
# [92]	validation_0-rmse:0.96059
# [143]	validation_0-rmse:0.86275
# [35]	validation_0-rmse:1.02072
# [144]	validation_0-rmse:0.86195
# [93]	validation_0-rmse:0.95967
# [36]	validation_0-rmse:1.01979
# [145]	validation_0-rmse:0.86125
# [94]	validation_0-rmse:0.95776
# [37]	validation_0-rmse:1.01871
# [26]	validation_0-rmse:1.04701
# [146]	validation_0-rmse:0.86062
# [95]	validation_0-rmse:0.95713
# [38]	validation_0-rmse:1.01722
# [147]	validation_0-rmse:0.85994
# [148]	validation_0-rmse:0.85922
# [39]	validation_0-rmse:1.01511
# [149]	validation_0-rmse:0.85852
# [27]	validation_0-rmse:1.04475
# [40]	validation_0-rmse:1.01285
#
# [96]	validation_0-rmse:0.95575
# [150]	validation_0-rmse:0.85774
#
# [28]	validation_0-rmse:1.04360
# [151]	validation_0-rmse:0.85702
# [81]	validation_0-rmse:0.95825
# [97]	validation_0-rmse:0.95419
# [152]	validation_0-rmse:0.85638
# [29]	validation_0-rmse:1.04328[82]	validation_0-rmse:0.95688
#
# [153]	validation_0-rmse:0.85575
# [98]	validation_0-rmse:0.95234
# [90]	validation_0-rmse:0.95743
# [3]	validation_0-rmse:1.09207
# [83]	validation_0-rmse:0.95526
# [30]	validation_0-rmse:1.04074
# [154]	validation_0-rmse:0.85509
# [99]	validation_0-rmse:0.95185
# [91]	validation_0-rmse:0.95712
# [84]	validation_0-rmse:0.95452
# [4]	validation_0-rmse:1.09186[155]	validation_0-rmse:0.85438
#
# [31]	validation_0-rmse:1.03829
# [100]	validation_0-rmse:0.94981
# [92]	validation_0-rmse:0.95620
# [85]	validation_0-rmse:0.95317
# [156]	validation_0-rmse:0.85309
# [101]	validation_0-rmse:0.94811
# [5]	validation_0-rmse:1.08938
# [93]	validation_0-rmse:0.95588
# [32]	validation_0-rmse:1.03599
# [86]	validation_0-rmse:0.95189
# [157]	validation_0-rmse:0.85244
# [94]	validation_0-rmse:0.95456
# [6]	validation_0-rmse:1.08830
# [102]	validation_0-rmse:0.94775
# [87]	validation_0-rmse:0.95097
# [33]	validation_0-rmse:1.03436
# [158]	validation_0-rmse:0.85181
# [103]	validation_0-rmse:0.94623
# [88]	validation_0-rmse:0.94967
# [7]	validation_0-rmse:1.08544
# [159]	validation_0-rmse:0.85056
# [34]	validation_0-rmse:1.03411
# [104]	validation_0-rmse:0.94481
# [89]	validation_0-rmse:0.94822
# [160]	validation_0-rmse:0.84989
# [8]	validation_0-rmse:1.08151
# [35]	validation_0-rmse:1.03168
# [72]	validation_0-rmse:0.98656
# [161]	validation_0-rmse:0.84921
# [90]	validation_0-rmse:0.94713[105]	validation_0-rmse:0.94399
#
# [162]	validation_0-rmse:0.84860
# [91]	validation_0-rmse:0.94532
# [73]	validation_0-rmse:0.98686
# [106]	validation_0-rmse:0.94253
# [163]	validation_0-rmse:0.84738
# [92]	validation_0-rmse:0.94406
# [74]	validation_0-rmse:0.98402[107]	validation_0-rmse:0.94232
#
# [36]	validation_0-rmse:1.03093
# [164]	validation_0-rmse:0.84672
# [93]	validation_0-rmse:0.94291
# [75]	validation_0-rmse:0.98297
# [108]	validation_0-rmse:0.93973
# [165]	validation_0-rmse:0.84609
# [37]	validation_0-rmse:1.02982
# [41]	validation_0-rmse:1.01062
# [76]	validation_0-rmse:0.97979
# [166]	validation_0-rmse:0.84464
# [109]	validation_0-rmse:0.93898
# [38]	validation_0-rmse:1.02805
# [42]	validation_0-rmse:1.00970
# [167]	validation_0-rmse:0.84406
# [77]	validation_0-rmse:0.97728[110]	validation_0-rmse:0.93751
#
# [43]	validation_0-rmse:1.00762
# [39]	validation_0-rmse:1.02712
# [168]	validation_0-rmse:0.84303
# [111]	validation_0-rmse:0.93682
# [44]	validation_0-rmse:1.00605
# [169]	validation_0-rmse:0.84163
# [112]	validation_0-rmse:0.93594
# [40]	validation_0-rmse:1.02512
# [45]	validation_0-rmse:1.00478
# [170]	validation_0-rmse:0.84025
# [113]	validation_0-rmse:0.93486
# [46]	validation_0-rmse:1.00278
# [171]	validation_0-rmse:0.83951
# [114]	validation_0-rmse:0.93431
# [47]	validation_0-rmse:1.00109
# [172]	validation_0-rmse:0.83895
# [78]	validation_0-rmse:0.97759
# [95]	validation_0-rmse:0.95309
# [173]	validation_0-rmse:0.83842
# [94]	validation_0-rmse:0.94164
# [41]	validation_0-rmse:1.02476
# [174]	validation_0-rmse:0.83790
# [96]	validation_0-rmse:0.95201
# [115]	validation_0-rmse:0.93245
# [175]	validation_0-rmse:0.83726
# [97]	validation_0-rmse:0.95110
# [48]	validation_0-rmse:0.99919
# [176]	validation_0-rmse:0.83676
# [79]	validation_0-rmse:0.97516
# [116]	validation_0-rmse:0.93134
# [98]	validation_0-rmse:0.94938[9]	validation_0-rmse:1.07920
#
# [49]	validation_0-rmse:0.99766
# [42]	validation_0-rmse:1.02300
# [177]	validation_0-rmse:0.83603
# [80]	validation_0-rmse:0.97407
# [117]	validation_0-rmse:0.92910
# [99]	validation_0-rmse:0.94793
# [50]	validation_0-rmse:0.99653
# [10]	validation_0-rmse:1.07758
# [178]	validation_0-rmse:0.83554
# [81]	validation_0-rmse:0.97318
# [118]	validation_0-rmse:0.92830
# [100]	validation_0-rmse:0.94567
# [51]	validation_0-rmse:0.99449
# [179]	validation_0-rmse:0.83511
# [82]	validation_0-rmse:0.97143
# [11]	validation_0-rmse:1.07474
# [101]	validation_0-rmse:0.94430
# [119]	validation_0-rmse:0.92627
# [52]	validation_0-rmse:0.99266
# [180]	validation_0-rmse:0.83465
# [83]	validation_0-rmse:0.97026
# [43]	validation_0-rmse:1.02112
# [120]	validation_0-rmse:0.92536
# [53]	validation_0-rmse:0.99087
# [12]	validation_0-rmse:1.07466
# [181]	validation_0-rmse:0.83404
# [121]	validation_0-rmse:0.92463
# [44]	validation_0-rmse:1.01902
# [54]	validation_0-rmse:0.98893
# [182]	validation_0-rmse:0.83364
# [13]	validation_0-rmse:1.07319
# [183]	validation_0-rmse:0.83325
# [45]	validation_0-rmse:1.01709
# [14]	validation_0-rmse:1.07190
# [95]	validation_0-rmse:0.94064
# [184]	validation_0-rmse:0.83263
# [46]	validation_0-rmse:1.01515
# [96]	validation_0-rmse:0.93880
# [185]	validation_0-rmse:0.83070
# [15]	validation_0-rmse:1.07184
# [97]	validation_0-rmse:0.93793
# [186]	validation_0-rmse:0.83033
# [47]	validation_0-rmse:1.01347
# [98]	validation_0-rmse:0.93672
# [187]	validation_0-rmse:0.82991
# [48]	validation_0-rmse:1.01302
# [188]	validation_0-rmse:0.82914
# [99]	validation_0-rmse:0.93592
# [49]	validation_0-rmse:1.01143
# [84]	validation_0-rmse:0.96897
# [189]	validation_0-rmse:0.82726
# [100]	validation_0-rmse:0.93409
# [190]	validation_0-rmse:0.82604
# [50]	validation_0-rmse:1.01032[101]	validation_0-rmse:0.93324
#
# [191]	validation_0-rmse:0.82420
# [102]	validation_0-rmse:0.93206
# [51]	validation_0-rmse:1.00815
# [103]	validation_0-rmse:0.93142[192]	validation_0-rmse:0.82360
# [55]	validation_0-rmse:0.98719[193]	validation_0-rmse:0.82322
# [52]	validation_0-rmse:1.00624
#
# [85]	validation_0-rmse:0.96666[194]	validation_0-rmse:0.82291
#
# [122]	validation_0-rmse:0.92312[56]	validation_0-rmse:0.98610
#
# [102]	validation_0-rmse:0.94333
# [53]	validation_0-rmse:1.00502
# [195]	validation_0-rmse:0.82190
# [196]	validation_0-rmse:0.82128
# [16]	validation_0-rmse:1.06852[57]	validation_0-rmse:0.98436
#
# [103]	validation_0-rmse:0.94190
# [54]	validation_0-rmse:1.00321
# [123]	validation_0-rmse:0.92191
#
# [197]	validation_0-rmse:0.82092
# [86]	validation_0-rmse:0.96513
# [58]	validation_0-rmse:0.98256
# [104]	validation_0-rmse:0.93964
# [55]	validation_0-rmse:1.00125
# [124]	validation_0-rmse:0.92201
# [17]	validation_0-rmse:1.06637
# [198]	validation_0-rmse:0.81995
# [104]	validation_0-rmse:0.93059
# [105]	validation_0-rmse:0.93824
# [87]	validation_0-rmse:0.96300
# [56]	validation_0-rmse:0.99913
# [199]	validation_0-rmse:0.81934
# [125]	validation_0-rmse:0.92099
# [59]	validation_0-rmse:0.98080
# [18]	validation_0-rmse:1.06660
# [105]	validation_0-rmse:0.92944
# [106]	validation_0-rmse:0.93685
# [88]	validation_0-rmse:0.96049
# [57]	validation_0-rmse:0.99730
# [126]	validation_0-rmse:0.92005
# [106]	validation_0-rmse:0.92829
# [60]	validation_0-rmse:0.97981
# [107]	validation_0-rmse:0.93443
# [19]	validation_0-rmse:1.06592
# [89]	validation_0-rmse:0.95901
# [127]	validation_0-rmse:0.91922[107]	validation_0-rmse:0.92749
# [58]	validation_0-rmse:0.99543
# [61]	validation_0-rmse:0.97798
#
# [108]	validation_0-rmse:0.93364
# [20]	validation_0-rmse:1.06366
# [108]	validation_0-rmse:0.92689
# [109]	validation_0-rmse:0.93352
# [62]	validation_0-rmse:0.97675
# [59]	validation_0-rmse:0.99336
# [109]	validation_0-rmse:0.92636[21]	validation_0-rmse:1.06292
#
# [128]	validation_0-rmse:0.91800
# [63]	validation_0-rmse:0.97519
# [60]	validation_0-rmse:0.99114
# [90]	validation_0-rmse:0.95783[110]	validation_0-rmse:0.92524
# [22]	validation_0-rmse:1.06002
# [129]	validation_0-rmse:0.91749
#
# [61]	validation_0-rmse:0.98945
# [64]	validation_0-rmse:0.97420
# [111]	validation_0-rmse:0.92414
# [23]	validation_0-rmse:1.05657
# [130]	validation_0-rmse:0.91691
# [65]	validation_0-rmse:0.97265
# [24]	validation_0-rmse:1.05271
# [112]	validation_0-rmse:0.92304
# [66]	validation_0-rmse:0.97163
# [131]	validation_0-rmse:0.91617
# [25]	validation_0-rmse:1.04934
# [67]	validation_0-rmse:0.97048
# [113]	validation_0-rmse:0.92225
# [132]	validation_0-rmse:0.91477
# [68]	validation_0-rmse:0.96898
# [26]	validation_0-rmse:1.04659
# [133]	validation_0-rmse:0.91474
# [110]	validation_0-rmse:0.93204
# [69]	validation_0-rmse:0.96801
# [134]	validation_0-rmse:0.91335
# [114]	validation_0-rmse:0.92164
# [70]	validation_0-rmse:0.96711
# [27]	validation_0-rmse:1.04467
# [111]	validation_0-rmse:0.93079
# [71]	validation_0-rmse:0.96612
# [135]	validation_0-rmse:0.91271
# [115]	validation_0-rmse:0.92108
# [112]	validation_0-rmse:0.93009
# [28]	validation_0-rmse:1.04332
# [72]	validation_0-rmse:0.96464
# [136]	validation_0-rmse:0.91200
# [116]	validation_0-rmse:0.92001
# [113]	validation_0-rmse:0.92936
# [29]	validation_0-rmse:1.04115
# [73]	validation_0-rmse:0.96367
# [117]	validation_0-rmse:0.91895
# [137]	validation_0-rmse:0.91082
# [114]	validation_0-rmse:0.92789
# [62]	validation_0-rmse:0.98782
# [74]	validation_0-rmse:0.96227
# [30]	validation_0-rmse:1.03887
# [138]	validation_0-rmse:0.91017
# [118]	validation_0-rmse:0.91791
# [115]	validation_0-rmse:0.92697
# [75]	validation_0-rmse:0.96075[119]	validation_0-rmse:0.91690
# [63]	validation_0-rmse:0.98592
# [31]	validation_0-rmse:1.03496
#
# [139]	validation_0-rmse:0.90946
# [120]	validation_0-rmse:0.91591
# [76]	validation_0-rmse:0.95941[140]	validation_0-rmse:0.90850
# [64]	validation_0-rmse:0.98551
# [121]	validation_0-rmse:0.91538
# [141]	validation_0-rmse:0.90646
#
# [65]	validation_0-rmse:0.98550
# [142]	validation_0-rmse:0.90592
# [122]	validation_0-rmse:0.91405
# [91]	validation_0-rmse:0.95600
# [66]	validation_0-rmse:0.98369[32]	validation_0-rmse:1.03304
#
# [143]	validation_0-rmse:0.90454
# [123]	validation_0-rmse:0.91340
# [92]	validation_0-rmse:0.95530
# [67]	validation_0-rmse:0.98101
# [144]	validation_0-rmse:0.90420
# [33]	validation_0-rmse:1.03069
# [124]	validation_0-rmse:0.91275
# [93]	validation_0-rmse:0.95345
# [145]	validation_0-rmse:0.90396
# [68]	validation_0-rmse:0.97932
# [125]	validation_0-rmse:0.91174
# [146]	validation_0-rmse:0.90310[94]	validation_0-rmse:0.95272
# [69]	validation_0-rmse:0.97869
# [126]	validation_0-rmse:0.91077
#
# [77]	validation_0-rmse:0.95812[127]	validation_0-rmse:0.91030
#
# [147]	validation_0-rmse:0.90232
# [116]	validation_0-rmse:0.92610
# [95]	validation_0-rmse:0.95173[70]	validation_0-rmse:0.97565
#
# [128]	validation_0-rmse:0.90931
# [148]	validation_0-rmse:0.90179
# [117]	validation_0-rmse:0.92485
# [78]	validation_0-rmse:0.95670[71]	validation_0-rmse:0.97460
#
# [96]	validation_0-rmse:0.95014
# [129]	validation_0-rmse:0.90859
# [149]	validation_0-rmse:0.90016
# [79]	validation_0-rmse:0.95527
# [130]	validation_0-rmse:0.90813
# [97]	validation_0-rmse:0.94936
# [150]	validation_0-rmse:0.89939[80]	validation_0-rmse:0.95449
#
# [131]	validation_0-rmse:0.90749
# [98]	validation_0-rmse:0.94688
# [151]	validation_0-rmse:0.89880
# [81]	validation_0-rmse:0.95299
# [72]	validation_0-rmse:0.97406
# [34]	validation_0-rmse:1.02847
# [132]	validation_0-rmse:0.90621
# [99]	validation_0-rmse:0.94698[152]	validation_0-rmse:0.89804
#
# [82]	validation_0-rmse:0.95173
# [133]	validation_0-rmse:0.90551
# [73]	validation_0-rmse:0.97224
# [35]	validation_0-rmse:1.02508
# [153]	validation_0-rmse:0.89763
# [100]	validation_0-rmse:0.94586
# [83]	validation_0-rmse:0.95029
# [134]	validation_0-rmse:0.90454
# [74]	validation_0-rmse:0.97198
# [36]	validation_0-rmse:1.02392
# [154]	validation_0-rmse:0.89691
# [101]	validation_0-rmse:0.94438
# [135]	validation_0-rmse:0.90410
# [84]	validation_0-rmse:0.94907
# [75]	validation_0-rmse:0.96919[136]	validation_0-rmse:0.90336
# [102]	validation_0-rmse:0.94288
#
# [85]	validation_0-rmse:0.94784[37]	validation_0-rmse:1.02188
#
# [155]	validation_0-rmse:0.89627
# [137]	validation_0-rmse:0.90241
# [103]	validation_0-rmse:0.94166
# [76]	validation_0-rmse:0.96761
# [118]	validation_0-rmse:0.92284
# [138]	validation_0-rmse:0.90169[86]	validation_0-rmse:0.94644
# [38]	validation_0-rmse:1.02120
# [77]	validation_0-rmse:0.96761
#
# [119]	validation_0-rmse:0.92161
# [104]	validation_0-rmse:0.94019
# [156]	validation_0-rmse:0.89612
# [87]	validation_0-rmse:0.94527
# [120]	validation_0-rmse:0.92124
# [39]	validation_0-rmse:1.01851
# [105]	validation_0-rmse:0.93867
# [157]	validation_0-rmse:0.89544
# [88]	validation_0-rmse:0.94414
# [121]	validation_0-rmse:0.91986
# [78]	validation_0-rmse:0.96588
# [106]	validation_0-rmse:0.93746
# [158]	validation_0-rmse:0.89515
# [40]	validation_0-rmse:1.01647
# [89]	validation_0-rmse:0.94319
# [122]	validation_0-rmse:0.91798
# [79]	validation_0-rmse:0.96387
# [159]	validation_0-rmse:0.89437
# [107]	validation_0-rmse:0.93626
# [139]	validation_0-rmse:0.90101
# ...
# [16]	validation_0-rmse:0.80975
# [2]	validation_0-rmse:1.02642
# [21]	validation_0-rmse:0.76365
# [188]	validation_0-rmse:0.80132
# [22]	validation_0-rmse:0.74716
# [17]	validation_0-rmse:0.80004
# [3]	validation_0-rmse:0.99663
# [189]	validation_0-rmse:0.80076
# [23]	validation_0-rmse:0.74321
# [24]	validation_0-rmse:0.74122
# [4]	validation_0-rmse:0.97567
# [190]	validation_0-rmse:0.80018
# [18]	validation_0-rmse:0.79187
# [25]	validation_0-rmse:0.73750
# [5]	validation_0-rmse:0.95882
# [191]	validation_0-rmse:0.79969
# [19]	validation_0-rmse:0.78590
# [20]	validation_0-rmse:0.78238
# [6]	validation_0-rmse:0.94185
# [192]	validation_0-rmse:0.79883
# [26]	validation_0-rmse:0.73275
# [7]	validation_0-rmse:0.92945
# [21]	validation_0-rmse:0.76365
# [0]	validation_0-rmse:1.06728[193]	validation_0-rmse:0.79822
#
# [8]	validation_0-rmse:0.91836
# [1]	validation_0-rmse:1.06805
# [22]	validation_0-rmse:0.74716
# [194]	validation_0-rmse:0.79762
# [9]	validation_0-rmse:0.90679
# [27]	validation_0-rmse:0.72983
# [2]	validation_0-rmse:1.05288
# [10]	validation_0-rmse:0.89022
# [23]	validation_0-rmse:0.74321
# [3]	validation_0-rmse:1.02595
# [195]	validation_0-rmse:0.79716
# [28]	validation_0-rmse:0.72902
# [11]	validation_0-rmse:0.87896
# [4]	validation_0-rmse:1.02720
# [24]	validation_0-rmse:0.74122
# [12]	validation_0-rmse:0.87076
# [5]	validation_0-rmse:1.00667
# [196]	validation_0-rmse:0.79637
# [13]	validation_0-rmse:0.86160
# [29]	validation_0-rmse:0.72212
# [6]	validation_0-rmse:1.00185
# [25]	validation_0-rmse:0.73750
# [14]	validation_0-rmse:0.85477
# [7]	validation_0-rmse:0.98181
# [15]	validation_0-rmse:0.84798
# [197]	validation_0-rmse:0.79559
# [30]	validation_0-rmse:0.72043
# [8]	validation_0-rmse:0.97045
# [26]	validation_0-rmse:0.73275
# [16]	validation_0-rmse:0.84072
# [9]	validation_0-rmse:0.95933
# [17]	validation_0-rmse:0.83542
# [198]	validation_0-rmse:0.79514
# [10]	validation_0-rmse:0.94458
# [31]	validation_0-rmse:0.71470
# [18]	validation_0-rmse:0.83326
# [27]	validation_0-rmse:0.72983
# [19]	validation_0-rmse:0.83153[11]	validation_0-rmse:0.92316
#
# [28]	validation_0-rmse:0.72902
# [199]	validation_0-rmse:0.79439
# [12]	validation_0-rmse:0.92298
# [20]	validation_0-rmse:0.82374
# [32]	validation_0-rmse:0.71355
# [21]	validation_0-rmse:0.81499[13]	validation_0-rmse:0.89628
#
# [29]	validation_0-rmse:0.72212
# [14]	validation_0-rmse:0.88331
# [22]	validation_0-rmse:0.79959
# [33]	validation_0-rmse:0.71195
# [23]	validation_0-rmse:0.79606
# [30]	validation_0-rmse:0.72043
# [15]	validation_0-rmse:0.88236
# [24]	validation_0-rmse:0.79543
# [34]	validation_0-rmse:0.71229
# [31]	validation_0-rmse:0.71470
# [25]	validation_0-rmse:0.78286
# [35]	validation_0-rmse:0.70772
# [26]	validation_0-rmse:0.78294
# [16]	validation_0-rmse:0.86282
# [27]	validation_0-rmse:0.77289[32]	validation_0-rmse:0.71355
#
# [36]	validation_0-rmse:0.70657
# [28]	validation_0-rmse:0.76498
# [37]	validation_0-rmse:0.70625
# [29]	validation_0-rmse:0.76565
# [17]	validation_0-rmse:0.85554
# [33]	validation_0-rmse:0.71195
# [30]	validation_0-rmse:0.75905
# [38]	validation_0-rmse:0.70612
# [34]	validation_0-rmse:0.71229
# [31]	validation_0-rmse:0.76000
# [18]	validation_0-rmse:0.85936
# [39]	validation_0-rmse:0.70670
# [32]	validation_0-rmse:0.75208
# [35]	validation_0-rmse:0.70772
# [40]	validation_0-rmse:0.70359
# [19]	validation_0-rmse:0.86081
# [33]	validation_0-rmse:0.74459
# [41]	validation_0-rmse:0.70454
# [36]	validation_0-rmse:0.70657
# [34]	validation_0-rmse:0.73951
# [42]	validation_0-rmse:0.70424
# [35]	validation_0-rmse:0.74074
# [37]	validation_0-rmse:0.70625
# [20]	validation_0-rmse:0.84899
# [36]	validation_0-rmse:0.72877
# [43]	validation_0-rmse:0.70569
# [38]	validation_0-rmse:0.70612
# [37]	validation_0-rmse:0.72840
# [21]	validation_0-rmse:0.85047
# [38]	validation_0-rmse:0.72467
# [39]	validation_0-rmse:0.70670[44]	validation_0-rmse:0.70599
#
# [39]	validation_0-rmse:0.71716
# [45]	validation_0-rmse:0.70157
# [40]	validation_0-rmse:0.70359
# [22]	validation_0-rmse:0.84036
# [40]	validation_0-rmse:0.71000
# [46]	validation_0-rmse:0.70157
# [23]	validation_0-rmse:0.83044
# [41]	validation_0-rmse:0.70760
# [41]	validation_0-rmse:0.70454
# [47]	validation_0-rmse:0.70158
# [24]	validation_0-rmse:0.80573
# [42]	validation_0-rmse:0.70591
# [42]	validation_0-rmse:0.70424
# [48]	validation_0-rmse:0.70159
# [49]	validation_0-rmse:0.70160
# [25]	validation_0-rmse:0.80073
# [43]	validation_0-rmse:0.70082
# [50]	validation_0-rmse:0.70160
# [43]	validation_0-rmse:0.70569
# [51]	validation_0-rmse:0.70161
# [26]	validation_0-rmse:0.79379
# [44]	validation_0-rmse:0.69897
# [52]	validation_0-rmse:0.70161
# [44]	validation_0-rmse:0.70599
# [53]	validation_0-rmse:0.70162
# [45]	validation_0-rmse:0.69587
# [54]	validation_0-rmse:0.70162
# [27]	validation_0-rmse:0.78227
# [55]	validation_0-rmse:0.70162
# [46]	validation_0-rmse:0.69210
# [56]	validation_0-rmse:0.70163
# [57]	validation_0-rmse:0.70163
# [45]	validation_0-rmse:0.70157
# [28]	validation_0-rmse:0.78209
# [47]	validation_0-rmse:0.68917
# [58]	validation_0-rmse:0.70163
# [48]	validation_0-rmse:0.69046
# [29]	validation_0-rmse:0.77063
# [59]	validation_0-rmse:0.70163
# [46]	validation_0-rmse:0.70157
# [49]	validation_0-rmse:0.68923
# [60]	validation_0-rmse:0.70164
# [50]	validation_0-rmse:0.68923
# [47]	validation_0-rmse:0.70158
# [30]	validation_0-rmse:0.75367
# [61]	validation_0-rmse:0.70164
# [51]	validation_0-rmse:0.68923
# [62]	validation_0-rmse:0.70164
# [31]	validation_0-rmse:0.74792[48]	validation_0-rmse:0.70159
#
# [63]	validation_0-rmse:0.70164
# [52]	validation_0-rmse:0.68923
# [64]	validation_0-rmse:0.70164
# [32]	validation_0-rmse:0.72924
# [53]	validation_0-rmse:0.68923
# [49]	validation_0-rmse:0.70160
# [65]	validation_0-rmse:0.70164
# [54]	validation_0-rmse:0.68923
# [33]	validation_0-rmse:0.72245
# [50]	validation_0-rmse:0.70160
# [55]	validation_0-rmse:0.68923
# [56]	validation_0-rmse:0.68923
# [34]	validation_0-rmse:0.71751
# [51]	validation_0-rmse:0.70161
# [57]	validation_0-rmse:0.68923
# [58]	validation_0-rmse:0.68923
# [35]	validation_0-rmse:0.70005
# [52]	validation_0-rmse:0.70161
# [59]	validation_0-rmse:0.68923
# [60]	validation_0-rmse:0.68923
# [36]	validation_0-rmse:0.68840
# [53]	validation_0-rmse:0.70162
# [61]	validation_0-rmse:0.68923
# [54]	validation_0-rmse:0.70162
# [62]	validation_0-rmse:0.68923
# [37]	validation_0-rmse:0.68518
# [63]	validation_0-rmse:0.68923
# [55]	validation_0-rmse:0.70162
# [38]	validation_0-rmse:0.68829
# [64]	validation_0-rmse:0.68923
# [65]	validation_0-rmse:0.68923
# [56]	validation_0-rmse:0.70163
# [39]	validation_0-rmse:0.67742
# [66]	validation_0-rmse:0.68923
# [57]	validation_0-rmse:0.70163
# [40]	validation_0-rmse:0.66962
# [58]	validation_0-rmse:0.70163
# [41]	validation_0-rmse:0.66597
# [59]	validation_0-rmse:0.70163
# [60]	validation_0-rmse:0.70164
# [42]	validation_0-rmse:0.65808
# [61]	validation_0-rmse:0.70164
# [43]	validation_0-rmse:0.65962
# [62]	validation_0-rmse:0.70164
# [63]	validation_0-rmse:0.70164
# [44]	validation_0-rmse:0.65952
# [64]	validation_0-rmse:0.70164
# [65]	validation_0-rmse:0.70164
# [45]	validation_0-rmse:0.65016
# [46]	validation_0-rmse:0.64208
# [47]	validation_0-rmse:0.64616
# [48]	validation_0-rmse:0.64363
# [49]	validation_0-rmse:0.64184
# [50]	validation_0-rmse:0.63791
# [51]	validation_0-rmse:0.63056
# [52]	validation_0-rmse:0.62680
# [53]	validation_0-rmse:0.62747
# [54]	validation_0-rmse:0.61612
# [55]	validation_0-rmse:0.62062
# [56]	validation_0-rmse:0.62051
# [57]	validation_0-rmse:0.61678
# [58]	validation_0-rmse:0.61678
# [59]	validation_0-rmse:0.61339
# [60]	validation_0-rmse:0.61626
# [61]	validation_0-rmse:0.61310
# [62]	validation_0-rmse:0.60984
# [63]	validation_0-rmse:0.60769
# [64]	validation_0-rmse:0.60926
# [65]	validation_0-rmse:0.60791
# [66]	validation_0-rmse:0.60654
# [67]	validation_0-rmse:0.60652
# [68]	validation_0-rmse:0.60740
# [69]	validation_0-rmse:0.60439
# [70]	validation_0-rmse:0.60649
# [71]	validation_0-rmse:0.60478
# [72]	validation_0-rmse:0.60475
# [73]	validation_0-rmse:0.60453
# [74]	validation_0-rmse:0.60348
# [75]	validation_0-rmse:0.60308
# [76]	validation_0-rmse:0.59695
# [77]	validation_0-rmse:0.59695
# [78]	validation_0-rmse:0.59759
# [79]	validation_0-rmse:0.59429
# [80]	validation_0-rmse:0.59463
# [81]	validation_0-rmse:0.59030
# [82]	validation_0-rmse:0.58537
# [83]	validation_0-rmse:0.58201
# [84]	validation_0-rmse:0.58231
# [85]	validation_0-rmse:0.57725
# [86]	validation_0-rmse:0.57733
# [87]	validation_0-rmse:0.57740
# [88]	validation_0-rmse:0.57714
# [89]	validation_0-rmse:0.57708
# [90]	validation_0-rmse:0.57330
# [91]	validation_0-rmse:0.57310
# [92]	validation_0-rmse:0.57521
# [93]	validation_0-rmse:0.57304
# [94]	validation_0-rmse:0.57304
# [95]	validation_0-rmse:0.57158
# [96]	validation_0-rmse:0.56602
# [97]	validation_0-rmse:0.56797
# [98]	validation_0-rmse:0.56291
# [99]	validation_0-rmse:0.56431
# [100]	validation_0-rmse:0.56485
# [101]	validation_0-rmse:0.56360
# [102]	validation_0-rmse:0.56356
# [103]	validation_0-rmse:0.56408
# [104]	validation_0-rmse:0.56404
# [105]	validation_0-rmse:0.56401
# [106]	validation_0-rmse:0.56113
# [107]	validation_0-rmse:0.56126
# [108]	validation_0-rmse:0.55731
# [109]	validation_0-rmse:0.55802
# [110]	validation_0-rmse:0.55820
# [111]	validation_0-rmse:0.55814
# [112]	validation_0-rmse:0.55904
# [113]	validation_0-rmse:0.55978
# [114]	validation_0-rmse:0.55982
# [115]	validation_0-rmse:0.55986
# [116]	validation_0-rmse:0.55987
# [117]	validation_0-rmse:0.55964
# [118]	validation_0-rmse:0.56329
# [119]	validation_0-rmse:0.56288
# [120]	validation_0-rmse:0.56285
# [121]	validation_0-rmse:0.56292
# [122]	validation_0-rmse:0.56244
# [123]	validation_0-rmse:0.56253
# [124]	validation_0-rmse:0.56253
# [125]	validation_0-rmse:0.56263
# [126]	validation_0-rmse:0.56043
# [127]	validation_0-rmse:0.56043
# [0]	validation_0-rmse:1.09382
# [1]	validation_0-rmse:1.09002
# [2]	validation_0-rmse:1.08635
# [3]	validation_0-rmse:1.08131
# [4]	validation_0-rmse:1.07682
# [5]	validation_0-rmse:1.07320
# [6]	validation_0-rmse:1.06957
# [7]	validation_0-rmse:1.06529
# [8]	validation_0-rmse:1.06199
# [9]	validation_0-rmse:1.05846
# [10]	validation_0-rmse:1.05549
# [11]	validation_0-rmse:1.05089
# [12]	validation_0-rmse:1.04735
# [13]	validation_0-rmse:1.04408
# [14]	validation_0-rmse:1.04069
# [15]	validation_0-rmse:1.03618
# [16]	validation_0-rmse:1.03284
# [17]	validation_0-rmse:1.02980
# [18]	validation_0-rmse:1.02505
# [19]	validation_0-rmse:1.02037
# [20]	validation_0-rmse:1.01728
# [21]	validation_0-rmse:1.01284
# [22]	validation_0-rmse:1.00830
# [23]	validation_0-rmse:1.00524
# [24]	validation_0-rmse:1.00198
# [25]	validation_0-rmse:0.99884
# [26]	validation_0-rmse:0.99634
# [27]	validation_0-rmse:0.99333
# [28]	validation_0-rmse:0.99057
# [29]	validation_0-rmse:0.98764
# [30]	validation_0-rmse:0.98474
# [31]	validation_0-rmse:0.98178
# [32]	validation_0-rmse:0.97895
# [33]	validation_0-rmse:0.97618
# [34]	validation_0-rmse:0.97350
# [35]	validation_0-rmse:0.97083
# [36]	validation_0-rmse:0.96848
# [37]	validation_0-rmse:0.96597
# [38]	validation_0-rmse:0.96322
# [39]	validation_0-rmse:0.96058
# [40]	validation_0-rmse:0.95846
# [41]	validation_0-rmse:0.95472
# [42]	validation_0-rmse:0.95203
# [43]	validation_0-rmse:0.94973
# [44]	validation_0-rmse:0.94714
# [45]	validation_0-rmse:0.94489
# [46]	validation_0-rmse:0.94257
# [47]	validation_0-rmse:0.94054
# [48]	validation_0-rmse:0.93795
# [49]	validation_0-rmse:0.93566
# [50]	validation_0-rmse:0.93359
# [51]	validation_0-rmse:0.93146
# [52]	validation_0-rmse:0.92918
# [53]	validation_0-rmse:0.92674
# [54]	validation_0-rmse:0.92470
# [55]	validation_0-rmse:0.92229
# [56]	validation_0-rmse:0.91994
# [57]	validation_0-rmse:0.91757
# [58]	validation_0-rmse:0.91583
# [59]	validation_0-rmse:0.91372
# [60]	validation_0-rmse:0.91159
# [61]	validation_0-rmse:0.90816
# [62]	validation_0-rmse:0.90465
# [63]	validation_0-rmse:0.90240
# [64]	validation_0-rmse:0.90060
# [65]	validation_0-rmse:0.89655
# [66]	validation_0-rmse:0.89459
# [67]	validation_0-rmse:0.89119
# [68]	validation_0-rmse:0.88730
# [69]	validation_0-rmse:0.88531
# [70]	validation_0-rmse:0.88240
# [71]	validation_0-rmse:0.87922
# [72]	validation_0-rmse:0.87724
# [73]	validation_0-rmse:0.87421
# [74]	validation_0-rmse:0.87219
# [75]	validation_0-rmse:0.86893
# [76]	validation_0-rmse:0.86552
# [77]	validation_0-rmse:0.86365
# [78]	validation_0-rmse:0.86183
# [79]	validation_0-rmse:0.86025
# [80]	validation_0-rmse:0.85852
# [81]	validation_0-rmse:0.85499
# [82]	validation_0-rmse:0.85144
# [83]	validation_0-rmse:0.84839
# [84]	validation_0-rmse:0.84686
# [85]	validation_0-rmse:0.84315
# [86]	validation_0-rmse:0.84144
# [87]	validation_0-rmse:0.83979
# [88]	validation_0-rmse:0.83597
# [89]	validation_0-rmse:0.83447
# [90]	validation_0-rmse:0.83284
# [91]	validation_0-rmse:0.83140
# [92]	validation_0-rmse:0.82976
# [93]	validation_0-rmse:0.82652
# [94]	validation_0-rmse:0.82520
# [95]	validation_0-rmse:0.82360
# [96]	validation_0-rmse:0.81993
# [97]	validation_0-rmse:0.81688
# [98]	validation_0-rmse:0.81350
# [99]	validation_0-rmse:0.81212
# [100]	validation_0-rmse:0.80855
# [101]	validation_0-rmse:0.80699
# [102]	validation_0-rmse:0.80377
# [103]	validation_0-rmse:0.80238
# [104]	validation_0-rmse:0.80098
# [105]	validation_0-rmse:0.79967
# [106]	validation_0-rmse:0.79821
# [107]	validation_0-rmse:0.79673
# [108]	validation_0-rmse:0.79545
# [109]	validation_0-rmse:0.79238
# [110]	validation_0-rmse:0.79090
# [111]	validation_0-rmse:0.78950
# [112]	validation_0-rmse:0.78809
# [113]	validation_0-rmse:0.78537
# [114]	validation_0-rmse:0.78420
# [115]	validation_0-rmse:0.78300
# [116]	validation_0-rmse:0.77973
# [117]	validation_0-rmse:0.77853
# [118]	validation_0-rmse:0.77526
# [119]	validation_0-rmse:0.77407
# [120]	validation_0-rmse:0.77288
# [121]	validation_0-rmse:0.77176
# [122]	validation_0-rmse:0.76848
# [123]	validation_0-rmse:0.76723
# [124]	validation_0-rmse:0.76615
# [125]	validation_0-rmse:0.76506
# [126]	validation_0-rmse:0.76401
# [127]	validation_0-rmse:0.76290
# [128]	validation_0-rmse:0.76173
# [129]	validation_0-rmse:0.75867
# [130]	validation_0-rmse:0.75557
# [131]	validation_0-rmse:0.75457
# [132]	validation_0-rmse:0.75144
# [133]	validation_0-rmse:0.74839
# [134]	validation_0-rmse:0.74556
# [135]	validation_0-rmse:0.74252
# [136]	validation_0-rmse:0.74148
# [137]	validation_0-rmse:0.73860
# [138]	validation_0-rmse:0.73765
# [139]	validation_0-rmse:0.73490
# [140]	validation_0-rmse:0.73211
# [141]	validation_0-rmse:0.72943
# [142]	validation_0-rmse:0.72707
# [143]	validation_0-rmse:0.72516
# [144]	validation_0-rmse:0.72247
# [145]	validation_0-rmse:0.71981
# [146]	validation_0-rmse:0.71909
# [147]	validation_0-rmse:0.71826
# [148]	validation_0-rmse:0.71563
# [149]	validation_0-rmse:0.71311
# [150]	validation_0-rmse:0.71021
# [151]	validation_0-rmse:0.70765
# [152]	validation_0-rmse:0.70511
# [153]	validation_0-rmse:0.70250
# [154]	validation_0-rmse:0.70000
# [155]	validation_0-rmse:0.69740
# [156]	validation_0-rmse:0.69494
# [157]	validation_0-rmse:0.69250
# [158]	validation_0-rmse:0.68992
# [159]	validation_0-rmse:0.68740
# [160]	validation_0-rmse:0.68658
# [161]	validation_0-rmse:0.68404
# [162]	validation_0-rmse:0.68169
# [163]	validation_0-rmse:0.67936
# [164]	validation_0-rmse:0.67690
# [165]	validation_0-rmse:0.67602
# [166]	validation_0-rmse:0.67373
# [167]	validation_0-rmse:0.67146
# [168]	validation_0-rmse:0.66923
# [169]	validation_0-rmse:0.66686
# [170]	validation_0-rmse:0.66465
# [171]	validation_0-rmse:0.66234
# [172]	validation_0-rmse:0.66018
# [173]	validation_0-rmse:0.65821
# [174]	validation_0-rmse:0.65577
# [175]	validation_0-rmse:0.65340
# [176]	validation_0-rmse:0.65108
# [177]	validation_0-rmse:0.65047
# [178]	validation_0-rmse:0.64820
# [179]	validation_0-rmse:0.64616
# [180]	validation_0-rmse:0.64396
# [181]	validation_0-rmse:0.64330
# [182]	validation_0-rmse:0.64130
# [183]	validation_0-rmse:0.63907
# [184]	validation_0-rmse:0.63682
# [185]	validation_0-rmse:0.63473
# [186]	validation_0-rmse:0.63273
# [187]	validation_0-rmse:0.63066
# [188]	validation_0-rmse:0.62982
# [189]	validation_0-rmse:0.62779
# [190]	validation_0-rmse:0.62578
# [191]	validation_0-rmse:0.62418
# [192]	validation_0-rmse:0.62233
# [193]	validation_0-rmse:0.62028
# [194]	validation_0-rmse:0.61816
# [195]	validation_0-rmse:0.61627
# [196]	validation_0-rmse:0.61444
# [197]	validation_0-rmse:0.61241
# [198]	validation_0-rmse:0.61050
# [199]	validation_0-rmse:0.60872
# 🕒 Temps total de recherche: 0.07 minutes
# 🏆 Meilleurs hyperparamètres trouvés :
#   colsample_bytree: 0.7
#   learning_rate: 0.01
#   max_depth: 7
#   n_estimators: 200
#   subsample: 1.0
# 💡 Meilleur score (neg_mean_squared_error): 0.9144
# 🔍 Vérification des NaN :
#   → y_test_real contient 1574 NaN
#   → y_pred contient 0 NaN
#
# ✅ Évaluation sur le jeu de test :
#   → RMSE : 290.78
#   → R²   : -0.0729

# %%
# Vérifier les valeurs réelles
print("Valeurs de box_office_reels:")
print(box_office_reels.tolist())

# Convertir les valeurs réelles avec gestion des séparateurs de milliers
def convert_to_float(x):
    if pd.isna(x) or x == '-' or x == 'nan':
        return np.nan
    try:
        # Remplacer les espaces et les virgules par rien
        if isinstance(x, str):
            x = x.replace(' ', '').replace(',', '')
        return float(x)
    except (ValueError, TypeError):
        print(f"Impossible de convertir '{x}' en nombre")
        return np.nan

# Utiliser la fonction de conversion
y_real = pd.Series(box_office_reels).apply(convert_to_float)
print("Valeurs converties:")
print(y_real.tolist())

# Appliquer une transformation logarithmique sur les valeurs non-nulles
y_real_log = np.log1p(y_real)

# Créer un masque pour identifier les films avec des valeurs réelles valides
mask_real_values = ~pd.isna(y_real)
print(f"Nombre de films avec box office connu: {mask_real_values.sum()}")

if mask_real_values.sum() > 0:
    print(f"Utilisation de {mask_real_values.sum()} films avec box office connu pour estimer les autres")
    
    # Créer un modèle simple
    from sklearn.ensemble import RandomForestRegressor
    
    # Préparer les données pour un modèle simple
    X_simple = pd.DataFrame(index=df_test.index)
    
    # Extraire les features clés
    for feature in ['budget', 'duree_minutes', 'mois_sortie', 'annee_sortie']:
        if feature in df_test.columns:
            X_simple[feature] = pd.to_numeric(df_test[feature], errors='coerce')
    
    # Ajouter d'autres features si disponibles
    if 'trailer_views' in df_test.columns:
        X_simple['trailer_views'] = df_test['trailer_views'].apply(
            lambda x: float(str(x).replace('vues', '').replace(',', '').replace(' ', '').strip()) 
            if isinstance(x, str) and 'vues' in x else np.nan
        )
    
    # Remplir les valeurs manquantes
    X_simple = X_simple.fillna(X_simple.median())
    
    # Sélectionner les entrées avec des valeurs réelles
    X_train_simple = X_simple[mask_real_values]
    y_train_simple = y_real_log[mask_real_values]
    
    print("Features utilisées pour la prédiction:")
    print(X_simple.columns.tolist())
    print("Statistiques des features:")
    print(X_simple.describe())
    
    # Entraîner le modèle simple
    simple_model = RandomForestRegressor(n_estimators=10, max_depth=3, random_state=42)
    simple_model.fit(X_train_simple, y_train_simple)
    
    # Prédire pour tous les films
    y_pred_log_simple = simple_model.predict(X_simple)
    y_pred_simple = np.expm1(y_pred_log_simple)
# Out:
# Valeurs de box_office_reels:
# ['25 470', None, '-', '23 762', '82 387', '-', '795 858', '-', nan, '56 406', '90 569', nan, '-']
# Valeurs converties:
# [25470.0, nan, nan, 23762.0, 82387.0, nan, 795858.0, nan, nan, 56406.0, 90569.0, nan, nan]
# Nombre de films avec box office connu: 6
# Utilisation de 6 films avec box office connu pour estimer les autres
# Features utilisées pour la prédiction:
# ['budget', 'duree_minutes', 'mois_sortie', 'annee_sortie', 'trailer_views']
# Statistiques des features:
#              budget  duree_minutes  mois_sortie  annee_sortie  trailer_views
# count  1.300000e+01      13.000000         13.0          13.0            0.0
# mean   4.646154e+07      93.076923          4.0        2025.0            NaN
# std    3.192861e+07       5.894369          0.0           0.0            NaN
# min    1.400000e+07      85.000000          4.0        2025.0            NaN
# 25%    4.000000e+07      89.000000          4.0        2025.0            NaN
# 50%    4.000000e+07      92.000000          4.0        2025.0            NaN
# 75%    4.000000e+07      97.000000          4.0        2025.0            NaN
# max    1.500000e+08     103.000000          4.0        2025.0            NaN

# %%
for i, (_, film) in enumerate(df_test.iterrows()):
        # Trouver un identifiant pour le film
        film_title = None
        for title_col in ['titre_allocine', 'titre_clean', 'titre_jpbox', 'film_id']:
            if title_col in film and pd.notna(film[title_col]):
                film_title = film[title_col]
                break
        
        # Si aucun titre n'est trouvé, utiliser un extrait du synopsis
        if film_title is None:
            if 'synopsis_x' in film and pd.notna(film['synopsis_x']):
                film_title = film['synopsis_x'][:50] + "..."
            else:
                film_title = f"Film #{i+1}"
        
        # Valeur prédite
        box_office_predit = y_pred_simple[i]
        
        # Valeur réelle
        box_office_reel = y_real.iloc[i]
        
        # Formatage pour l'affichage
        pred_txt = f"{box_office_predit:,.0f} entrées"
        real_txt = "Non disponible" if pd.isna(box_office_reel) else f"{box_office_reel:,.0f} entrées"
        
        # Affichage
        print(f"- {film_title}")
        print(f"  - Box office prédit: {pred_txt}")
        print(f"  - Box office réel: {real_txt}")
        print("  --------------------------")
    
    # Calculer les métriques d'évaluation sur les films connus
valid_indices = mask_real_values
if valid_indices.sum() > 0:
        from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
        
        y_valid_real = y_real[valid_indices]
        y_valid_pred = y_pred_simple[valid_indices]
        
        print("\nÉvaluation des performances:")
        
        # R²
        r2 = r2_score(y_valid_real, y_valid_pred)
        print(f"R² = {r2:.4f}")
        
        # RMSE
        rmse = np.sqrt(mean_squared_error(y_valid_real, y_valid_pred))
        print(f"RMSE = {rmse:.2f}")
        
        # MAE
        mae = mean_absolute_error(y_valid_real, y_valid_pred)
        print(f"MAE = {mae:.2f}")
        
        # Erreur relative moyenne
        rel_errors = np.abs((y_valid_pred - y_valid_real) / y_valid_real) * 100
        print(f"Erreur relative moyenne: {np.mean(rel_errors):.2f}%")
        print(f"Erreur médiane: {np.median(rel_errors):.2f}%")
else:
        print("Pas assez de valeurs réelles pour entraîner un modèle")
# Out:
# - Deux sœurs
#   - Box office prédit: 27,009 entrées
#   - Box office réel: 25,470 entrées
#   --------------------------
# - 24570
#   - Box office prédit: 58,365 entrées
#   - Box office réel: Non disponible
#   --------------------------
# - Mikado
#   - Box office prédit: 37,762 entrées
#   - Box office réel: Non disponible
#   --------------------------
# - Cassandre
#   - Box office prédit: 26,088 entrées
#   - Box office réel: 23,762 entrées
#   --------------------------
# - Ozi, la voix de la forêt
#   - Box office prédit: 83,962 entrées
#   - Box office réel: 82,387 entrées
#   --------------------------
# - Dog Man
#   - Box office prédit: 66,260 entrées
#   - Box office réel: Non disponible
#   --------------------------
# - Minecraft, Le Film
#   - Box office prédit: 196,732 entrées
#   - Box office réel: 795,858 entrées
#   --------------------------
# - Zion
#   - Box office prédit: 27,009 entrées
#   - Box office réel: Non disponible
#   --------------------------
# - Banger
#   - Box office prédit: 66,260 entrées
#   - Box office réel: Non disponible
#   --------------------------
# - Natacha (presque) hôtesse de l’air
#   - Box office prédit: 66,260 entrées
#   - Box office réel: 56,406 entrées
#   --------------------------
# - Le Routard
#   - Box office prédit: 89,716 entrées
#   - Box office réel: 90,569 entrées
#   --------------------------
# - One of Them Days
#   - Box office prédit: 27,009 entrées
#   - Box office réel: Non disponible
#   --------------------------
# - Doux Jésus
#   - Box office prédit: 89,716 entrées
#   - Box office réel: Non disponible
#   --------------------------
#
# Évaluation des performances:
# R² = 0.2201
# RMSE = 244629.09
# MAE = 102545.70
# Erreur relative moyenne: 18.57%
# Erreur médiane: 7.92%
